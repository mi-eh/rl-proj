# %%
from gym_sepsis.envs.sepsis_env_modified import SepsisEnv
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import os
import datetime

# -------------------------
# Device setup
# -------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
# -------------------------
# Environment setup
# -------------------------
env = SepsisEnv()

reset_output = env.reset()
if isinstance(reset_output, tuple):
    state = reset_output[0]
else:
    state = reset_output
state = np.array(state).flatten()

state_size = len(state)
action_size = env.action_space.n

print("State size:", state_size)
print("Action size:", action_size)
# Out:
# State size: 46
# Action size: 24

# %%
# obs = env.reset()
# done = False
# while not done:
#     action = env.action_space.sample()
#     obs, reward, done, info = env.step(0)
#     print(reward)

# %%
# -------------------------
# Q-network (shared by online and target)
# -------------------------
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, layers=3, hidden=128):
        super(QNetwork, self).__init__()
        self.fc_in = nn.Linear(state_size, hidden)
        self.fc = nn.ModuleList()
        for _ in range(layers):
            self.fc.append(nn.Linear(hidden, hidden))
        self.fc_out = nn.Linear(hidden, action_size)

    def forward(self, x):
        x = torch.relu(self.fc_in(x))
        for layer in self.fc:
            x = torch.relu(layer(x))
        return self.fc_out(x)

# %%
# -------------------------
# Hyperparameters
# -------------------------
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.005
epsilon_decay = 0.995
lr = 1e-3
batch_size = 64
memory_size = 20000
num_episodes = 1000
target_update_freq = 10
eval_episodes = 200  # for evaluation

time_stamp = datetime.datetime.now().timestamp().__round__()
unique_id = str(time_stamp)
save_path = f"policies/policy_net_{unique_id}.pth"

# %%
# -------------------------
# Initialize networks, optimizer, memory
# -------------------------
policy_net = QNetwork(state_size, action_size).to(device)
target_net = QNetwork(state_size, action_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
loss_fn = nn.MSELoss()
memory = deque(maxlen=memory_size)

# %%
# -------------------------
# Helper functions
# -------------------------
def get_action(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        q_values = policy_net(state_t)
        return torch.argmax(q_values).item()

def replay():
    if len(memory) < batch_size:
        return None
    
    batch = random.sample(memory, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(np.vstack(states)).to(device)
    next_states = torch.FloatTensor(np.vstack(next_states)).to(device)
    actions = torch.LongTensor(actions).unsqueeze(1).to(device)
    rewards = torch.FloatTensor(rewards).unsqueeze(1).to(device)
    dones = torch.FloatTensor(dones).unsqueeze(1).to(device)

    # Q-learning (Double DQN)
    q_values = policy_net(states).gather(1, actions)
    next_actions = policy_net(next_states).argmax(1).unsqueeze(1)
    next_q_values = target_net(next_states).gather(1, next_actions).detach()
    target_q = rewards + (gamma * next_q_values * (1 - dones))

    loss = loss_fn(q_values, target_q)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return loss.item()

# %%
# -------------------------
# Training loop
# -------------------------
reward_history, loss_history, episode_length = [], [], []
epsilon_history, action_counts = [], np.zeros(action_size, dtype=int)

for episode in range(num_episodes):
    reset_output = env.reset()
    state = reset_output[0] if isinstance(reset_output, tuple) else reset_output
    state = np.array(state).flatten()
    done, total_reward, steps = False, 0, 0
    episode_losses = []

    while not done:
        action = get_action(state, epsilon)
        step_output = env.step(action)
        if len(step_output) == 5:
            next_state, reward, terminated, truncated, info = step_output
            done = terminated or truncated
        else:
            next_state, reward, done, info = step_output
        next_state = np.array(next_state).flatten()

        memory.append((state, action, reward, next_state, float(done)))
        state = next_state
        total_reward += reward
        steps += 1
        action_counts[action] += 1

        loss_val = replay()
        if loss_val is not None:
            episode_losses.append(loss_val)

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    if episode % target_update_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())

    reward_history.append(total_reward)
    epsilon_history.append(epsilon)
    episode_length.append(steps)
    loss_history.append(np.mean(episode_losses) if episode_losses else 0)

    print("Episode {}/{} | Reward: {:.2f} | Steps: {} | Eps: {:.3f}".format(
        episode+1, num_episodes, total_reward, steps, epsilon))

# Save trained policy
torch.save(policy_net.state_dict(), save_path)
print("Saved trained policy to '{}'".format(save_path))
# Out:
# Episode 1/1000 | Reward: 3.59 | Steps: 9 | Eps: 0.995
# Episode 2/1000 | Reward: -7.58 | Steps: 10 | Eps: 0.990
# Episode 3/1000 | Reward: 0.93 | Steps: 9 | Eps: 0.985
# Episode 4/1000 | Reward: 0.89 | Steps: 9 | Eps: 0.980
# Episode 5/1000 | Reward: 5.40 | Steps: 10 | Eps: 0.975
# Episode 6/1000 | Reward: 3.63 | Steps: 10 | Eps: 0.970
# Episode 7/1000 | Reward: -8.49 | Steps: 6 | Eps: 0.966
# Episode 8/1000 | Reward: -6.76 | Steps: 9 | Eps: 0.961
# Episode 9/1000 | Reward: 3.21 | Steps: 10 | Eps: 0.956
# Episode 10/1000 | Reward: 2.76 | Steps: 9 | Eps: 0.951
# Episode 11/1000 | Reward: 4.06 | Steps: 9 | Eps: 0.946
# Episode 12/1000 | Reward: 2.22 | Steps: 10 | Eps: 0.942
# Episode 13/1000 | Reward: 2.94 | Steps: 10 | Eps: 0.937
# Episode 14/1000 | Reward: 6.29 | Steps: 10 | Eps: 0.932
# Episode 15/1000 | Reward: 4.42 | Steps: 9 | Eps: 0.928
# Episode 16/1000 | Reward: 3.64 | Steps: 8 | Eps: 0.923
# Episode 17/1000 | Reward: 3.78 | Steps: 9 | Eps: 0.918
# Episode 18/1000 | Reward: 3.42 | Steps: 9 | Eps: 0.914
# Episode 19/1000 | Reward: 4.22 | Steps: 10 | Eps: 0.909
# Episode 20/1000 | Reward: 3.19 | Steps: 10 | Eps: 0.905
# Episode 21/1000 | Reward: 2.95 | Steps: 9 | Eps: 0.900
# Episode 22/1000 | Reward: 4.89 | Steps: 9 | Eps: 0.896
# Episode 23/1000 | Reward: 3.11 | Steps: 9 | Eps: 0.891
# Episode 24/1000 | Reward: 4.48 | Steps: 10 | Eps: 0.887
# Episode 25/1000 | Reward: 2.49 | Steps: 9 | Eps: 0.882
# Episode 26/1000 | Reward: 2.32 | Steps: 9 | Eps: 0.878
# Episode 27/1000 | Reward: -5.88 | Steps: 10 | Eps: 0.873
# Episode 28/1000 | Reward: 3.36 | Steps: 9 | Eps: 0.869
# Episode 29/1000 | Reward: 4.56 | Steps: 8 | Eps: 0.865
# Episode 30/1000 | Reward: 3.97 | Steps: 9 | Eps: 0.860
# Episode 31/1000 | Reward: 4.94 | Steps: 8 | Eps: 0.856
# Episode 32/1000 | Reward: 3.19 | Steps: 9 | Eps: 0.852
# Episode 33/1000 | Reward: 4.80 | Steps: 10 | Eps: 0.848
# Episode 34/1000 | Reward: 2.56 | Steps: 10 | Eps: 0.843
# Episode 35/1000 | Reward: 3.60 | Steps: 9 | Eps: 0.839
# Episode 36/1000 | Reward: 4.43 | Steps: 6 | Eps: 0.835
# Episode 37/1000 | Reward: 4.36 | Steps: 9 | Eps: 0.831
# Episode 38/1000 | Reward: 5.12 | Steps: 9 | Eps: 0.827
# Episode 39/1000 | Reward: -6.96 | Steps: 9 | Eps: 0.822
# Episode 40/1000 | Reward: 2.69 | Steps: 9 | Eps: 0.818
# Episode 41/1000 | Reward: 4.05 | Steps: 9 | Eps: 0.814
# Episode 42/1000 | Reward: 4.57 | Steps: 9 | Eps: 0.810
# Episode 43/1000 | Reward: -7.20 | Steps: 9 | Eps: 0.806
# Episode 44/1000 | Reward: 3.26 | Steps: 9 | Eps: 0.802
# Episode 45/1000 | Reward: 1.60 | Steps: 9 | Eps: 0.798
# Episode 46/1000 | Reward: -6.44 | Steps: 10 | Eps: 0.794
# Episode 47/1000 | Reward: 3.01 | Steps: 9 | Eps: 0.790
# Episode 48/1000 | Reward: 2.11 | Steps: 10 | Eps: 0.786
# Episode 49/1000 | Reward: 3.12 | Steps: 10 | Eps: 0.782
# Episode 50/1000 | Reward: 3.03 | Steps: 10 | Eps: 0.778
# Episode 51/1000 | Reward: 3.87 | Steps: 10 | Eps: 0.774
# Episode 52/1000 | Reward: 1.29 | Steps: 9 | Eps: 0.771
# Episode 53/1000 | Reward: 3.64 | Steps: 9 | Eps: 0.767
# Episode 54/1000 | Reward: 4.78 | Steps: 10 | Eps: 0.763
# Episode 55/1000 | Reward: 3.32 | Steps: 9 | Eps: 0.759
# Episode 56/1000 | Reward: 2.63 | Steps: 9 | Eps: 0.755
# Episode 57/1000 | Reward: 3.45 | Steps: 9 | Eps: 0.751
# Episode 58/1000 | Reward: 3.84 | Steps: 9 | Eps: 0.748
# Episode 59/1000 | Reward: -9.02 | Steps: 8 | Eps: 0.744
# Episode 60/1000 | Reward: 3.80 | Steps: 10 | Eps: 0.740
# Episode 61/1000 | Reward: 2.18 | Steps: 10 | Eps: 0.737
# Episode 62/1000 | Reward: 9.36 | Steps: 8 | Eps: 0.733
# Episode 63/1000 | Reward: 3.73 | Steps: 10 | Eps: 0.729
# Episode 64/1000 | Reward: 3.44 | Steps: 10 | Eps: 0.726
# Episode 65/1000 | Reward: 4.11 | Steps: 10 | Eps: 0.722
# Episode 66/1000 | Reward: 5.52 | Steps: 10 | Eps: 0.718
# Episode 67/1000 | Reward: 4.10 | Steps: 8 | Eps: 0.715
# Episode 68/1000 | Reward: 3.77 | Steps: 9 | Eps: 0.711
# Episode 69/1000 | Reward: 4.68 | Steps: 9 | Eps: 0.708
# Episode 70/1000 | Reward: 5.13 | Steps: 9 | Eps: 0.704
# Episode 71/1000 | Reward: 1.62 | Steps: 9 | Eps: 0.701
# Episode 72/1000 | Reward: 6.33 | Steps: 9 | Eps: 0.697
# Episode 73/1000 | Reward: 3.43 | Steps: 9 | Eps: 0.694
# Episode 74/1000 | Reward: -10.50 | Steps: 11 | Eps: 0.690
# Episode 75/1000 | Reward: 5.40 | Steps: 8 | Eps: 0.687
# Episode 76/1000 | Reward: 2.74 | Steps: 9 | Eps: 0.683
# Episode 77/1000 | Reward: 3.50 | Steps: 8 | Eps: 0.680
# Episode 78/1000 | Reward: 3.94 | Steps: 9 | Eps: 0.676
# Episode 79/1000 | Reward: 2.37 | Steps: 10 | Eps: 0.673
# Episode 80/1000 | Reward: 2.59 | Steps: 10 | Eps: 0.670
# Episode 81/1000 | Reward: 2.29 | Steps: 9 | Eps: 0.666
# Episode 82/1000 | Reward: 3.56 | Steps: 10 | Eps: 0.663
# Episode 83/1000 | Reward: 4.01 | Steps: 9 | Eps: 0.660
# Episode 84/1000 | Reward: 4.68 | Steps: 10 | Eps: 0.656
# Episode 85/1000 | Reward: -7.57 | Steps: 9 | Eps: 0.653
# Episode 86/1000 | Reward: 3.70 | Steps: 10 | Eps: 0.650
# Episode 87/1000 | Reward: 1.73 | Steps: 10 | Eps: 0.647
# Episode 88/1000 | Reward: 4.80 | Steps: 9 | Eps: 0.643
# Episode 89/1000 | Reward: 3.96 | Steps: 10 | Eps: 0.640
# Episode 90/1000 | Reward: 4.67 | Steps: 9 | Eps: 0.637
# Episode 91/1000 | Reward: 3.89 | Steps: 8 | Eps: 0.634
# Episode 92/1000 | Reward: 4.13 | Steps: 9 | Eps: 0.631
# Episode 93/1000 | Reward: 3.92 | Steps: 9 | Eps: 0.627
# Episode 94/1000 | Reward: 3.97 | Steps: 11 | Eps: 0.624
# Episode 95/1000 | Reward: 3.18 | Steps: 10 | Eps: 0.621
# Episode 96/1000 | Reward: 2.63 | Steps: 9 | Eps: 0.618
# Episode 97/1000 | Reward: 3.29 | Steps: 9 | Eps: 0.615
# Episode 98/1000 | Reward: 4.08 | Steps: 9 | Eps: 0.612
# Episode 99/1000 | Reward: 4.10 | Steps: 10 | Eps: 0.609
# Episode 100/1000 | Reward: -7.24 | Steps: 8 | Eps: 0.606
# Episode 101/1000 | Reward: 5.11 | Steps: 9 | Eps: 0.603
# Episode 102/1000 | Reward: 4.85 | Steps: 11 | Eps: 0.600
# Episode 103/1000 | Reward: 3.14 | Steps: 10 | Eps: 0.597
# Episode 104/1000 | Reward: 3.18 | Steps: 11 | Eps: 0.594
# Episode 105/1000 | Reward: 4.23 | Steps: 9 | Eps: 0.591
# Episode 106/1000 | Reward: 2.61 | Steps: 10 | Eps: 0.588
# Episode 107/1000 | Reward: 4.65 | Steps: 10 | Eps: 0.585
# Episode 108/1000 | Reward: 3.89 | Steps: 10 | Eps: 0.582
# Episode 109/1000 | Reward: 5.77 | Steps: 9 | Eps: 0.579
# Episode 110/1000 | Reward: 5.35 | Steps: 10 | Eps: 0.576
# Episode 111/1000 | Reward: 3.30 | Steps: 11 | Eps: 0.573
# Episode 112/1000 | Reward: 2.91 | Steps: 9 | Eps: 0.570
# Episode 113/1000 | Reward: 1.72 | Steps: 9 | Eps: 0.568
# Episode 114/1000 | Reward: 4.16 | Steps: 10 | Eps: 0.565
# Episode 115/1000 | Reward: 6.37 | Steps: 9 | Eps: 0.562
# Episode 116/1000 | Reward: 3.97 | Steps: 10 | Eps: 0.559
# Episode 117/1000 | Reward: 5.14 | Steps: 10 | Eps: 0.556
# Episode 118/1000 | Reward: 4.06 | Steps: 10 | Eps: 0.554
# Episode 119/1000 | Reward: 2.20 | Steps: 9 | Eps: 0.551
# Episode 120/1000 | Reward: 2.99 | Steps: 9 | Eps: 0.548
# Episode 121/1000 | Reward: 3.33 | Steps: 9 | Eps: 0.545
# Episode 122/1000 | Reward: 4.12 | Steps: 10 | Eps: 0.543
# Episode 123/1000 | Reward: 3.22 | Steps: 10 | Eps: 0.540
# Episode 124/1000 | Reward: 3.27 | Steps: 9 | Eps: 0.537
# Episode 125/1000 | Reward: 4.04 | Steps: 9 | Eps: 0.534
# Episode 126/1000 | Reward: 2.68 | Steps: 10 | Eps: 0.532
# Episode 127/1000 | Reward: 2.72 | Steps: 9 | Eps: 0.529
# Episode 128/1000 | Reward: 3.01 | Steps: 9 | Eps: 0.526
# Episode 129/1000 | Reward: 5.81 | Steps: 10 | Eps: 0.524
# Episode 130/1000 | Reward: 4.40 | Steps: 10 | Eps: 0.521
# Episode 131/1000 | Reward: 4.70 | Steps: 9 | Eps: 0.519
# Episode 132/1000 | Reward: 4.28 | Steps: 10 | Eps: 0.516
# Episode 133/1000 | Reward: 4.36 | Steps: 9 | Eps: 0.513
# Episode 134/1000 | Reward: 2.59 | Steps: 10 | Eps: 0.511
# Episode 135/1000 | Reward: 5.06 | Steps: 10 | Eps: 0.508
# Episode 136/1000 | Reward: 2.96 | Steps: 9 | Eps: 0.506
# Episode 137/1000 | Reward: -5.73 | Steps: 10 | Eps: 0.503
# Episode 138/1000 | Reward: 3.16 | Steps: 9 | Eps: 0.501
# Episode 139/1000 | Reward: 3.60 | Steps: 9 | Eps: 0.498
# Episode 140/1000 | Reward: 4.34 | Steps: 8 | Eps: 0.496
# Episode 141/1000 | Reward: 3.83 | Steps: 9 | Eps: 0.493
# Episode 142/1000 | Reward: 2.58 | Steps: 9 | Eps: 0.491
# Episode 143/1000 | Reward: 3.32 | Steps: 10 | Eps: 0.488
# Episode 144/1000 | Reward: 4.16 | Steps: 9 | Eps: 0.486
# Episode 145/1000 | Reward: 3.19 | Steps: 9 | Eps: 0.483
# Episode 146/1000 | Reward: 3.97 | Steps: 9 | Eps: 0.481
# Episode 147/1000 | Reward: 4.49 | Steps: 10 | Eps: 0.479
# Episode 148/1000 | Reward: 3.73 | Steps: 9 | Eps: 0.476
# Episode 149/1000 | Reward: 4.21 | Steps: 8 | Eps: 0.474
# Episode 150/1000 | Reward: 3.15 | Steps: 8 | Eps: 0.471
# Episode 151/1000 | Reward: 4.02 | Steps: 9 | Eps: 0.469
# Episode 152/1000 | Reward: 3.71 | Steps: 10 | Eps: 0.467
# Episode 153/1000 | Reward: 4.97 | Steps: 10 | Eps: 0.464
# Episode 154/1000 | Reward: 4.32 | Steps: 10 | Eps: 0.462
# Episode 155/1000 | Reward: 4.08 | Steps: 9 | Eps: 0.460
# Episode 156/1000 | Reward: 3.73 | Steps: 8 | Eps: 0.458
# Episode 157/1000 | Reward: 4.58 | Steps: 9 | Eps: 0.455
# Episode 158/1000 | Reward: 3.42 | Steps: 10 | Eps: 0.453
# Episode 159/1000 | Reward: 5.16 | Steps: 10 | Eps: 0.451
# Episode 160/1000 | Reward: 3.97 | Steps: 10 | Eps: 0.448
# Episode 161/1000 | Reward: 3.32 | Steps: 10 | Eps: 0.446
# Episode 162/1000 | Reward: 3.21 | Steps: 8 | Eps: 0.444
# Episode 163/1000 | Reward: 2.78 | Steps: 9 | Eps: 0.442
# Episode 164/1000 | Reward: 3.24 | Steps: 9 | Eps: 0.440
# Episode 165/1000 | Reward: 1.79 | Steps: 9 | Eps: 0.437
# Episode 166/1000 | Reward: 1.02 | Steps: 9 | Eps: 0.435
# Episode 167/1000 | Reward: 3.45 | Steps: 10 | Eps: 0.433
# Episode 168/1000 | Reward: -9.11 | Steps: 9 | Eps: 0.431
# Episode 169/1000 | Reward: 3.32 | Steps: 10 | Eps: 0.429
# Episode 170/1000 | Reward: 3.38 | Steps: 10 | Eps: 0.427
# Episode 171/1000 | Reward: 3.07 | Steps: 9 | Eps: 0.424
# Episode 172/1000 | Reward: 3.93 | Steps: 9 | Eps: 0.422
# Episode 173/1000 | Reward: 4.29 | Steps: 9 | Eps: 0.420
# Episode 174/1000 | Reward: 4.05 | Steps: 10 | Eps: 0.418
# Episode 175/1000 | Reward: 4.23 | Steps: 6 | Eps: 0.416
# Episode 176/1000 | Reward: 2.79 | Steps: 10 | Eps: 0.414
# Episode 177/1000 | Reward: 3.72 | Steps: 10 | Eps: 0.412
# Episode 178/1000 | Reward: 5.33 | Steps: 10 | Eps: 0.410
# Episode 179/1000 | Reward: 3.17 | Steps: 9 | Eps: 0.408
# Episode 180/1000 | Reward: 3.65 | Steps: 9 | Eps: 0.406
# Episode 181/1000 | Reward: 4.08 | Steps: 9 | Eps: 0.404
# Episode 182/1000 | Reward: 5.23 | Steps: 8 | Eps: 0.402
# Episode 183/1000 | Reward: 3.10 | Steps: 9 | Eps: 0.400
# Episode 184/1000 | Reward: 5.05 | Steps: 10 | Eps: 0.398
# Episode 185/1000 | Reward: 3.70 | Steps: 9 | Eps: 0.396
# Episode 186/1000 | Reward: 4.56 | Steps: 10 | Eps: 0.394
# Episode 187/1000 | Reward: 4.17 | Steps: 9 | Eps: 0.392
# Episode 188/1000 | Reward: 3.73 | Steps: 9 | Eps: 0.390
# Episode 189/1000 | Reward: 5.89 | Steps: 9 | Eps: 0.388
# Episode 190/1000 | Reward: 1.32 | Steps: 9 | Eps: 0.386
# Episode 191/1000 | Reward: 4.42 | Steps: 9 | Eps: 0.384
# Episode 192/1000 | Reward: 3.83 | Steps: 7 | Eps: 0.382
# Episode 193/1000 | Reward: 3.82 | Steps: 9 | Eps: 0.380
# Episode 194/1000 | Reward: 3.38 | Steps: 10 | Eps: 0.378
# Episode 195/1000 | Reward: 4.01 | Steps: 9 | Eps: 0.376
# Episode 196/1000 | Reward: 4.18 | Steps: 8 | Eps: 0.374
# Episode 197/1000 | Reward: 2.85 | Steps: 8 | Eps: 0.373
# Episode 198/1000 | Reward: 2.86 | Steps: 9 | Eps: 0.371
# Episode 199/1000 | Reward: 0.29 | Steps: 10 | Eps: 0.369
# Episode 200/1000 | Reward: 4.08 | Steps: 9 | Eps: 0.367
# Episode 201/1000 | Reward: 4.09 | Steps: 11 | Eps: 0.365
# Episode 202/1000 | Reward: 5.41 | Steps: 9 | Eps: 0.363
# Episode 203/1000 | Reward: 2.93 | Steps: 10 | Eps: 0.361
# Episode 204/1000 | Reward: 2.90 | Steps: 10 | Eps: 0.360
# Episode 205/1000 | Reward: 4.31 | Steps: 8 | Eps: 0.358
# Episode 206/1000 | Reward: 2.39 | Steps: 9 | Eps: 0.356
# Episode 207/1000 | Reward: 2.50 | Steps: 9 | Eps: 0.354
# Episode 208/1000 | Reward: 3.28 | Steps: 10 | Eps: 0.353
# Episode 209/1000 | Reward: -7.74 | Steps: 10 | Eps: 0.351
# Episode 210/1000 | Reward: 3.30 | Steps: 10 | Eps: 0.349
# Episode 211/1000 | Reward: 2.69 | Steps: 9 | Eps: 0.347
# Episode 212/1000 | Reward: 3.67 | Steps: 6 | Eps: 0.346
# Episode 213/1000 | Reward: 2.46 | Steps: 9 | Eps: 0.344
# Episode 214/1000 | Reward: 4.51 | Steps: 9 | Eps: 0.342
# Episode 215/1000 | Reward: 3.33 | Steps: 12 | Eps: 0.340
# Episode 216/1000 | Reward: 4.14 | Steps: 10 | Eps: 0.339
# Episode 217/1000 | Reward: 5.04 | Steps: 9 | Eps: 0.337
# Episode 218/1000 | Reward: -7.29 | Steps: 9 | Eps: 0.335
# Episode 219/1000 | Reward: 2.51 | Steps: 10 | Eps: 0.334
# Episode 220/1000 | Reward: 3.23 | Steps: 9 | Eps: 0.332
# Episode 221/1000 | Reward: 1.82 | Steps: 9 | Eps: 0.330
# Episode 222/1000 | Reward: 4.69 | Steps: 9 | Eps: 0.329
# Episode 223/1000 | Reward: 4.74 | Steps: 8 | Eps: 0.327
# Episode 224/1000 | Reward: 5.20 | Steps: 9 | Eps: 0.325
# Episode 225/1000 | Reward: 5.09 | Steps: 9 | Eps: 0.324
# Episode 226/1000 | Reward: 2.88 | Steps: 10 | Eps: 0.322
# Episode 227/1000 | Reward: 4.86 | Steps: 10 | Eps: 0.321
# Episode 228/1000 | Reward: 3.03 | Steps: 9 | Eps: 0.319
# Episode 229/1000 | Reward: 2.24 | Steps: 10 | Eps: 0.317
# Episode 230/1000 | Reward: 4.06 | Steps: 10 | Eps: 0.316
# Episode 231/1000 | Reward: 4.89 | Steps: 9 | Eps: 0.314
# Episode 232/1000 | Reward: 2.54 | Steps: 9 | Eps: 0.313
# Episode 233/1000 | Reward: 4.44 | Steps: 10 | Eps: 0.311
# Episode 234/1000 | Reward: 3.67 | Steps: 9 | Eps: 0.309
# Episode 235/1000 | Reward: 2.83 | Steps: 9 | Eps: 0.308
# Episode 236/1000 | Reward: 3.05 | Steps: 10 | Eps: 0.306
# Episode 237/1000 | Reward: -2.85 | Steps: 9 | Eps: 0.305
# Episode 238/1000 | Reward: 4.82 | Steps: 9 | Eps: 0.303
# Episode 239/1000 | Reward: 3.45 | Steps: 10 | Eps: 0.302
# Episode 240/1000 | Reward: 5.05 | Steps: 9 | Eps: 0.300
# Episode 241/1000 | Reward: 5.01 | Steps: 9 | Eps: 0.299
# Episode 242/1000 | Reward: 2.84 | Steps: 9 | Eps: 0.297
# Episode 243/1000 | Reward: 2.10 | Steps: 9 | Eps: 0.296
# Episode 244/1000 | Reward: 3.40 | Steps: 9 | Eps: 0.294
# Episode 245/1000 | Reward: 5.21 | Steps: 10 | Eps: 0.293
# Episode 246/1000 | Reward: 2.84 | Steps: 10 | Eps: 0.291
# Episode 247/1000 | Reward: 5.40 | Steps: 10 | Eps: 0.290
# Episode 248/1000 | Reward: 3.48 | Steps: 9 | Eps: 0.288
# Episode 249/1000 | Reward: 2.53 | Steps: 10 | Eps: 0.287
# Episode 250/1000 | Reward: 3.70 | Steps: 9 | Eps: 0.286
# Episode 251/1000 | Reward: -7.51 | Steps: 9 | Eps: 0.284
# Episode 252/1000 | Reward: 2.72 | Steps: 10 | Eps: 0.283
# Episode 253/1000 | Reward: 3.42 | Steps: 9 | Eps: 0.281
# Episode 254/1000 | Reward: -8.08 | Steps: 9 | Eps: 0.280
# Episode 255/1000 | Reward: 3.38 | Steps: 6 | Eps: 0.279
# Episode 256/1000 | Reward: -7.26 | Steps: 10 | Eps: 0.277
# Episode 257/1000 | Reward: 4.15 | Steps: 10 | Eps: 0.276
# Episode 258/1000 | Reward: 2.48 | Steps: 10 | Eps: 0.274
# Episode 259/1000 | Reward: 5.56 | Steps: 10 | Eps: 0.273
# Episode 260/1000 | Reward: 3.46 | Steps: 10 | Eps: 0.272
# Episode 261/1000 | Reward: 3.81 | Steps: 10 | Eps: 0.270
# Episode 262/1000 | Reward: 3.07 | Steps: 9 | Eps: 0.269
# Episode 263/1000 | Reward: 4.69 | Steps: 10 | Eps: 0.268
# Episode 264/1000 | Reward: 3.37 | Steps: 10 | Eps: 0.266
# Episode 265/1000 | Reward: 4.46 | Steps: 10 | Eps: 0.265
# Episode 266/1000 | Reward: 3.93 | Steps: 10 | Eps: 0.264
# Episode 267/1000 | Reward: 4.62 | Steps: 9 | Eps: 0.262
# Episode 268/1000 | Reward: 3.73 | Steps: 10 | Eps: 0.261
# Episode 269/1000 | Reward: 4.23 | Steps: 9 | Eps: 0.260
# Episode 270/1000 | Reward: 3.84 | Steps: 9 | Eps: 0.258
# Episode 271/1000 | Reward: 2.95 | Steps: 10 | Eps: 0.257
# Episode 272/1000 | Reward: 3.26 | Steps: 10 | Eps: 0.256
# Episode 273/1000 | Reward: 3.91 | Steps: 7 | Eps: 0.255
# Episode 274/1000 | Reward: 3.21 | Steps: 9 | Eps: 0.253
# Episode 275/1000 | Reward: 3.27 | Steps: 9 | Eps: 0.252
# Episode 276/1000 | Reward: 2.99 | Steps: 9 | Eps: 0.251
# Episode 277/1000 | Reward: 3.24 | Steps: 11 | Eps: 0.249
# Episode 278/1000 | Reward: 4.58 | Steps: 9 | Eps: 0.248
# Episode 279/1000 | Reward: 2.52 | Steps: 9 | Eps: 0.247
# Episode 280/1000 | Reward: 1.94 | Steps: 9 | Eps: 0.246
# Episode 281/1000 | Reward: 1.69 | Steps: 9 | Eps: 0.245
# Episode 282/1000 | Reward: -8.92 | Steps: 8 | Eps: 0.243
# Episode 283/1000 | Reward: 4.08 | Steps: 10 | Eps: 0.242
# Episode 284/1000 | Reward: 3.19 | Steps: 10 | Eps: 0.241
# Episode 285/1000 | Reward: 3.52 | Steps: 10 | Eps: 0.240
# Episode 286/1000 | Reward: 4.76 | Steps: 6 | Eps: 0.238
# Episode 287/1000 | Reward: -7.78 | Steps: 9 | Eps: 0.237
# Episode 288/1000 | Reward: 4.27 | Steps: 9 | Eps: 0.236
# Episode 289/1000 | Reward: -9.72 | Steps: 9 | Eps: 0.235
# Episode 290/1000 | Reward: 3.02 | Steps: 11 | Eps: 0.234
# Episode 291/1000 | Reward: 3.61 | Steps: 9 | Eps: 0.233
# Episode 292/1000 | Reward: 2.33 | Steps: 9 | Eps: 0.231
# Episode 293/1000 | Reward: 4.29 | Steps: 9 | Eps: 0.230
# Episode 294/1000 | Reward: 5.34 | Steps: 9 | Eps: 0.229
# Episode 295/1000 | Reward: 2.18 | Steps: 9 | Eps: 0.228
# Episode 296/1000 | Reward: -4.73 | Steps: 9 | Eps: 0.227
# Episode 297/1000 | Reward: 4.43 | Steps: 10 | Eps: 0.226
# Episode 298/1000 | Reward: 2.94 | Steps: 9 | Eps: 0.225
# Episode 299/1000 | Reward: 3.89 | Steps: 10 | Eps: 0.223
# Episode 300/1000 | Reward: 6.79 | Steps: 10 | Eps: 0.222
# Episode 301/1000 | Reward: 2.93 | Steps: 10 | Eps: 0.221
# Episode 302/1000 | Reward: -9.10 | Steps: 9 | Eps: 0.220
# Episode 303/1000 | Reward: 4.06 | Steps: 10 | Eps: 0.219
# Episode 304/1000 | Reward: 4.02 | Steps: 9 | Eps: 0.218
# Episode 305/1000 | Reward: 3.85 | Steps: 10 | Eps: 0.217
# Episode 306/1000 | Reward: 4.46 | Steps: 9 | Eps: 0.216
# Episode 307/1000 | Reward: 3.04 | Steps: 9 | Eps: 0.215
# Episode 308/1000 | Reward: 2.44 | Steps: 9 | Eps: 0.214
# Episode 309/1000 | Reward: 3.65 | Steps: 9 | Eps: 0.212
# Episode 310/1000 | Reward: -6.54 | Steps: 9 | Eps: 0.211
# Episode 311/1000 | Reward: 4.84 | Steps: 9 | Eps: 0.210
# Episode 312/1000 | Reward: -5.74 | Steps: 10 | Eps: 0.209
# Episode 313/1000 | Reward: 2.65 | Steps: 9 | Eps: 0.208
# Episode 314/1000 | Reward: 3.17 | Steps: 9 | Eps: 0.207
# Episode 315/1000 | Reward: 4.20 | Steps: 10 | Eps: 0.206
# Episode 316/1000 | Reward: 3.73 | Steps: 10 | Eps: 0.205
# Episode 317/1000 | Reward: 3.15 | Steps: 10 | Eps: 0.204
# Episode 318/1000 | Reward: 4.60 | Steps: 10 | Eps: 0.203
# Episode 319/1000 | Reward: 3.48 | Steps: 9 | Eps: 0.202
# Episode 320/1000 | Reward: 4.15 | Steps: 10 | Eps: 0.201
# Episode 321/1000 | Reward: 2.65 | Steps: 10 | Eps: 0.200
# Episode 322/1000 | Reward: 3.61 | Steps: 9 | Eps: 0.199
# Episode 323/1000 | Reward: 2.41 | Steps: 10 | Eps: 0.198
# Episode 324/1000 | Reward: 4.46 | Steps: 9 | Eps: 0.197
# Episode 325/1000 | Reward: 1.69 | Steps: 9 | Eps: 0.196
# Episode 326/1000 | Reward: 2.53 | Steps: 11 | Eps: 0.195
# Episode 327/1000 | Reward: 1.90 | Steps: 9 | Eps: 0.194
# Episode 328/1000 | Reward: 3.49 | Steps: 10 | Eps: 0.193
# Episode 329/1000 | Reward: 3.62 | Steps: 9 | Eps: 0.192
# Episode 330/1000 | Reward: 3.29 | Steps: 9 | Eps: 0.191
# Episode 331/1000 | Reward: 4.32 | Steps: 10 | Eps: 0.190
# Episode 332/1000 | Reward: 4.50 | Steps: 9 | Eps: 0.189
# Episode 333/1000 | Reward: 3.32 | Steps: 10 | Eps: 0.188
# Episode 334/1000 | Reward: 3.43 | Steps: 10 | Eps: 0.187
# Episode 335/1000 | Reward: 4.65 | Steps: 10 | Eps: 0.187
# Episode 336/1000 | Reward: 4.27 | Steps: 10 | Eps: 0.186
# Episode 337/1000 | Reward: 3.21 | Steps: 9 | Eps: 0.185
# Episode 338/1000 | Reward: 2.60 | Steps: 10 | Eps: 0.184
# Episode 339/1000 | Reward: 2.99 | Steps: 9 | Eps: 0.183
# Episode 340/1000 | Reward: 3.96 | Steps: 9 | Eps: 0.182
# Episode 341/1000 | Reward: 2.65 | Steps: 10 | Eps: 0.181
# Episode 342/1000 | Reward: 1.75 | Steps: 10 | Eps: 0.180
# Episode 343/1000 | Reward: 3.70 | Steps: 9 | Eps: 0.179
# Episode 344/1000 | Reward: 3.76 | Steps: 9 | Eps: 0.178
# Episode 345/1000 | Reward: 2.61 | Steps: 9 | Eps: 0.177
# Episode 346/1000 | Reward: 4.00 | Steps: 11 | Eps: 0.177
# Episode 347/1000 | Reward: 2.93 | Steps: 9 | Eps: 0.176
# Episode 348/1000 | Reward: 3.46 | Steps: 10 | Eps: 0.175
# Episode 349/1000 | Reward: 2.77 | Steps: 10 | Eps: 0.174
# Episode 350/1000 | Reward: 5.38 | Steps: 9 | Eps: 0.173
# Episode 351/1000 | Reward: 4.06 | Steps: 10 | Eps: 0.172
# Episode 352/1000 | Reward: 2.32 | Steps: 9 | Eps: 0.171
# Episode 353/1000 | Reward: 3.18 | Steps: 10 | Eps: 0.170
# Episode 354/1000 | Reward: 3.86 | Steps: 10 | Eps: 0.170
# Episode 355/1000 | Reward: 1.36 | Steps: 12 | Eps: 0.169
# Episode 356/1000 | Reward: 4.56 | Steps: 9 | Eps: 0.168
# Episode 357/1000 | Reward: 3.04 | Steps: 10 | Eps: 0.167
# Episode 358/1000 | Reward: 3.90 | Steps: 10 | Eps: 0.166
# Episode 359/1000 | Reward: 3.95 | Steps: 9 | Eps: 0.165
# Episode 360/1000 | Reward: 4.29 | Steps: 9 | Eps: 0.165
# Episode 361/1000 | Reward: 4.64 | Steps: 10 | Eps: 0.164
# Episode 362/1000 | Reward: 4.18 | Steps: 9 | Eps: 0.163
# Episode 363/1000 | Reward: 3.40 | Steps: 10 | Eps: 0.162
# Episode 364/1000 | Reward: 3.84 | Steps: 10 | Eps: 0.161
# Episode 365/1000 | Reward: 3.23 | Steps: 10 | Eps: 0.160
# Episode 366/1000 | Reward: 4.46 | Steps: 9 | Eps: 0.160
# Episode 367/1000 | Reward: 4.65 | Steps: 8 | Eps: 0.159
# Episode 368/1000 | Reward: 3.57 | Steps: 9 | Eps: 0.158
# Episode 369/1000 | Reward: 3.57 | Steps: 10 | Eps: 0.157
# Episode 370/1000 | Reward: 3.94 | Steps: 9 | Eps: 0.157
# Episode 371/1000 | Reward: 2.96 | Steps: 9 | Eps: 0.156
# Episode 372/1000 | Reward: 4.39 | Steps: 10 | Eps: 0.155
# Episode 373/1000 | Reward: 3.90 | Steps: 9 | Eps: 0.154
# Episode 374/1000 | Reward: 3.07 | Steps: 10 | Eps: 0.153
# Episode 375/1000 | Reward: 0.95 | Steps: 11 | Eps: 0.153
# Episode 376/1000 | Reward: 3.30 | Steps: 10 | Eps: 0.152
# Episode 377/1000 | Reward: 3.77 | Steps: 10 | Eps: 0.151
# Episode 378/1000 | Reward: 3.47 | Steps: 9 | Eps: 0.150
# Episode 379/1000 | Reward: 4.33 | Steps: 10 | Eps: 0.150
# Episode 380/1000 | Reward: 3.03 | Steps: 10 | Eps: 0.149
# Episode 381/1000 | Reward: 4.79 | Steps: 9 | Eps: 0.148
# Episode 382/1000 | Reward: 4.29 | Steps: 10 | Eps: 0.147
# Episode 383/1000 | Reward: 2.43 | Steps: 7 | Eps: 0.147
# Episode 384/1000 | Reward: 3.19 | Steps: 9 | Eps: 0.146
# Episode 385/1000 | Reward: 4.45 | Steps: 10 | Eps: 0.145
# Episode 386/1000 | Reward: 3.96 | Steps: 10 | Eps: 0.144
# Episode 387/1000 | Reward: 3.84 | Steps: 10 | Eps: 0.144
# Episode 388/1000 | Reward: 3.63 | Steps: 10 | Eps: 0.143
# Episode 389/1000 | Reward: -11.44 | Steps: 6 | Eps: 0.142
# Episode 390/1000 | Reward: -11.57 | Steps: 11 | Eps: 0.142
# Episode 391/1000 | Reward: -10.80 | Steps: 9 | Eps: 0.141
# Episode 392/1000 | Reward: 3.29 | Steps: 9 | Eps: 0.140
# Episode 393/1000 | Reward: 4.03 | Steps: 9 | Eps: 0.139
# Episode 394/1000 | Reward: 4.53 | Steps: 10 | Eps: 0.139
# Episode 395/1000 | Reward: 3.57 | Steps: 8 | Eps: 0.138
# Episode 396/1000 | Reward: 4.82 | Steps: 9 | Eps: 0.137
# Episode 397/1000 | Reward: 3.70 | Steps: 8 | Eps: 0.137
# Episode 398/1000 | Reward: 3.22 | Steps: 10 | Eps: 0.136
# Episode 399/1000 | Reward: 3.41 | Steps: 9 | Eps: 0.135
# Episode 400/1000 | Reward: 5.81 | Steps: 10 | Eps: 0.135
# Episode 401/1000 | Reward: 3.00 | Steps: 10 | Eps: 0.134
# Episode 402/1000 | Reward: 4.03 | Steps: 9 | Eps: 0.133
# Episode 403/1000 | Reward: 5.39 | Steps: 10 | Eps: 0.133
# Episode 404/1000 | Reward: 2.38 | Steps: 10 | Eps: 0.132
# Episode 405/1000 | Reward: 3.17 | Steps: 10 | Eps: 0.131
# Episode 406/1000 | Reward: 2.54 | Steps: 9 | Eps: 0.131
# Episode 407/1000 | Reward: 2.12 | Steps: 9 | Eps: 0.130
# Episode 408/1000 | Reward: 2.52 | Steps: 10 | Eps: 0.129
# Episode 409/1000 | Reward: 3.06 | Steps: 9 | Eps: 0.129
# Episode 410/1000 | Reward: 2.84 | Steps: 9 | Eps: 0.128
# Episode 411/1000 | Reward: 3.50 | Steps: 9 | Eps: 0.127
# Episode 412/1000 | Reward: 0.98 | Steps: 9 | Eps: 0.127
# Episode 413/1000 | Reward: -10.62 | Steps: 9 | Eps: 0.126
# Episode 414/1000 | Reward: 4.57 | Steps: 8 | Eps: 0.126
# Episode 415/1000 | Reward: 4.29 | Steps: 9 | Eps: 0.125
# Episode 416/1000 | Reward: 4.43 | Steps: 9 | Eps: 0.124
# Episode 417/1000 | Reward: 4.68 | Steps: 9 | Eps: 0.124
# Episode 418/1000 | Reward: 4.99 | Steps: 9 | Eps: 0.123
# Episode 419/1000 | Reward: 4.57 | Steps: 10 | Eps: 0.122
# Episode 420/1000 | Reward: 4.89 | Steps: 10 | Eps: 0.122
# Episode 421/1000 | Reward: 4.62 | Steps: 9 | Eps: 0.121
# Episode 422/1000 | Reward: 3.14 | Steps: 9 | Eps: 0.121
# Episode 423/1000 | Reward: 3.56 | Steps: 9 | Eps: 0.120
# Episode 424/1000 | Reward: 2.91 | Steps: 10 | Eps: 0.119
# Episode 425/1000 | Reward: 4.32 | Steps: 10 | Eps: 0.119
# Episode 426/1000 | Reward: 3.87 | Steps: 10 | Eps: 0.118
# Episode 427/1000 | Reward: 2.57 | Steps: 9 | Eps: 0.118
# Episode 428/1000 | Reward: 4.23 | Steps: 7 | Eps: 0.117
# Episode 429/1000 | Reward: 3.80 | Steps: 10 | Eps: 0.116
# Episode 430/1000 | Reward: 3.23 | Steps: 10 | Eps: 0.116
# Episode 431/1000 | Reward: -7.16 | Steps: 9 | Eps: 0.115
# Episode 432/1000 | Reward: 3.40 | Steps: 10 | Eps: 0.115
# Episode 433/1000 | Reward: 3.50 | Steps: 10 | Eps: 0.114
# Episode 434/1000 | Reward: 2.32 | Steps: 10 | Eps: 0.114
# Episode 435/1000 | Reward: 3.41 | Steps: 9 | Eps: 0.113
# Episode 436/1000 | Reward: 5.83 | Steps: 9 | Eps: 0.112
# Episode 437/1000 | Reward: 2.73 | Steps: 9 | Eps: 0.112
# Episode 438/1000 | Reward: 3.22 | Steps: 9 | Eps: 0.111
# Episode 439/1000 | Reward: -6.11 | Steps: 9 | Eps: 0.111
# Episode 440/1000 | Reward: -0.26 | Steps: 9 | Eps: 0.110
# Episode 441/1000 | Reward: 3.62 | Steps: 10 | Eps: 0.110
# Episode 442/1000 | Reward: 5.07 | Steps: 10 | Eps: 0.109
# Episode 443/1000 | Reward: 3.76 | Steps: 9 | Eps: 0.109
# Episode 444/1000 | Reward: 3.99 | Steps: 9 | Eps: 0.108
# Episode 445/1000 | Reward: 0.11 | Steps: 9 | Eps: 0.107
# Episode 446/1000 | Reward: 2.27 | Steps: 11 | Eps: 0.107
# Episode 447/1000 | Reward: 6.99 | Steps: 8 | Eps: 0.106
# Episode 448/1000 | Reward: 3.33 | Steps: 9 | Eps: 0.106
# Episode 449/1000 | Reward: -8.92 | Steps: 8 | Eps: 0.105
# Episode 450/1000 | Reward: 4.67 | Steps: 9 | Eps: 0.105
# Episode 451/1000 | Reward: 4.26 | Steps: 10 | Eps: 0.104
# Episode 452/1000 | Reward: 2.97 | Steps: 10 | Eps: 0.104
# Episode 453/1000 | Reward: 5.18 | Steps: 10 | Eps: 0.103
# Episode 454/1000 | Reward: 0.28 | Steps: 9 | Eps: 0.103
# Episode 455/1000 | Reward: 3.79 | Steps: 10 | Eps: 0.102
# Episode 456/1000 | Reward: 2.57 | Steps: 9 | Eps: 0.102
# Episode 457/1000 | Reward: 4.89 | Steps: 10 | Eps: 0.101
# Episode 458/1000 | Reward: 4.56 | Steps: 9 | Eps: 0.101
# Episode 459/1000 | Reward: 4.41 | Steps: 9 | Eps: 0.100
# Episode 460/1000 | Reward: 3.79 | Steps: 10 | Eps: 0.100
# Episode 461/1000 | Reward: 2.60 | Steps: 10 | Eps: 0.099
# Episode 462/1000 | Reward: 3.29 | Steps: 9 | Eps: 0.099
# Episode 463/1000 | Reward: 2.80 | Steps: 9 | Eps: 0.098
# Episode 464/1000 | Reward: 5.92 | Steps: 9 | Eps: 0.098
# Episode 465/1000 | Reward: 2.97 | Steps: 9 | Eps: 0.097
# Episode 466/1000 | Reward: 3.24 | Steps: 9 | Eps: 0.097
# Episode 467/1000 | Reward: 1.38 | Steps: 10 | Eps: 0.096
# Episode 468/1000 | Reward: 4.12 | Steps: 10 | Eps: 0.096
# Episode 469/1000 | Reward: 5.28 | Steps: 9 | Eps: 0.095
# Episode 470/1000 | Reward: 3.37 | Steps: 9 | Eps: 0.095
# Episode 471/1000 | Reward: 3.36 | Steps: 9 | Eps: 0.094
# Episode 472/1000 | Reward: 3.86 | Steps: 10 | Eps: 0.094
# Episode 473/1000 | Reward: 2.87 | Steps: 10 | Eps: 0.093
# Episode 474/1000 | Reward: 3.46 | Steps: 10 | Eps: 0.093
# Episode 475/1000 | Reward: 1.74 | Steps: 10 | Eps: 0.092
# Episode 476/1000 | Reward: 4.67 | Steps: 9 | Eps: 0.092
# Episode 477/1000 | Reward: 3.19 | Steps: 10 | Eps: 0.092
# Episode 478/1000 | Reward: -10.38 | Steps: 9 | Eps: 0.091
# Episode 479/1000 | Reward: 5.19 | Steps: 9 | Eps: 0.091
# Episode 480/1000 | Reward: 3.35 | Steps: 9 | Eps: 0.090
# Episode 481/1000 | Reward: 3.99 | Steps: 9 | Eps: 0.090
# Episode 482/1000 | Reward: 1.68 | Steps: 9 | Eps: 0.089
# Episode 483/1000 | Reward: 3.01 | Steps: 10 | Eps: 0.089
# Episode 484/1000 | Reward: 4.22 | Steps: 9 | Eps: 0.088
# Episode 485/1000 | Reward: 5.25 | Steps: 10 | Eps: 0.088
# Episode 486/1000 | Reward: 4.56 | Steps: 9 | Eps: 0.088
# Episode 487/1000 | Reward: 2.93 | Steps: 10 | Eps: 0.087
# Episode 488/1000 | Reward: 4.33 | Steps: 9 | Eps: 0.087
# Episode 489/1000 | Reward: 2.37 | Steps: 9 | Eps: 0.086
# Episode 490/1000 | Reward: 3.31 | Steps: 9 | Eps: 0.086
# Episode 491/1000 | Reward: 7.06 | Steps: 7 | Eps: 0.085
# Episode 492/1000 | Reward: -9.91 | Steps: 9 | Eps: 0.085
# Episode 493/1000 | Reward: 4.19 | Steps: 9 | Eps: 0.084
# Episode 494/1000 | Reward: 3.14 | Steps: 9 | Eps: 0.084
# Episode 495/1000 | Reward: 4.73 | Steps: 10 | Eps: 0.084
# Episode 496/1000 | Reward: 4.20 | Steps: 10 | Eps: 0.083
# Episode 497/1000 | Reward: 3.97 | Steps: 10 | Eps: 0.083
# Episode 498/1000 | Reward: 5.15 | Steps: 9 | Eps: 0.082
# Episode 499/1000 | Reward: 3.86 | Steps: 9 | Eps: 0.082
# Episode 500/1000 | Reward: 4.05 | Steps: 11 | Eps: 0.082
# Episode 501/1000 | Reward: 3.87 | Steps: 11 | Eps: 0.081
# Episode 502/1000 | Reward: 3.28 | Steps: 10 | Eps: 0.081
# Episode 503/1000 | Reward: 3.77 | Steps: 10 | Eps: 0.080
# Episode 504/1000 | Reward: 1.32 | Steps: 9 | Eps: 0.080
# Episode 505/1000 | Reward: -9.36 | Steps: 9 | Eps: 0.080
# Episode 506/1000 | Reward: -7.14 | Steps: 6 | Eps: 0.079
# Episode 507/1000 | Reward: 3.31 | Steps: 10 | Eps: 0.079
# Episode 508/1000 | Reward: 3.60 | Steps: 9 | Eps: 0.078
# Episode 509/1000 | Reward: 4.45 | Steps: 9 | Eps: 0.078
# Episode 510/1000 | Reward: 6.56 | Steps: 11 | Eps: 0.078
# Episode 511/1000 | Reward: 5.09 | Steps: 10 | Eps: 0.077
# Episode 512/1000 | Reward: 2.95 | Steps: 9 | Eps: 0.077
# Episode 513/1000 | Reward: 2.45 | Steps: 9 | Eps: 0.076
# Episode 514/1000 | Reward: 2.62 | Steps: 10 | Eps: 0.076
# Episode 515/1000 | Reward: 2.90 | Steps: 9 | Eps: 0.076
# Episode 516/1000 | Reward: 1.50 | Steps: 9 | Eps: 0.075
# Episode 517/1000 | Reward: 2.16 | Steps: 10 | Eps: 0.075
# Episode 518/1000 | Reward: 3.76 | Steps: 9 | Eps: 0.075
# Episode 519/1000 | Reward: 2.80 | Steps: 9 | Eps: 0.074
# Episode 520/1000 | Reward: 3.51 | Steps: 9 | Eps: 0.074
# Episode 521/1000 | Reward: 3.91 | Steps: 9 | Eps: 0.073
# Episode 522/1000 | Reward: 5.61 | Steps: 9 | Eps: 0.073
# Episode 523/1000 | Reward: 4.18 | Steps: 9 | Eps: 0.073
# Episode 524/1000 | Reward: 2.40 | Steps: 7 | Eps: 0.072
# Episode 525/1000 | Reward: 0.04 | Steps: 11 | Eps: 0.072
# Episode 526/1000 | Reward: 3.53 | Steps: 9 | Eps: 0.072
# Episode 527/1000 | Reward: 0.63 | Steps: 9 | Eps: 0.071
# Episode 528/1000 | Reward: 4.30 | Steps: 9 | Eps: 0.071
# Episode 529/1000 | Reward: 3.64 | Steps: 10 | Eps: 0.071
# Episode 530/1000 | Reward: 2.24 | Steps: 9 | Eps: 0.070
# Episode 531/1000 | Reward: 3.64 | Steps: 9 | Eps: 0.070
# Episode 532/1000 | Reward: 3.36 | Steps: 9 | Eps: 0.069
# Episode 533/1000 | Reward: 3.36 | Steps: 10 | Eps: 0.069
# Episode 534/1000 | Reward: 3.27 | Steps: 10 | Eps: 0.069
# Episode 535/1000 | Reward: -9.30 | Steps: 9 | Eps: 0.068
# Episode 536/1000 | Reward: 5.42 | Steps: 9 | Eps: 0.068
# Episode 537/1000 | Reward: -5.90 | Steps: 9 | Eps: 0.068
# Episode 538/1000 | Reward: 2.35 | Steps: 9 | Eps: 0.067
# Episode 539/1000 | Reward: 4.18 | Steps: 10 | Eps: 0.067
# Episode 540/1000 | Reward: 3.62 | Steps: 10 | Eps: 0.067
# Episode 541/1000 | Reward: 3.57 | Steps: 13 | Eps: 0.066
# Episode 542/1000 | Reward: 5.50 | Steps: 9 | Eps: 0.066
# Episode 543/1000 | Reward: 4.05 | Steps: 9 | Eps: 0.066
# Episode 544/1000 | Reward: 3.24 | Steps: 10 | Eps: 0.065
# Episode 545/1000 | Reward: 3.56 | Steps: 9 | Eps: 0.065
# Episode 546/1000 | Reward: 4.36 | Steps: 9 | Eps: 0.065
# Episode 547/1000 | Reward: 2.92 | Steps: 9 | Eps: 0.064
# Episode 548/1000 | Reward: 4.70 | Steps: 7 | Eps: 0.064
# Episode 549/1000 | Reward: 6.80 | Steps: 8 | Eps: 0.064
# Episode 550/1000 | Reward: 4.64 | Steps: 10 | Eps: 0.063
# Episode 551/1000 | Reward: 3.51 | Steps: 9 | Eps: 0.063
# Episode 552/1000 | Reward: 5.29 | Steps: 9 | Eps: 0.063
# Episode 553/1000 | Reward: 3.63 | Steps: 10 | Eps: 0.063
# Episode 554/1000 | Reward: 4.45 | Steps: 9 | Eps: 0.062
# Episode 555/1000 | Reward: 3.98 | Steps: 9 | Eps: 0.062
# Episode 556/1000 | Reward: 3.26 | Steps: 9 | Eps: 0.062
# Episode 557/1000 | Reward: 2.46 | Steps: 9 | Eps: 0.061
# Episode 558/1000 | Reward: 3.49 | Steps: 10 | Eps: 0.061
# Episode 559/1000 | Reward: -6.03 | Steps: 11 | Eps: 0.061
# Episode 560/1000 | Reward: 3.80 | Steps: 9 | Eps: 0.060
# Episode 561/1000 | Reward: 2.90 | Steps: 11 | Eps: 0.060
# Episode 562/1000 | Reward: 4.61 | Steps: 10 | Eps: 0.060
# Episode 563/1000 | Reward: 3.78 | Steps: 10 | Eps: 0.059
# Episode 564/1000 | Reward: 3.20 | Steps: 9 | Eps: 0.059
# Episode 565/1000 | Reward: 3.26 | Steps: 10 | Eps: 0.059
# Episode 566/1000 | Reward: 3.57 | Steps: 10 | Eps: 0.059
# Episode 567/1000 | Reward: 3.96 | Steps: 10 | Eps: 0.058
# Episode 568/1000 | Reward: 3.65 | Steps: 10 | Eps: 0.058
# Episode 569/1000 | Reward: 3.61 | Steps: 10 | Eps: 0.058
# Episode 570/1000 | Reward: 2.49 | Steps: 9 | Eps: 0.057
# Episode 571/1000 | Reward: 3.35 | Steps: 9 | Eps: 0.057
# Episode 572/1000 | Reward: 4.19 | Steps: 9 | Eps: 0.057
# Episode 573/1000 | Reward: 4.26 | Steps: 9 | Eps: 0.057
# Episode 574/1000 | Reward: 3.97 | Steps: 9 | Eps: 0.056
# Episode 575/1000 | Reward: 5.25 | Steps: 10 | Eps: 0.056
# Episode 576/1000 | Reward: -6.42 | Steps: 9 | Eps: 0.056
# Episode 577/1000 | Reward: 4.98 | Steps: 10 | Eps: 0.055
# Episode 578/1000 | Reward: -5.72 | Steps: 10 | Eps: 0.055
# Episode 579/1000 | Reward: 2.55 | Steps: 9 | Eps: 0.055
# Episode 580/1000 | Reward: 4.90 | Steps: 9 | Eps: 0.055
# Episode 581/1000 | Reward: 4.44 | Steps: 9 | Eps: 0.054
# Episode 582/1000 | Reward: -7.33 | Steps: 10 | Eps: 0.054
# Episode 583/1000 | Reward: 3.12 | Steps: 9 | Eps: 0.054
# Episode 584/1000 | Reward: 3.62 | Steps: 9 | Eps: 0.054
# Episode 585/1000 | Reward: 4.62 | Steps: 9 | Eps: 0.053
# Episode 586/1000 | Reward: 4.45 | Steps: 10 | Eps: 0.053
# Episode 587/1000 | Reward: 6.10 | Steps: 9 | Eps: 0.053
# Episode 588/1000 | Reward: 2.34 | Steps: 9 | Eps: 0.052
# Episode 589/1000 | Reward: 4.46 | Steps: 8 | Eps: 0.052
# Episode 590/1000 | Reward: 3.06 | Steps: 11 | Eps: 0.052
# Episode 591/1000 | Reward: 2.62 | Steps: 9 | Eps: 0.052
# Episode 592/1000 | Reward: 5.47 | Steps: 12 | Eps: 0.051
# Episode 593/1000 | Reward: 3.08 | Steps: 10 | Eps: 0.051
# Episode 594/1000 | Reward: 3.47 | Steps: 12 | Eps: 0.051
# Episode 595/1000 | Reward: 3.43 | Steps: 9 | Eps: 0.051
# Episode 596/1000 | Reward: 0.84 | Steps: 9 | Eps: 0.050
# Episode 597/1000 | Reward: 3.57 | Steps: 9 | Eps: 0.050
# Episode 598/1000 | Reward: 4.32 | Steps: 10 | Eps: 0.050
# Episode 599/1000 | Reward: 3.35 | Steps: 10 | Eps: 0.050
# Episode 600/1000 | Reward: 3.15 | Steps: 10 | Eps: 0.049
# Episode 601/1000 | Reward: 4.23 | Steps: 9 | Eps: 0.049
# Episode 602/1000 | Reward: 3.28 | Steps: 9 | Eps: 0.049
# Episode 603/1000 | Reward: 3.65 | Steps: 10 | Eps: 0.049
# Episode 604/1000 | Reward: 3.04 | Steps: 10 | Eps: 0.048
# Episode 605/1000 | Reward: 2.46 | Steps: 9 | Eps: 0.048
# Episode 606/1000 | Reward: 2.69 | Steps: 10 | Eps: 0.048
# Episode 607/1000 | Reward: 4.47 | Steps: 9 | Eps: 0.048
# Episode 608/1000 | Reward: 3.95 | Steps: 9 | Eps: 0.047
# Episode 609/1000 | Reward: 4.39 | Steps: 9 | Eps: 0.047
# Episode 610/1000 | Reward: 3.69 | Steps: 9 | Eps: 0.047
# Episode 611/1000 | Reward: 4.20 | Steps: 10 | Eps: 0.047
# Episode 612/1000 | Reward: 6.39 | Steps: 8 | Eps: 0.047
# Episode 613/1000 | Reward: -8.67 | Steps: 6 | Eps: 0.046
# Episode 614/1000 | Reward: 4.20 | Steps: 10 | Eps: 0.046
# Episode 615/1000 | Reward: 3.19 | Steps: 9 | Eps: 0.046
# Episode 616/1000 | Reward: -7.59 | Steps: 9 | Eps: 0.046
# Episode 617/1000 | Reward: 3.43 | Steps: 9 | Eps: 0.045
# Episode 618/1000 | Reward: 3.94 | Steps: 10 | Eps: 0.045
# Episode 619/1000 | Reward: -0.75 | Steps: 9 | Eps: 0.045
# Episode 620/1000 | Reward: 3.97 | Steps: 8 | Eps: 0.045
# Episode 621/1000 | Reward: 0.85 | Steps: 9 | Eps: 0.044
# Episode 622/1000 | Reward: 2.67 | Steps: 10 | Eps: 0.044
# Episode 623/1000 | Reward: 3.93 | Steps: 10 | Eps: 0.044
# Episode 624/1000 | Reward: 2.61 | Steps: 9 | Eps: 0.044
# Episode 625/1000 | Reward: 4.49 | Steps: 10 | Eps: 0.044
# Episode 626/1000 | Reward: 3.89 | Steps: 9 | Eps: 0.043
# Episode 627/1000 | Reward: 4.21 | Steps: 9 | Eps: 0.043
# Episode 628/1000 | Reward: 5.78 | Steps: 10 | Eps: 0.043
# Episode 629/1000 | Reward: 3.91 | Steps: 10 | Eps: 0.043
# Episode 630/1000 | Reward: 2.60 | Steps: 10 | Eps: 0.043
# Episode 631/1000 | Reward: 4.99 | Steps: 9 | Eps: 0.042
# Episode 632/1000 | Reward: 4.62 | Steps: 9 | Eps: 0.042
# Episode 633/1000 | Reward: 3.75 | Steps: 9 | Eps: 0.042
# Episode 634/1000 | Reward: 4.52 | Steps: 9 | Eps: 0.042
# Episode 635/1000 | Reward: 3.55 | Steps: 10 | Eps: 0.041
# Episode 636/1000 | Reward: 3.88 | Steps: 10 | Eps: 0.041
# Episode 637/1000 | Reward: 2.35 | Steps: 8 | Eps: 0.041
# Episode 638/1000 | Reward: 4.75 | Steps: 10 | Eps: 0.041
# Episode 639/1000 | Reward: 4.03 | Steps: 10 | Eps: 0.041
# Episode 640/1000 | Reward: 4.38 | Steps: 9 | Eps: 0.040
# Episode 641/1000 | Reward: 5.74 | Steps: 9 | Eps: 0.040
# Episode 642/1000 | Reward: 4.02 | Steps: 9 | Eps: 0.040
# Episode 643/1000 | Reward: 4.00 | Steps: 9 | Eps: 0.040
# Episode 644/1000 | Reward: 3.60 | Steps: 9 | Eps: 0.040
# Episode 645/1000 | Reward: 2.90 | Steps: 9 | Eps: 0.039
# Episode 646/1000 | Reward: 4.93 | Steps: 6 | Eps: 0.039
# Episode 647/1000 | Reward: 3.52 | Steps: 9 | Eps: 0.039
# Episode 648/1000 | Reward: 3.53 | Steps: 10 | Eps: 0.039
# Episode 649/1000 | Reward: 4.47 | Steps: 9 | Eps: 0.039
# Episode 650/1000 | Reward: 3.59 | Steps: 10 | Eps: 0.038
# Episode 651/1000 | Reward: 3.97 | Steps: 10 | Eps: 0.038
# Episode 652/1000 | Reward: 3.75 | Steps: 9 | Eps: 0.038
# Episode 653/1000 | Reward: 4.11 | Steps: 9 | Eps: 0.038
# Episode 654/1000 | Reward: 3.69 | Steps: 9 | Eps: 0.038
# Episode 655/1000 | Reward: 6.18 | Steps: 10 | Eps: 0.038
# Episode 656/1000 | Reward: 2.53 | Steps: 9 | Eps: 0.037
# Episode 657/1000 | Reward: -5.76 | Steps: 10 | Eps: 0.037
# Episode 658/1000 | Reward: 1.59 | Steps: 10 | Eps: 0.037
# Episode 659/1000 | Reward: 4.19 | Steps: 9 | Eps: 0.037
# Episode 660/1000 | Reward: -8.91 | Steps: 12 | Eps: 0.037
# Episode 661/1000 | Reward: 4.02 | Steps: 8 | Eps: 0.036
# Episode 662/1000 | Reward: 3.54 | Steps: 11 | Eps: 0.036
# Episode 663/1000 | Reward: 3.84 | Steps: 9 | Eps: 0.036
# Episode 664/1000 | Reward: 3.00 | Steps: 10 | Eps: 0.036
# Episode 665/1000 | Reward: 3.16 | Steps: 10 | Eps: 0.036
# Episode 666/1000 | Reward: -13.07 | Steps: 10 | Eps: 0.035
# Episode 667/1000 | Reward: -5.43 | Steps: 11 | Eps: 0.035
# Episode 668/1000 | Reward: 4.52 | Steps: 8 | Eps: 0.035
# Episode 669/1000 | Reward: -8.57 | Steps: 9 | Eps: 0.035
# Episode 670/1000 | Reward: 4.11 | Steps: 10 | Eps: 0.035
# Episode 671/1000 | Reward: 4.00 | Steps: 8 | Eps: 0.035
# Episode 672/1000 | Reward: 1.12 | Steps: 12 | Eps: 0.034
# Episode 673/1000 | Reward: 5.02 | Steps: 9 | Eps: 0.034
# Episode 674/1000 | Reward: 3.37 | Steps: 10 | Eps: 0.034
# Episode 675/1000 | Reward: 1.25 | Steps: 10 | Eps: 0.034
# Episode 676/1000 | Reward: 2.48 | Steps: 9 | Eps: 0.034
# Episode 677/1000 | Reward: 2.93 | Steps: 9 | Eps: 0.034
# Episode 678/1000 | Reward: 3.90 | Steps: 9 | Eps: 0.033
# Episode 679/1000 | Reward: 1.96 | Steps: 9 | Eps: 0.033
# Episode 680/1000 | Reward: 3.49 | Steps: 9 | Eps: 0.033
# Episode 681/1000 | Reward: 2.76 | Steps: 9 | Eps: 0.033
# Episode 682/1000 | Reward: 4.35 | Steps: 9 | Eps: 0.033
# Episode 683/1000 | Reward: 4.68 | Steps: 9 | Eps: 0.033
# Episode 684/1000 | Reward: 4.42 | Steps: 10 | Eps: 0.032
# Episode 685/1000 | Reward: 4.80 | Steps: 9 | Eps: 0.032
# Episode 686/1000 | Reward: 3.34 | Steps: 9 | Eps: 0.032
# Episode 687/1000 | Reward: 3.09 | Steps: 10 | Eps: 0.032
# Episode 688/1000 | Reward: 2.35 | Steps: 10 | Eps: 0.032
# Episode 689/1000 | Reward: 2.82 | Steps: 10 | Eps: 0.032
# Episode 690/1000 | Reward: 3.49 | Steps: 9 | Eps: 0.031
# Episode 691/1000 | Reward: 3.39 | Steps: 10 | Eps: 0.031
# Episode 692/1000 | Reward: 2.66 | Steps: 9 | Eps: 0.031
# Episode 693/1000 | Reward: 4.07 | Steps: 9 | Eps: 0.031
# Episode 694/1000 | Reward: 4.49 | Steps: 9 | Eps: 0.031
# Episode 695/1000 | Reward: 4.61 | Steps: 10 | Eps: 0.031
# Episode 696/1000 | Reward: 4.07 | Steps: 10 | Eps: 0.031
# Episode 697/1000 | Reward: 4.03 | Steps: 9 | Eps: 0.030
# Episode 698/1000 | Reward: 2.90 | Steps: 9 | Eps: 0.030
# Episode 699/1000 | Reward: -7.49 | Steps: 9 | Eps: 0.030
# Episode 700/1000 | Reward: 3.88 | Steps: 9 | Eps: 0.030
# Episode 701/1000 | Reward: 7.30 | Steps: 9 | Eps: 0.030
# Episode 702/1000 | Reward: 5.56 | Steps: 12 | Eps: 0.030
# Episode 703/1000 | Reward: 3.56 | Steps: 9 | Eps: 0.029
# Episode 704/1000 | Reward: 4.89 | Steps: 7 | Eps: 0.029
# Episode 705/1000 | Reward: -10.83 | Steps: 9 | Eps: 0.029
# Episode 706/1000 | Reward: 3.93 | Steps: 10 | Eps: 0.029
# Episode 707/1000 | Reward: 5.69 | Steps: 9 | Eps: 0.029
# Episode 708/1000 | Reward: 0.29 | Steps: 9 | Eps: 0.029
# Episode 709/1000 | Reward: 2.74 | Steps: 10 | Eps: 0.029
# Episode 710/1000 | Reward: 4.45 | Steps: 10 | Eps: 0.028
# Episode 711/1000 | Reward: 3.39 | Steps: 9 | Eps: 0.028
# Episode 712/1000 | Reward: 4.39 | Steps: 10 | Eps: 0.028
# Episode 713/1000 | Reward: 3.91 | Steps: 9 | Eps: 0.028
# Episode 714/1000 | Reward: 4.25 | Steps: 9 | Eps: 0.028
# Episode 715/1000 | Reward: 5.35 | Steps: 9 | Eps: 0.028
# Episode 716/1000 | Reward: 1.73 | Steps: 9 | Eps: 0.028
# Episode 717/1000 | Reward: 4.19 | Steps: 10 | Eps: 0.027
# Episode 718/1000 | Reward: 3.81 | Steps: 9 | Eps: 0.027
# Episode 719/1000 | Reward: 2.82 | Steps: 10 | Eps: 0.027
# Episode 720/1000 | Reward: 3.13 | Steps: 10 | Eps: 0.027
# Episode 721/1000 | Reward: 4.59 | Steps: 10 | Eps: 0.027
# Episode 722/1000 | Reward: 2.86 | Steps: 8 | Eps: 0.027
# Episode 723/1000 | Reward: 3.41 | Steps: 11 | Eps: 0.027
# Episode 724/1000 | Reward: 3.40 | Steps: 9 | Eps: 0.027
# Episode 725/1000 | Reward: 5.04 | Steps: 10 | Eps: 0.026
# Episode 726/1000 | Reward: 5.16 | Steps: 8 | Eps: 0.026
# Episode 727/1000 | Reward: 3.45 | Steps: 10 | Eps: 0.026
# Episode 728/1000 | Reward: 5.36 | Steps: 10 | Eps: 0.026
# Episode 729/1000 | Reward: 2.18 | Steps: 10 | Eps: 0.026
# Episode 730/1000 | Reward: 3.81 | Steps: 9 | Eps: 0.026
# Episode 731/1000 | Reward: 3.66 | Steps: 10 | Eps: 0.026
# Episode 732/1000 | Reward: 2.53 | Steps: 10 | Eps: 0.025
# Episode 733/1000 | Reward: 5.41 | Steps: 7 | Eps: 0.025
# Episode 734/1000 | Reward: 3.31 | Steps: 10 | Eps: 0.025
# Episode 735/1000 | Reward: 5.17 | Steps: 10 | Eps: 0.025
# Episode 736/1000 | Reward: -7.88 | Steps: 9 | Eps: 0.025
# Episode 737/1000 | Reward: 3.24 | Steps: 9 | Eps: 0.025
# Episode 738/1000 | Reward: -8.90 | Steps: 8 | Eps: 0.025
# Episode 739/1000 | Reward: 5.57 | Steps: 7 | Eps: 0.025
# Episode 740/1000 | Reward: -5.72 | Steps: 7 | Eps: 0.024
# Episode 741/1000 | Reward: 4.37 | Steps: 7 | Eps: 0.024
# Episode 742/1000 | Reward: 4.08 | Steps: 10 | Eps: 0.024
# Episode 743/1000 | Reward: 2.53 | Steps: 9 | Eps: 0.024
# Episode 744/1000 | Reward: 2.55 | Steps: 9 | Eps: 0.024
# Episode 745/1000 | Reward: 4.07 | Steps: 9 | Eps: 0.024
# Episode 746/1000 | Reward: 4.48 | Steps: 7 | Eps: 0.024
# Episode 747/1000 | Reward: 3.92 | Steps: 8 | Eps: 0.024
# Episode 748/1000 | Reward: 3.13 | Steps: 7 | Eps: 0.024
# Episode 749/1000 | Reward: 4.59 | Steps: 10 | Eps: 0.023
# Episode 750/1000 | Reward: 5.48 | Steps: 9 | Eps: 0.023
# Episode 751/1000 | Reward: 1.71 | Steps: 10 | Eps: 0.023
# Episode 752/1000 | Reward: 2.72 | Steps: 10 | Eps: 0.023
# Episode 753/1000 | Reward: 3.11 | Steps: 9 | Eps: 0.023
# Episode 754/1000 | Reward: 2.89 | Steps: 9 | Eps: 0.023
# Episode 755/1000 | Reward: 4.66 | Steps: 10 | Eps: 0.023
# Episode 756/1000 | Reward: 4.31 | Steps: 9 | Eps: 0.023
# Episode 757/1000 | Reward: -4.79 | Steps: 10 | Eps: 0.022
# Episode 758/1000 | Reward: -6.62 | Steps: 10 | Eps: 0.022
# Episode 759/1000 | Reward: 1.69 | Steps: 9 | Eps: 0.022
# Episode 760/1000 | Reward: 4.34 | Steps: 10 | Eps: 0.022
# Episode 761/1000 | Reward: 3.54 | Steps: 9 | Eps: 0.022
# Episode 762/1000 | Reward: 4.90 | Steps: 9 | Eps: 0.022
# Episode 763/1000 | Reward: 3.87 | Steps: 9 | Eps: 0.022
# Episode 764/1000 | Reward: 3.67 | Steps: 9 | Eps: 0.022
# Episode 765/1000 | Reward: 3.84 | Steps: 8 | Eps: 0.022
# Episode 766/1000 | Reward: -9.09 | Steps: 9 | Eps: 0.022
# Episode 767/1000 | Reward: 4.16 | Steps: 6 | Eps: 0.021
# Episode 768/1000 | Reward: 2.83 | Steps: 9 | Eps: 0.021
# Episode 769/1000 | Reward: 4.01 | Steps: 6 | Eps: 0.021
# Episode 770/1000 | Reward: 3.43 | Steps: 8 | Eps: 0.021
# Episode 771/1000 | Reward: 1.53 | Steps: 10 | Eps: 0.021
# Episode 772/1000 | Reward: 3.25 | Steps: 9 | Eps: 0.021
# Episode 773/1000 | Reward: 2.64 | Steps: 10 | Eps: 0.021
# Episode 774/1000 | Reward: 5.41 | Steps: 9 | Eps: 0.021
# Episode 775/1000 | Reward: -6.32 | Steps: 9 | Eps: 0.021
# Episode 776/1000 | Reward: 3.33 | Steps: 10 | Eps: 0.020
# Episode 777/1000 | Reward: 2.60 | Steps: 9 | Eps: 0.020
# Episode 778/1000 | Reward: 3.77 | Steps: 10 | Eps: 0.020
# Episode 779/1000 | Reward: 2.55 | Steps: 10 | Eps: 0.020
# Episode 780/1000 | Reward: 3.92 | Steps: 9 | Eps: 0.020
# Episode 781/1000 | Reward: 3.51 | Steps: 9 | Eps: 0.020
# Episode 782/1000 | Reward: 3.58 | Steps: 9 | Eps: 0.020
# Episode 783/1000 | Reward: -11.44 | Steps: 9 | Eps: 0.020
# Episode 784/1000 | Reward: 8.37 | Steps: 10 | Eps: 0.020
# Episode 785/1000 | Reward: 3.68 | Steps: 9 | Eps: 0.020
# Episode 786/1000 | Reward: 3.90 | Steps: 9 | Eps: 0.019
# Episode 787/1000 | Reward: 4.29 | Steps: 9 | Eps: 0.019
# Episode 788/1000 | Reward: 3.92 | Steps: 9 | Eps: 0.019
# Episode 789/1000 | Reward: 3.47 | Steps: 9 | Eps: 0.019
# Episode 790/1000 | Reward: 2.35 | Steps: 9 | Eps: 0.019
# Episode 791/1000 | Reward: 3.69 | Steps: 7 | Eps: 0.019
# Episode 792/1000 | Reward: 3.08 | Steps: 10 | Eps: 0.019
# Episode 793/1000 | Reward: 5.03 | Steps: 9 | Eps: 0.019
# Episode 794/1000 | Reward: 2.62 | Steps: 9 | Eps: 0.019
# Episode 795/1000 | Reward: 2.10 | Steps: 9 | Eps: 0.019
# Episode 796/1000 | Reward: 2.39 | Steps: 10 | Eps: 0.019
# Episode 797/1000 | Reward: 1.61 | Steps: 10 | Eps: 0.018
# Episode 798/1000 | Reward: 2.75 | Steps: 10 | Eps: 0.018
# Episode 799/1000 | Reward: 2.64 | Steps: 8 | Eps: 0.018
# Episode 800/1000 | Reward: 3.77 | Steps: 9 | Eps: 0.018
# Episode 801/1000 | Reward: 4.62 | Steps: 9 | Eps: 0.018
# Episode 802/1000 | Reward: 1.60 | Steps: 9 | Eps: 0.018
# Episode 803/1000 | Reward: 3.74 | Steps: 9 | Eps: 0.018
# Episode 804/1000 | Reward: 3.63 | Steps: 9 | Eps: 0.018
# Episode 805/1000 | Reward: 3.18 | Steps: 9 | Eps: 0.018
# Episode 806/1000 | Reward: 3.43 | Steps: 9 | Eps: 0.018
# Episode 807/1000 | Reward: 4.79 | Steps: 10 | Eps: 0.018
# Episode 808/1000 | Reward: 5.23 | Steps: 8 | Eps: 0.017
# Episode 809/1000 | Reward: 3.36 | Steps: 10 | Eps: 0.017
# Episode 810/1000 | Reward: 3.59 | Steps: 10 | Eps: 0.017
# Episode 811/1000 | Reward: 3.89 | Steps: 9 | Eps: 0.017
# Episode 812/1000 | Reward: 3.39 | Steps: 9 | Eps: 0.017
# Episode 813/1000 | Reward: 4.60 | Steps: 10 | Eps: 0.017
# Episode 814/1000 | Reward: 4.60 | Steps: 9 | Eps: 0.017
# Episode 815/1000 | Reward: 5.83 | Steps: 9 | Eps: 0.017
# Episode 816/1000 | Reward: 3.21 | Steps: 10 | Eps: 0.017
# Episode 817/1000 | Reward: 5.06 | Steps: 10 | Eps: 0.017
# Episode 818/1000 | Reward: 3.26 | Steps: 10 | Eps: 0.017
# Episode 819/1000 | Reward: -6.34 | Steps: 9 | Eps: 0.016
# Episode 820/1000 | Reward: 3.52 | Steps: 9 | Eps: 0.016
# Episode 821/1000 | Reward: 2.07 | Steps: 9 | Eps: 0.016
# Episode 822/1000 | Reward: 4.13 | Steps: 10 | Eps: 0.016
# Episode 823/1000 | Reward: 5.07 | Steps: 9 | Eps: 0.016
# Episode 824/1000 | Reward: 3.73 | Steps: 9 | Eps: 0.016
# Episode 825/1000 | Reward: 4.46 | Steps: 9 | Eps: 0.016
# Episode 826/1000 | Reward: 3.71 | Steps: 10 | Eps: 0.016
# Episode 827/1000 | Reward: 3.50 | Steps: 9 | Eps: 0.016
# Episode 828/1000 | Reward: 4.30 | Steps: 9 | Eps: 0.016
# Episode 829/1000 | Reward: 3.43 | Steps: 10 | Eps: 0.016
# Episode 830/1000 | Reward: 3.09 | Steps: 9 | Eps: 0.016
# Episode 831/1000 | Reward: 4.25 | Steps: 10 | Eps: 0.016
# Episode 832/1000 | Reward: 2.27 | Steps: 9 | Eps: 0.015
# Episode 833/1000 | Reward: 3.99 | Steps: 9 | Eps: 0.015
# Episode 834/1000 | Reward: 3.42 | Steps: 10 | Eps: 0.015
# Episode 835/1000 | Reward: 3.51 | Steps: 10 | Eps: 0.015
# Episode 836/1000 | Reward: 2.85 | Steps: 10 | Eps: 0.015
# Episode 837/1000 | Reward: 2.91 | Steps: 9 | Eps: 0.015
# Episode 838/1000 | Reward: 4.59 | Steps: 9 | Eps: 0.015
# Episode 839/1000 | Reward: 4.64 | Steps: 9 | Eps: 0.015
# Episode 840/1000 | Reward: 3.80 | Steps: 9 | Eps: 0.015
# Episode 841/1000 | Reward: 5.23 | Steps: 9 | Eps: 0.015
# Episode 842/1000 | Reward: 5.10 | Steps: 10 | Eps: 0.015
# Episode 843/1000 | Reward: 4.30 | Steps: 10 | Eps: 0.015
# Episode 844/1000 | Reward: 3.82 | Steps: 9 | Eps: 0.015
# Episode 845/1000 | Reward: 2.99 | Steps: 10 | Eps: 0.014
# Episode 846/1000 | Reward: 6.01 | Steps: 10 | Eps: 0.014
# Episode 847/1000 | Reward: -9.87 | Steps: 11 | Eps: 0.014
# Episode 848/1000 | Reward: 4.38 | Steps: 11 | Eps: 0.014
# Episode 849/1000 | Reward: 4.29 | Steps: 9 | Eps: 0.014
# Episode 850/1000 | Reward: 2.29 | Steps: 10 | Eps: 0.014
# Episode 851/1000 | Reward: 2.67 | Steps: 10 | Eps: 0.014
# Episode 852/1000 | Reward: 4.05 | Steps: 8 | Eps: 0.014
# Episode 853/1000 | Reward: 3.21 | Steps: 9 | Eps: 0.014
# Episode 854/1000 | Reward: 2.29 | Steps: 9 | Eps: 0.014
# Episode 855/1000 | Reward: 4.06 | Steps: 10 | Eps: 0.014
# Episode 856/1000 | Reward: 3.58 | Steps: 9 | Eps: 0.014
# Episode 857/1000 | Reward: 4.09 | Steps: 9 | Eps: 0.014
# Episode 858/1000 | Reward: 4.52 | Steps: 9 | Eps: 0.014
# Episode 859/1000 | Reward: 3.16 | Steps: 9 | Eps: 0.013
# Episode 860/1000 | Reward: -6.02 | Steps: 9 | Eps: 0.013
# Episode 861/1000 | Reward: 2.30 | Steps: 9 | Eps: 0.013
# Episode 862/1000 | Reward: 3.01 | Steps: 10 | Eps: 0.013
# Episode 863/1000 | Reward: 2.60 | Steps: 10 | Eps: 0.013
# Episode 864/1000 | Reward: 5.34 | Steps: 8 | Eps: 0.013
# Episode 865/1000 | Reward: 1.97 | Steps: 9 | Eps: 0.013
# Episode 866/1000 | Reward: -1.03 | Steps: 13 | Eps: 0.013
# Episode 867/1000 | Reward: -11.15 | Steps: 9 | Eps: 0.013
# Episode 868/1000 | Reward: 4.85 | Steps: 9 | Eps: 0.013
# Episode 869/1000 | Reward: -8.50 | Steps: 10 | Eps: 0.013
# Episode 870/1000 | Reward: 4.59 | Steps: 9 | Eps: 0.013
# Episode 871/1000 | Reward: 3.11 | Steps: 9 | Eps: 0.013
# Episode 872/1000 | Reward: 2.49 | Steps: 10 | Eps: 0.013
# Episode 873/1000 | Reward: 4.97 | Steps: 10 | Eps: 0.013
# Episode 874/1000 | Reward: 4.82 | Steps: 9 | Eps: 0.013
# Episode 875/1000 | Reward: 2.38 | Steps: 10 | Eps: 0.012
# Episode 876/1000 | Reward: 4.06 | Steps: 6 | Eps: 0.012
# Episode 877/1000 | Reward: 2.40 | Steps: 8 | Eps: 0.012
# Episode 878/1000 | Reward: 2.91 | Steps: 9 | Eps: 0.012
# Episode 879/1000 | Reward: 3.86 | Steps: 10 | Eps: 0.012
# Episode 880/1000 | Reward: -6.27 | Steps: 10 | Eps: 0.012
# Episode 881/1000 | Reward: -8.13 | Steps: 10 | Eps: 0.012
# Episode 882/1000 | Reward: 2.42 | Steps: 9 | Eps: 0.012
# Episode 883/1000 | Reward: 2.27 | Steps: 9 | Eps: 0.012
# Episode 884/1000 | Reward: 2.66 | Steps: 9 | Eps: 0.012
# Episode 885/1000 | Reward: 9.49 | Steps: 7 | Eps: 0.012
# Episode 886/1000 | Reward: 1.88 | Steps: 9 | Eps: 0.012
# Episode 887/1000 | Reward: 7.62 | Steps: 9 | Eps: 0.012
# Episode 888/1000 | Reward: 3.22 | Steps: 10 | Eps: 0.012
# Episode 889/1000 | Reward: 1.44 | Steps: 9 | Eps: 0.012
# Episode 890/1000 | Reward: 4.47 | Steps: 7 | Eps: 0.012
# Episode 891/1000 | Reward: 2.77 | Steps: 10 | Eps: 0.011
# Episode 892/1000 | Reward: 3.84 | Steps: 10 | Eps: 0.011
# Episode 893/1000 | Reward: 3.21 | Steps: 9 | Eps: 0.011
# Episode 894/1000 | Reward: 2.14 | Steps: 9 | Eps: 0.011
# Episode 895/1000 | Reward: 0.39 | Steps: 9 | Eps: 0.011
# Episode 896/1000 | Reward: 1.89 | Steps: 9 | Eps: 0.011
# Episode 897/1000 | Reward: 2.97 | Steps: 9 | Eps: 0.011
# Episode 898/1000 | Reward: 4.53 | Steps: 7 | Eps: 0.011
# Episode 899/1000 | Reward: 2.37 | Steps: 10 | Eps: 0.011
# Episode 900/1000 | Reward: 3.76 | Steps: 9 | Eps: 0.011
# Episode 901/1000 | Reward: -6.98 | Steps: 9 | Eps: 0.011
# Episode 902/1000 | Reward: 2.43 | Steps: 10 | Eps: 0.011
# Episode 903/1000 | Reward: 5.25 | Steps: 10 | Eps: 0.011
# Episode 904/1000 | Reward: 2.68 | Steps: 9 | Eps: 0.011
# Episode 905/1000 | Reward: 3.63 | Steps: 9 | Eps: 0.011
# Episode 906/1000 | Reward: 3.00 | Steps: 10 | Eps: 0.011
# Episode 907/1000 | Reward: 2.06 | Steps: 9 | Eps: 0.011
# Episode 908/1000 | Reward: 4.38 | Steps: 8 | Eps: 0.011
# Episode 909/1000 | Reward: 3.41 | Steps: 12 | Eps: 0.010
# Episode 910/1000 | Reward: 3.21 | Steps: 9 | Eps: 0.010
# Episode 911/1000 | Reward: 4.55 | Steps: 9 | Eps: 0.010
# Episode 912/1000 | Reward: 3.66 | Steps: 8 | Eps: 0.010
# Episode 913/1000 | Reward: 3.85 | Steps: 10 | Eps: 0.010
# Episode 914/1000 | Reward: 2.93 | Steps: 10 | Eps: 0.010
# Episode 915/1000 | Reward: 3.02 | Steps: 9 | Eps: 0.010
# Episode 916/1000 | Reward: 2.92 | Steps: 10 | Eps: 0.010
# Episode 917/1000 | Reward: 4.45 | Steps: 9 | Eps: 0.010
# Episode 918/1000 | Reward: 4.45 | Steps: 9 | Eps: 0.010
# Episode 919/1000 | Reward: 3.18 | Steps: 10 | Eps: 0.010
# Episode 920/1000 | Reward: 4.72 | Steps: 10 | Eps: 0.010
# Episode 921/1000 | Reward: 4.22 | Steps: 8 | Eps: 0.010
# Episode 922/1000 | Reward: -6.18 | Steps: 8 | Eps: 0.010
# Episode 923/1000 | Reward: 4.90 | Steps: 9 | Eps: 0.010
# Episode 924/1000 | Reward: 2.74 | Steps: 9 | Eps: 0.010
# Episode 925/1000 | Reward: 2.74 | Steps: 10 | Eps: 0.010
# Episode 926/1000 | Reward: 3.08 | Steps: 9 | Eps: 0.010
# Episode 927/1000 | Reward: 3.12 | Steps: 10 | Eps: 0.010
# Episode 928/1000 | Reward: 4.05 | Steps: 10 | Eps: 0.010
# Episode 929/1000 | Reward: 4.45 | Steps: 9 | Eps: 0.009
# Episode 930/1000 | Reward: 2.24 | Steps: 10 | Eps: 0.009
# Episode 931/1000 | Reward: 3.89 | Steps: 10 | Eps: 0.009
# Episode 932/1000 | Reward: 3.80 | Steps: 10 | Eps: 0.009
# Episode 933/1000 | Reward: 5.95 | Steps: 10 | Eps: 0.009
# Episode 934/1000 | Reward: 1.95 | Steps: 9 | Eps: 0.009
# Episode 935/1000 | Reward: 4.73 | Steps: 9 | Eps: 0.009
# Episode 936/1000 | Reward: 4.32 | Steps: 9 | Eps: 0.009
# Episode 937/1000 | Reward: 2.20 | Steps: 9 | Eps: 0.009
# Episode 938/1000 | Reward: 2.31 | Steps: 10 | Eps: 0.009
# Episode 939/1000 | Reward: 4.21 | Steps: 9 | Eps: 0.009
# Episode 940/1000 | Reward: -9.24 | Steps: 9 | Eps: 0.009
# Episode 941/1000 | Reward: 3.75 | Steps: 10 | Eps: 0.009
# Episode 942/1000 | Reward: 3.55 | Steps: 10 | Eps: 0.009
# Episode 943/1000 | Reward: 3.75 | Steps: 10 | Eps: 0.009
# Episode 944/1000 | Reward: 4.27 | Steps: 9 | Eps: 0.009
# Episode 945/1000 | Reward: 4.39 | Steps: 10 | Eps: 0.009
# Episode 946/1000 | Reward: 4.13 | Steps: 9 | Eps: 0.009
# Episode 947/1000 | Reward: 2.42 | Steps: 10 | Eps: 0.009
# Episode 948/1000 | Reward: 3.37 | Steps: 9 | Eps: 0.009
# Episode 949/1000 | Reward: 3.57 | Steps: 9 | Eps: 0.009
# Episode 950/1000 | Reward: -7.84 | Steps: 6 | Eps: 0.009
# Episode 951/1000 | Reward: 3.95 | Steps: 7 | Eps: 0.009
# Episode 952/1000 | Reward: 3.96 | Steps: 6 | Eps: 0.008
# Episode 953/1000 | Reward: 4.57 | Steps: 7 | Eps: 0.008
# Episode 954/1000 | Reward: 3.41 | Steps: 10 | Eps: 0.008
# Episode 955/1000 | Reward: 2.01 | Steps: 9 | Eps: 0.008
# Episode 956/1000 | Reward: 3.63 | Steps: 8 | Eps: 0.008
# Episode 957/1000 | Reward: 4.00 | Steps: 9 | Eps: 0.008
# Episode 958/1000 | Reward: 3.68 | Steps: 10 | Eps: 0.008
# Episode 959/1000 | Reward: 3.78 | Steps: 10 | Eps: 0.008
# Episode 960/1000 | Reward: 4.92 | Steps: 10 | Eps: 0.008
# Episode 961/1000 | Reward: 2.49 | Steps: 10 | Eps: 0.008
# Episode 962/1000 | Reward: 4.92 | Steps: 9 | Eps: 0.008
# Episode 963/1000 | Reward: 3.51 | Steps: 9 | Eps: 0.008
# Episode 964/1000 | Reward: 3.55 | Steps: 7 | Eps: 0.008
# Episode 965/1000 | Reward: 3.11 | Steps: 9 | Eps: 0.008
# Episode 966/1000 | Reward: 2.23 | Steps: 9 | Eps: 0.008
# Episode 967/1000 | Reward: 3.41 | Steps: 9 | Eps: 0.008
# Episode 968/1000 | Reward: 3.95 | Steps: 7 | Eps: 0.008
# Episode 969/1000 | Reward: 3.70 | Steps: 10 | Eps: 0.008
# Episode 970/1000 | Reward: 3.21 | Steps: 9 | Eps: 0.008
# Episode 971/1000 | Reward: 3.58 | Steps: 8 | Eps: 0.008
# Episode 972/1000 | Reward: 4.32 | Steps: 10 | Eps: 0.008
# Episode 973/1000 | Reward: 4.74 | Steps: 8 | Eps: 0.008
# Episode 974/1000 | Reward: 3.23 | Steps: 9 | Eps: 0.008
# Episode 975/1000 | Reward: 2.87 | Steps: 9 | Eps: 0.008
# Episode 976/1000 | Reward: 3.24 | Steps: 9 | Eps: 0.008
# Episode 977/1000 | Reward: 3.27 | Steps: 9 | Eps: 0.007
# Episode 978/1000 | Reward: -7.77 | Steps: 10 | Eps: 0.007
# Episode 979/1000 | Reward: 3.72 | Steps: 10 | Eps: 0.007
# Episode 980/1000 | Reward: 3.23 | Steps: 9 | Eps: 0.007
# Episode 981/1000 | Reward: 3.23 | Steps: 9 | Eps: 0.007
# Episode 982/1000 | Reward: 3.29 | Steps: 10 | Eps: 0.007
# Episode 983/1000 | Reward: 4.99 | Steps: 9 | Eps: 0.007
# Episode 984/1000 | Reward: 4.46 | Steps: 10 | Eps: 0.007
# Episode 985/1000 | Reward: 3.97 | Steps: 10 | Eps: 0.007
# Episode 986/1000 | Reward: 5.99 | Steps: 9 | Eps: 0.007
# Episode 987/1000 | Reward: 3.57 | Steps: 8 | Eps: 0.007
# Episode 988/1000 | Reward: 3.25 | Steps: 9 | Eps: 0.007
# Episode 989/1000 | Reward: 5.88 | Steps: 10 | Eps: 0.007
# Episode 990/1000 | Reward: 3.10 | Steps: 9 | Eps: 0.007
# Episode 991/1000 | Reward: 3.74 | Steps: 10 | Eps: 0.007
# Episode 992/1000 | Reward: 2.37 | Steps: 9 | Eps: 0.007
# Episode 993/1000 | Reward: 2.81 | Steps: 10 | Eps: 0.007
# Episode 994/1000 | Reward: 3.41 | Steps: 8 | Eps: 0.007
# Episode 995/1000 | Reward: 3.90 | Steps: 9 | Eps: 0.007
# Episode 996/1000 | Reward: 5.09 | Steps: 8 | Eps: 0.007
# Episode 997/1000 | Reward: 3.54 | Steps: 10 | Eps: 0.007
# Episode 998/1000 | Reward: 4.10 | Steps: 9 | Eps: 0.007
# Episode 999/1000 | Reward: 3.73 | Steps: 8 | Eps: 0.007
# Episode 1000/1000 | Reward: 4.04 | Steps: 10 | Eps: 0.007
# Saved trained policy to 'policies/policy_net_1761601379.pth'

# %%
# -------------------------
# Evaluation (ε = 0)
# -------------------------
def evaluate_policy(env, model, episodes=20):
    rewards, lengths = [], []
    action_counts_eval = np.zeros(action_size, dtype=int)

    model.eval()
    with torch.no_grad():
        for ep in range(episodes):
            reset_output = env.reset()
            state = reset_output[0] if isinstance(reset_output, tuple) else reset_output
            state = np.array(state).flatten()
            done, total_reward, steps = False, 0, 0

            while not done:
                state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
                q_values = model(state_t)
                action = torch.argmax(q_values).item()

                step_output = env.step(action)
                if len(step_output) == 5:
                    next_state, reward, terminated, truncated, info = step_output
                    done = terminated or truncated
                else:
                    next_state, reward, done, info = step_output

                next_state = np.array(next_state).flatten()
                state = next_state
                total_reward += reward
                steps += 1
                action_counts_eval[action] += 1

            rewards.append(total_reward)
            lengths.append(steps)
            print("Eval Episode {}/{} | Reward: {:.2f} | Steps: {}".format(ep+1, episodes, total_reward, steps))

    return np.mean(rewards), np.std(rewards), np.mean(lengths), np.std(lengths), action_counts_eval

mean_r, std_r, mean_l, std_l, eval_actions = evaluate_policy(env, policy_net, episodes=eval_episodes)
print("\nEvaluation over {} episodes:".format(eval_episodes))
print("Avg Reward: {:.2f} ± {:.2f}".format(mean_r, std_r))
print("Avg Length: {:.2f} ± {:.2f}".format(mean_l, std_l))
# Out:
# Eval Episode 1/200 | Reward: 3.85 | Steps: 10
# Eval Episode 2/200 | Reward: 3.00 | Steps: 9
# Eval Episode 3/200 | Reward: 2.28 | Steps: 10
# Eval Episode 4/200 | Reward: 4.13 | Steps: 9
# Eval Episode 5/200 | Reward: 3.48 | Steps: 9
# Eval Episode 6/200 | Reward: 4.50 | Steps: 10
# Eval Episode 7/200 | Reward: 3.44 | Steps: 10
# Eval Episode 8/200 | Reward: 2.50 | Steps: 9
# Eval Episode 9/200 | Reward: 3.51 | Steps: 9
# Eval Episode 10/200 | Reward: 3.88 | Steps: 9
# Eval Episode 11/200 | Reward: 2.91 | Steps: 9
# Eval Episode 12/200 | Reward: 3.86 | Steps: 9
# Eval Episode 13/200 | Reward: 4.07 | Steps: 9
# Eval Episode 14/200 | Reward: 4.26 | Steps: 9
# Eval Episode 15/200 | Reward: 1.63 | Steps: 8
# Eval Episode 16/200 | Reward: 3.05 | Steps: 9
# Eval Episode 17/200 | Reward: 2.10 | Steps: 9
# Eval Episode 18/200 | Reward: 4.01 | Steps: 10
# Eval Episode 19/200 | Reward: -3.81 | Steps: 9
# Eval Episode 20/200 | Reward: 3.89 | Steps: 10
# Eval Episode 21/200 | Reward: 4.02 | Steps: 10
# Eval Episode 22/200 | Reward: 3.55 | Steps: 9
# Eval Episode 23/200 | Reward: 3.40 | Steps: 10
# Eval Episode 24/200 | Reward: 4.53 | Steps: 8
# Eval Episode 25/200 | Reward: 2.37 | Steps: 9
# Eval Episode 26/200 | Reward: 3.28 | Steps: 9
# Eval Episode 27/200 | Reward: -8.40 | Steps: 8
# Eval Episode 28/200 | Reward: 4.86 | Steps: 8
# Eval Episode 29/200 | Reward: 2.91 | Steps: 11
# Eval Episode 30/200 | Reward: 3.01 | Steps: 9
# Eval Episode 31/200 | Reward: 3.69 | Steps: 10
# Eval Episode 32/200 | Reward: 4.09 | Steps: 9
# Eval Episode 33/200 | Reward: 3.60 | Steps: 9
# Eval Episode 34/200 | Reward: 3.66 | Steps: 10
# Eval Episode 35/200 | Reward: 3.04 | Steps: 9
# Eval Episode 36/200 | Reward: 3.41 | Steps: 10
# Eval Episode 37/200 | Reward: 4.43 | Steps: 10
# Eval Episode 38/200 | Reward: 3.33 | Steps: 9
# Eval Episode 39/200 | Reward: 3.99 | Steps: 9
# Eval Episode 40/200 | Reward: 2.05 | Steps: 8
# Eval Episode 41/200 | Reward: 4.35 | Steps: 9
# Eval Episode 42/200 | Reward: 3.09 | Steps: 9
# Eval Episode 43/200 | Reward: 3.49 | Steps: 9
# Eval Episode 44/200 | Reward: 3.89 | Steps: 9
# Eval Episode 45/200 | Reward: 4.09 | Steps: 9
# Eval Episode 46/200 | Reward: 4.21 | Steps: 9
# Eval Episode 47/200 | Reward: -0.21 | Steps: 9
# Eval Episode 48/200 | Reward: 3.56 | Steps: 9
# Eval Episode 49/200 | Reward: 2.46 | Steps: 9
# Eval Episode 50/200 | Reward: 3.78 | Steps: 9
# Eval Episode 51/200 | Reward: 4.23 | Steps: 9
# Eval Episode 52/200 | Reward: 3.27 | Steps: 9
# Eval Episode 53/200 | Reward: 3.21 | Steps: 9
# Eval Episode 54/200 | Reward: 2.92 | Steps: 10
# Eval Episode 55/200 | Reward: 4.85 | Steps: 10
# Eval Episode 56/200 | Reward: 5.35 | Steps: 10
# Eval Episode 57/200 | Reward: 4.23 | Steps: 9
# Eval Episode 58/200 | Reward: 4.03 | Steps: 7
# Eval Episode 59/200 | Reward: 4.47 | Steps: 7
# Eval Episode 60/200 | Reward: 3.32 | Steps: 9
# Eval Episode 61/200 | Reward: 5.04 | Steps: 10
# Eval Episode 62/200 | Reward: 3.06 | Steps: 11
# Eval Episode 63/200 | Reward: 3.61 | Steps: 10
# Eval Episode 64/200 | Reward: 3.07 | Steps: 9
# Eval Episode 65/200 | Reward: 2.67 | Steps: 11
# Eval Episode 66/200 | Reward: 3.28 | Steps: 10
# Eval Episode 67/200 | Reward: 2.97 | Steps: 9
# Eval Episode 68/200 | Reward: 4.24 | Steps: 10
# Eval Episode 69/200 | Reward: 4.83 | Steps: 10
# Eval Episode 70/200 | Reward: 4.22 | Steps: 7
# Eval Episode 71/200 | Reward: 2.84 | Steps: 9
# Eval Episode 72/200 | Reward: 5.78 | Steps: 9
# Eval Episode 73/200 | Reward: 4.13 | Steps: 10
# Eval Episode 74/200 | Reward: 4.59 | Steps: 7
# Eval Episode 75/200 | Reward: 4.12 | Steps: 9
# Eval Episode 76/200 | Reward: 3.57 | Steps: 10
# Eval Episode 77/200 | Reward: 3.51 | Steps: 9
# Eval Episode 78/200 | Reward: 4.15 | Steps: 10
# Eval Episode 79/200 | Reward: 2.58 | Steps: 9
# Eval Episode 80/200 | Reward: 4.14 | Steps: 10
# Eval Episode 81/200 | Reward: 3.71 | Steps: 10
# Eval Episode 82/200 | Reward: 4.11 | Steps: 9
# Eval Episode 83/200 | Reward: 2.68 | Steps: 9
# Eval Episode 84/200 | Reward: 5.43 | Steps: 9
# Eval Episode 85/200 | Reward: 3.80 | Steps: 9
# Eval Episode 86/200 | Reward: 2.68 | Steps: 9
# Eval Episode 87/200 | Reward: 2.77 | Steps: 9
# Eval Episode 88/200 | Reward: 4.57 | Steps: 8
# Eval Episode 89/200 | Reward: 4.64 | Steps: 9
# Eval Episode 90/200 | Reward: 2.16 | Steps: 10
# Eval Episode 91/200 | Reward: 4.03 | Steps: 9
# Eval Episode 92/200 | Reward: 3.96 | Steps: 10
# Eval Episode 93/200 | Reward: 2.87 | Steps: 9
# Eval Episode 94/200 | Reward: 2.80 | Steps: 10
# Eval Episode 95/200 | Reward: 7.06 | Steps: 10
# Eval Episode 96/200 | Reward: 5.22 | Steps: 9
# Eval Episode 97/200 | Reward: 2.73 | Steps: 9
# Eval Episode 98/200 | Reward: 0.88 | Steps: 10
# Eval Episode 99/200 | Reward: 4.00 | Steps: 10
# Eval Episode 100/200 | Reward: 4.11 | Steps: 9
# Eval Episode 101/200 | Reward: 5.36 | Steps: 9
# Eval Episode 102/200 | Reward: 3.58 | Steps: 10
# Eval Episode 103/200 | Reward: 3.16 | Steps: 9
# Eval Episode 104/200 | Reward: 2.49 | Steps: 9
# Eval Episode 105/200 | Reward: 4.07 | Steps: 10
# Eval Episode 106/200 | Reward: 0.98 | Steps: 10
# Eval Episode 107/200 | Reward: 4.33 | Steps: 9
# Eval Episode 108/200 | Reward: 4.79 | Steps: 10
# Eval Episode 109/200 | Reward: 3.28 | Steps: 8
# Eval Episode 110/200 | Reward: 2.13 | Steps: 9
# Eval Episode 111/200 | Reward: 4.34 | Steps: 9
# Eval Episode 112/200 | Reward: 3.29 | Steps: 9
# Eval Episode 113/200 | Reward: -7.37 | Steps: 9
# Eval Episode 114/200 | Reward: 4.41 | Steps: 9
# Eval Episode 115/200 | Reward: 2.14 | Steps: 9
# Eval Episode 116/200 | Reward: 5.10 | Steps: 9
# Eval Episode 117/200 | Reward: 2.32 | Steps: 9
# Eval Episode 118/200 | Reward: 4.88 | Steps: 9
# Eval Episode 119/200 | Reward: -6.52 | Steps: 10
# Eval Episode 120/200 | Reward: 3.26 | Steps: 9
# Eval Episode 121/200 | Reward: 4.44 | Steps: 9
# Eval Episode 122/200 | Reward: 7.04 | Steps: 9
# Eval Episode 123/200 | Reward: 4.30 | Steps: 10
# Eval Episode 124/200 | Reward: 4.12 | Steps: 8
# Eval Episode 125/200 | Reward: 2.52 | Steps: 10
# Eval Episode 126/200 | Reward: 5.67 | Steps: 10
# Eval Episode 127/200 | Reward: -6.22 | Steps: 9
# Eval Episode 128/200 | Reward: 2.40 | Steps: 9
# Eval Episode 129/200 | Reward: 1.01 | Steps: 9
# Eval Episode 130/200 | Reward: 5.04 | Steps: 9
# Eval Episode 131/200 | Reward: 2.69 | Steps: 9
# Eval Episode 132/200 | Reward: 2.90 | Steps: 10
# Eval Episode 133/200 | Reward: 3.34 | Steps: 10
# Eval Episode 134/200 | Reward: 3.21 | Steps: 9
# Eval Episode 135/200 | Reward: 5.42 | Steps: 9
# Eval Episode 136/200 | Reward: 3.13 | Steps: 10
# Eval Episode 137/200 | Reward: 2.81 | Steps: 8
# Eval Episode 138/200 | Reward: 3.50 | Steps: 9
# Eval Episode 139/200 | Reward: 5.92 | Steps: 9
# Eval Episode 140/200 | Reward: 3.40 | Steps: 9
# Eval Episode 141/200 | Reward: 2.84 | Steps: 9
# Eval Episode 142/200 | Reward: 4.75 | Steps: 10
# Eval Episode 143/200 | Reward: 3.76 | Steps: 9
# Eval Episode 144/200 | Reward: 3.18 | Steps: 11
# Eval Episode 145/200 | Reward: 6.98 | Steps: 7
# Eval Episode 146/200 | Reward: 3.59 | Steps: 9
# Eval Episode 147/200 | Reward: 3.56 | Steps: 9
# Eval Episode 148/200 | Reward: 2.64 | Steps: 10
# Eval Episode 149/200 | Reward: 4.02 | Steps: 9
# Eval Episode 150/200 | Reward: 4.20 | Steps: 9
# Eval Episode 151/200 | Reward: 3.58 | Steps: 9
# Eval Episode 152/200 | Reward: 4.68 | Steps: 9
# Eval Episode 153/200 | Reward: 3.68 | Steps: 9
# Eval Episode 154/200 | Reward: 2.84 | Steps: 10
# Eval Episode 155/200 | Reward: 3.26 | Steps: 9
# Eval Episode 156/200 | Reward: 4.05 | Steps: 9
# Eval Episode 157/200 | Reward: 2.30 | Steps: 11
# Eval Episode 158/200 | Reward: 2.96 | Steps: 10
# Eval Episode 159/200 | Reward: 3.00 | Steps: 9
# Eval Episode 160/200 | Reward: 3.96 | Steps: 9
# Eval Episode 161/200 | Reward: -9.04 | Steps: 9
# Eval Episode 162/200 | Reward: -8.96 | Steps: 9
# Eval Episode 163/200 | Reward: 3.38 | Steps: 10
# Eval Episode 164/200 | Reward: 3.76 | Steps: 10
# Eval Episode 165/200 | Reward: 3.32 | Steps: 10
# Eval Episode 166/200 | Reward: 3.76 | Steps: 9
# Eval Episode 167/200 | Reward: 5.14 | Steps: 9
# Eval Episode 168/200 | Reward: 3.83 | Steps: 9
# Eval Episode 169/200 | Reward: 3.35 | Steps: 9
# Eval Episode 170/200 | Reward: 3.74 | Steps: 10
# Eval Episode 171/200 | Reward: 3.32 | Steps: 9
# Eval Episode 172/200 | Reward: 4.75 | Steps: 10
# Eval Episode 173/200 | Reward: 4.98 | Steps: 9
# Eval Episode 174/200 | Reward: 4.92 | Steps: 9
# Eval Episode 175/200 | Reward: 2.32 | Steps: 9
# Eval Episode 176/200 | Reward: 5.63 | Steps: 9
# Eval Episode 177/200 | Reward: 3.11 | Steps: 10
# Eval Episode 178/200 | Reward: 3.49 | Steps: 10
# Eval Episode 179/200 | Reward: 4.75 | Steps: 10
# Eval Episode 180/200 | Reward: -8.23 | Steps: 10
# Eval Episode 181/200 | Reward: -5.92 | Steps: 9
# Eval Episode 182/200 | Reward: 2.85 | Steps: 10
# Eval Episode 183/200 | Reward: 1.40 | Steps: 9
# Eval Episode 184/200 | Reward: 4.24 | Steps: 9
# Eval Episode 185/200 | Reward: 3.33 | Steps: 10
# Eval Episode 186/200 | Reward: 4.60 | Steps: 10
# Eval Episode 187/200 | Reward: 3.65 | Steps: 9
# Eval Episode 188/200 | Reward: -8.20 | Steps: 11
# Eval Episode 189/200 | Reward: 2.77 | Steps: 9
# Eval Episode 190/200 | Reward: 4.37 | Steps: 10
# Eval Episode 191/200 | Reward: 3.86 | Steps: 9
# Eval Episode 192/200 | Reward: 3.48 | Steps: 7
# Eval Episode 193/200 | Reward: 4.05 | Steps: 9
# Eval Episode 194/200 | Reward: 3.44 | Steps: 8
# Eval Episode 195/200 | Reward: -8.53 | Steps: 9
# Eval Episode 196/200 | Reward: 4.44 | Steps: 10
# Eval Episode 197/200 | Reward: 3.32 | Steps: 9
# Eval Episode 198/200 | Reward: 3.24 | Steps: 10
# Eval Episode 199/200 | Reward: 3.15 | Steps: 9
# Eval Episode 200/200 | Reward: 3.07 | Steps: 9
#
# Evaluation over 200 episodes:
# Avg Reward: 3.06 ± 2.74
# Avg Length: 9.26 ± 0.73

# %%
# -------------------------
# Visualizations (optional)
# -------------------------
directory_name = f"plots/{unique_id}"
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except Exception as e:
    print(f"An error occurred: {e}")

def visualize_q_distribution(model, n_samples=200):
    sampled_states = []
    for _ in range(n_samples):
        reset_output = env.reset()
        s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
        sampled_states.append(np.array(s).flatten())
    states_t = torch.FloatTensor(np.vstack(sampled_states)).to(device)
    with torch.no_grad():
        q_vals = model(states_t).cpu().numpy()
    plt.figure(figsize=(10,5))
    plt.boxplot(q_vals)
    plt.title("Distribution of Predicted Q-values per Action")
    plt.xlabel("Action Index")
    plt.ylabel("Q-value")
    plt.savefig(f"plots/{unique_id}/q_values.png")
    plt.show()
    plt.close()

visualize_q_distribution(policy_net)

plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
plt.plot(reward_history)
plt.title("Training Reward per Episode")
plt.xlabel("Episode"); plt.ylabel("Reward")

plt.subplot(2,3,2)
plt.plot(loss_history)
plt.title("Average Loss per Episode")
plt.xlabel("Episode"); plt.ylabel("Loss")

plt.subplot(2,3,3)
plt.plot(episode_length)
plt.title("Episode Length")
plt.xlabel("Episode"); plt.ylabel("Steps")

plt.subplot(2,3,4)
plt.bar(np.arange(action_size), action_counts)
plt.title("Action Distribution (Training)")
plt.xlabel("Action"); plt.ylabel("Count")

plt.subplot(2,3,5)
plt.bar(np.arange(action_size), eval_actions, color='orange')
plt.title("Action Distribution (Evaluation)")
plt.xlabel("Action"); plt.ylabel("Count")

plt.subplot(2,3,6)
plt.plot(epsilon_history)
plt.title("Epsilon Decay")
plt.xlabel("Episode"); plt.ylabel("Epsilon")

plt.tight_layout()
plt.savefig(f"plots/{unique_id}/training_plots.png")
plt.show()
plt.close()
# Out:
# Directory 'plots/1761601379' created successfully.

# %%
# -------------------------
# Feature gradient importance (optional)
# -------------------------
def compute_feature_loss_importance(model, memory, batch_size=256):
    if len(memory) < batch_size:
        print("Not enough samples in memory.")
        return None, None

    batch = random.sample(memory, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(np.vstack(states)).to(device)
    next_states = torch.FloatTensor(np.vstack(next_states)).to(device)
    actions = torch.LongTensor(actions).unsqueeze(1).to(device)
    rewards = torch.FloatTensor(rewards).unsqueeze(1).to(device)
    dones = torch.FloatTensor(dones).unsqueeze(1).to(device)

    states.requires_grad = True

    q_values = policy_net(states).gather(1, actions)
    next_actions = policy_net(next_states).argmax(1).unsqueeze(1)
    next_q_values = target_net(next_states).gather(1, next_actions).detach()
    target_q = rewards + (gamma * next_q_values * (1 - dones))

    loss = (q_values - target_q).pow(2).mean()
    loss.backward(retain_graph=True)

    grad_magnitudes = states.grad.abs().mean(dim=0).cpu().numpy()
    norm_grad = grad_magnitudes / (grad_magnitudes.sum() + 1e-8)

    feature_idx = np.arange(len(norm_grad))
    plt.figure(figsize=(16,10))
    feature_names = env.feature_names if hasattr(env, 'feature_names') else ["f{}".format(i) for i in range(state_size)]
    plt.bar(feature_names[0:46], norm_grad)
    plt.xticks(rotation=90)
    plt.title("Normalized Trajectory Loss Contribution by Feature")
    plt.ylabel("Normalized |dLoss/dFeature|")
    plt.savefig(f"plots/{unique_id}/loss_by_feature.png")
    plt.show()
    plt.close()

    return grad_magnitudes, norm_grad

# Run after training:
grad_mags, norm_grad = compute_feature_loss_importance(policy_net, memory)

# %%
# -------------------------
# === XRL MODULE 1: Policy Distillation -> Decision Tree
# -------------------------
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.metrics import accuracy_score

directory_name = f"trees/{unique_id}"
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except Exception as e:
    print(f"An error occurred: {e}")

def distill_policy_to_tree(model, env, n_samples=3000, max_depth=4):
    model.eval()
    X, y = [], []

    for _ in range(n_samples):
        reset_output = env.reset()
        s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
        s = np.array(s).flatten()
        X.append(s)

        with torch.no_grad():
            s_t = torch.FloatTensor(s).unsqueeze(0).to(device)
            q_vals = model(s_t)
            action = torch.argmax(q_vals).item()
            y.append(action)

    X = np.array(X)
    y = np.array(y)

    tree = DecisionTreeClassifier(max_depth=max_depth, random_state=42)
    tree.fit(X, y)

    fidelity = accuracy_score(y, tree.predict(X))
    print("Distillation complete - Tree fidelity to policy: {:.2f}%".format(fidelity * 100))

    with open(f"trees/{unique_id}/tree_fidelity.txt", 'w', encoding='utf-8') as file:
        file.write("Distillation complete - Tree fidelity to policy: {:.2f}%".format(fidelity * 100))

    plt.figure(figsize=(64, 40))
    feature_names = getattr(env, "feature_names", ["f{}".format(i) for i in range(X.shape[1])])
    plot_tree(tree, feature_names=feature_names[0:46],
              class_names=[str(i) for i in range(env.action_space.n)], filled=True)
    plt.title("Decision Tree Surrogate for Policy")
    plt.savefig(f"plots/{unique_id}/decision_tree.png")
    plt.show()
    plt.close()

    print(export_text(tree, feature_names=feature_names[0:46]))
    return tree

policy_tree = distill_policy_to_tree(policy_net, env, n_samples=3000, max_depth=4)

# Save the tree if desired (pickle)
try:
    import pickle
    with open(f"trees/{unique_id}/policy_tree.pkl", "wb") as f:
        pickle.dump(policy_tree, f)
    print("Saved tree as 'policy_tree.pkl'")
except Exception as e:
    print("Could not save tree: {}".format(e))
# Out:
# Directory 'trees/1761601379' created successfully.
# Distillation complete - Tree fidelity to policy: 39.87%
# |--- vent <= -0.16
# |   |--- ANION GAP <= 0.40
# |   |   |--- race_white <= -0.52
# |   |   |   |--- HEMOGLOBIN <= -0.01
# |   |   |   |   |--- class: 21
# |   |   |   |--- HEMOGLOBIN >  -0.01
# |   |   |   |   |--- class: 1
# |   |   |--- race_white >  -0.52
# |   |   |   |--- BICARBONATE <= 0.15
# |   |   |   |   |--- class: 16
# |   |   |   |--- BICARBONATE >  0.15
# |   |   |   |   |--- class: 16
# |   |--- ANION GAP >  0.40
# |   |   |--- BUN <= 2.71
# |   |   |   |--- sofa <= 0.38
# |   |   |   |   |--- class: 16
# |   |   |   |--- sofa >  0.38
# |   |   |   |   |--- class: 20
# |   |   |--- BUN >  2.71
# |   |   |   |--- sofa <= -0.61
# |   |   |   |   |--- class: 5
# |   |   |   |--- sofa >  -0.61
# |   |   |   |   |--- class: 20
# |--- vent >  -0.16
# |   |--- race_white <= -0.52
# |   |   |--- race_hispanic <= 2.74
# |   |   |   |--- blood_culture_positive <= 0.39
# |   |   |   |   |--- class: 21
# |   |   |   |--- blood_culture_positive >  0.39
# |   |   |   |   |--- class: 1
# |   |   |--- race_hispanic >  2.74
# |   |   |   |--- weight <= -0.37
# |   |   |   |   |--- class: 21
# |   |   |   |--- weight >  -0.37
# |   |   |   |   |--- class: 1
# |   |--- race_white >  -0.52
# |   |   |--- qsofa_resprate_score <= -1.08
# |   |   |   |--- RespRate <= -0.61
# |   |   |   |   |--- class: 21
# |   |   |   |--- RespRate >  -0.61
# |   |   |   |   |--- class: 16
# |   |   |--- qsofa_resprate_score >  -1.08
# |   |   |   |--- DiasBP <= -0.31
# |   |   |   |   |--- class: 16
# |   |   |   |--- DiasBP >  -0.31
# |   |   |   |   |--- class: 16
#
# Saved tree as 'policy_tree.pkl'

# %% [markdown]
# # -------------------------
# # === XRL MODULE 2: SHAP explanations (KernelExplainer for Py3.6)
# # -------------------------
# import shap
#
# def explain_policy_with_shap(model, env, n_samples=500, background_size=100, explain_samples=200):
#     model.eval()
#
#     # Sample states
#     states = []
#     for _ in range(n_samples):
#         reset_output = env.reset()
#         s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
#         states.append(np.array(s).flatten())
#     X = np.array(states)
#
#     # Model wrapper for SHAP: returns (N, action_size) array
#     def q_predict(x):
#         x_t = torch.FloatTensor(x).to(device)
#         with torch.no_grad():
#             q_vals = model(x_t).cpu().numpy()
#         return q_vals
#
#     # KernelExplainer works with old SHAP versions and Py3.6
#     if len(X) < background_size:
#         background = X
#     else:
#         idx = np.random.choice(len(X), background_size, replace=False)
#         background = X[idx]
#
#     print("Building KernelExplainer (this may take some time)...")
#     explainer = shap.KernelExplainer(q_predict, background)
#     # Limit explained samples for speed; KernelExplainer is expensive
#     to_explain = X[:explain_samples]
#     shap_values = explainer.shap_values(to_explain)
#
#     feature_names = getattr(env, "feature_names", ["f{}".format(i) for i in range(X.shape[1])])
#
#     # shap_values is a list (one array per model output), each array shape = (samples, features)
#     # We'll show summaries for each action's Q-value
#     for a_idx in range(len(shap_values)):
#         print("Summary plot for action {}".format(a_idx))
#         try:
#             shap.summary_plot(shap_values[a_idx], features=to_explain, feature_names=feature_names, show=True)
#         except Exception as e:
#             print("Could not show SHAP summary_plot for action {}: {}".format(a_idx, e))
#
#     # Return the raw shap_values + the data used
#     return {"shap_values": shap_values, "data": to_explain, "feature_names": feature_names}
#
# shap_res = explain_policy_with_shap(policy_net, env, n_samples=500, background_size=100, explain_samples=200)

# %% [markdown]
# # -------------------------
# # Optional: Shapley Decision Boundary (2D visualization)
# # -------------------------
# def shapley_decision_boundary(model, shap_res, feature_idx=(0,1), grid_size=50):
#     f1, f2 = feature_idx
#     data = shap_res["data"]
#     feature_names = shap_res["feature_names"]
#
#     f1_range = np.linspace(data[:, f1].min(), data[:, f1].max(), grid_size)
#     f2_range = np.linspace(data[:, f2].min(), data[:, f2].max(), grid_size)
#     grid = np.array([[a, b] for a in f1_range for b in f2_range])
#
#     base = data.mean(axis=0)
#     X_grid = np.tile(base, (grid.shape[0], 1))
#     X_grid[:, f1] = grid[:, 0]
#     X_grid[:, f2] = grid[:, 1]
#
#     with torch.no_grad():
#         q_vals = model(torch.FloatTensor(X_grid).to(device)).cpu().numpy()
#     actions = np.argmax(q_vals, axis=1)
#
#     plt.figure(figsize=(8,6))
#     plt.tricontourf(grid[:,0], grid[:,1], actions, cmap='Spectral', alpha=0.7)
#     plt.xlabel(feature_names[f1])
#     plt.ylabel(feature_names[f2])
#     plt.title("Shapley-Informed Policy Decision Regions")
#     plt.colorbar(label='Action')
#     plt.show()
#
# # Example: use features 0 and 1 (change to most informative ones based on SHAP)
# shapley_decision_boundary(policy_net, shap_res, feature_idx=(0,1), grid_size=60)
#
# print("Script finished.")
