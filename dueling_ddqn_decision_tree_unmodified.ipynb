# %%
from gym_sepsis.envs.sepsis_env import SepsisEnv
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import os
import datetime

# -------------------------
# Device setup
# -------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

SEED = 8289
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
# Out:
# Using device: cpu

# %%
# -------------------------
# Environment setup
# -------------------------
env = SepsisEnv()

env.seed(SEED)
env.action_space.seed(SEED)

reset_output = env.reset()
if isinstance(reset_output, tuple):
    state = reset_output[0]
else:
    state = reset_output
state = np.array(state).flatten()

state_size = len(state)
action_size = env.action_space.n

print("State size:", state_size)
print("Action size:", action_size)
# Out:
# State size: 46
# Action size: 24

# %%
# obs = env.reset()
# done = False
# while not done:
#     action = env.action_space.sample()
#     obs, reward, done, info = env.step(0)
#     print(reward)

# %%
# # -------------------------
# # Q-network (shared by online and target)
# # -------------------------
# class QNetwork(nn.Module):
#     def __init__(self, state_size, action_size, layers=3, hidden=128):
#         super(QNetwork, self).__init__()
#         self.fc_in = nn.Linear(state_size, hidden)
#         self.fc = nn.ModuleList()
#         for _ in range(layers):
#             self.fc.append(nn.Linear(hidden, hidden))
#         self.fc_out = nn.Linear(hidden, action_size)

#     def forward(self, x):
#         x = torch.relu(self.fc_in(x))
#         for layer in self.fc:
#             x = torch.relu(layer(x))
#         return self.fc_out(x)

# %%
# -------------------------
# Dueling Q-Network
# -------------------------
class DuelingQNetwork(nn.Module):
    def __init__(self, state_size, action_size, layers=3, hidden=128):
        super(DuelingQNetwork, self).__init__()
        self.fc_in = nn.Linear(state_size, hidden)
        self.hidden_layers = nn.ModuleList([nn.Linear(hidden, hidden) for _ in range(layers)])

        # Separate streams for value and advantage
        self.value_stream = nn.Sequential(
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        self.advantage_stream = nn.Sequential(
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, action_size)
        )

    def forward(self, x):
        # Shared feature extraction
        x = torch.relu(self.fc_in(x))
        for layer in self.hidden_layers:
            x = torch.relu(layer(x))

        # Separate value and advantage computation
        value = self.value_stream(x)
        advantage = self.advantage_stream(x)
        
        # Combine streams: Q(s,a) = V(s) + (A(s,a) - mean(A(s,a)))
        q_values = value + (advantage - advantage.mean(dim=1, keepdim=True))
        return q_values

# %%
# -------------------------
# Hyperparameters
# -------------------------
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.005
epsilon_decay = 0.99
lr = 5e-4
batch_size = 128
memory_size = 20000
num_episodes = 1000
target_update_freq = 5
eval_episodes = 200  # for evaluation

time_stamp = datetime.datetime.now().timestamp().__round__()
unique_id = str(time_stamp)
save_path = f"policies/policy_net_{unique_id}.pth"

# %%
# -------------------------
# Initialize networks, optimizer, memory
# -------------------------
policy_net = DuelingQNetwork(state_size, action_size).to(device)
target_net = DuelingQNetwork(state_size, action_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr, eps=1e-4)
torch.nn.utils.clip_grad_norm_(policy_net.parameters(), max_norm=10)
loss_fn = nn.HuberLoss()
memory = deque(maxlen=memory_size)

# %%
# -------------------------
# Helper functions
# -------------------------
def get_action(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        q_values = policy_net(state_t)
        return torch.argmax(q_values).item()

# -------------------------
# Replay function (Dueling Double DQN)
# -------------------------
def replay():
    if len(memory) < batch_size:
        return None

    batch = random.sample(memory, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(np.vstack(states)).to(device)
    next_states = torch.FloatTensor(np.vstack(next_states)).to(device)
    actions = torch.LongTensor(actions).unsqueeze(1).to(device)
    rewards = torch.FloatTensor(rewards).unsqueeze(1).to(device)
    dones = torch.FloatTensor(dones).unsqueeze(1).to(device)

    # -------------------------
    # Compute current Q-values
    # -------------------------
    q_values = policy_net(states).gather(1, actions)

    # -------------------------
    # Double DQN target
    # -------------------------
    with torch.no_grad():
        # Select best actions according to online (policy) network
        next_actions = policy_net(next_states).argmax(1).unsqueeze(1)
        # Evaluate those actions using the target network (dueling version)
        next_q_values = target_net(next_states).gather(1, next_actions)
        # Compute target Q-values
        target_q = rewards + (gamma * next_q_values * (1 - dones))

    # -------------------------
    # Compute loss and optimize
    # -------------------------
    loss = loss_fn(q_values, target_q)
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(policy_net.parameters(), max_norm=10)
    optimizer.step()

    return loss.item()

# %%
# -------------------------
# Training loop
# -------------------------
reward_history, loss_history, episode_length = [], [], []
epsilon_history, action_counts = [], np.zeros(action_size, dtype=int)

for episode in range(num_episodes):
    reset_output = env.reset()
    state = reset_output[0] if isinstance(reset_output, tuple) else reset_output
    state = np.array(state).flatten()
    done, total_reward, steps = False, 0, 0
    episode_losses = []

    while not done:
        action = get_action(state, epsilon)
        step_output = env.step(action)
        if len(step_output) == 5:
            next_state, reward, terminated, truncated, info = step_output
            done = terminated or truncated
        else:
            next_state, reward, done, info = step_output
        next_state = np.array(next_state).flatten()

        memory.append((state, action, reward, next_state, float(done)))
        state = next_state
        total_reward += reward
        steps += 1
        action_counts[action] += 1

        loss_val = replay()
        if loss_val is not None:
            episode_losses.append(loss_val)

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    if episode % target_update_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())

    reward_history.append(total_reward)
    epsilon_history.append(epsilon)
    episode_length.append(steps)
    loss_history.append(np.mean(episode_losses) if episode_losses else 0)

    print("Episode {}/{} | Reward: {:.2f} | Steps: {} | Eps: {:.3f}".format(
        episode+1, num_episodes, total_reward, steps, epsilon))

# Save trained policy
torch.save(policy_net.state_dict(), save_path)
print("Saved trained policy to '{}'".format(save_path))
# Out:
# Episode 1/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.990
# Episode 2/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.980
# Episode 3/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.970
# Episode 4/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.961
# Episode 5/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.951
# Episode 6/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.941
# Episode 7/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.932
# Episode 8/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.923
# Episode 9/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.914
# Episode 10/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.904
# Episode 11/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.895
# Episode 12/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.886
# Episode 13/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.878
# Episode 14/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.869
# Episode 15/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.860
# Episode 16/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.851
# Episode 17/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.843
# Episode 18/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.835
# Episode 19/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.826
# Episode 20/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.818
# Episode 21/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.810
# Episode 22/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.802
# Episode 23/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.794
# Episode 24/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.786
# Episode 25/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.778
# Episode 26/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.770
# Episode 27/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.762
# Episode 28/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.755
# Episode 29/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.747
# Episode 30/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.740
# Episode 31/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.732
# Episode 32/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.725
# Episode 33/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.718
# Episode 34/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.711
# Episode 35/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.703
# Episode 36/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.696
# Episode 37/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.689
# Episode 38/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.683
# Episode 39/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.676
# Episode 40/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.669
# Episode 41/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.662
# Episode 42/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.656
# Episode 43/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.649
# Episode 44/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.643
# Episode 45/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.636
# Episode 46/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.630
# Episode 47/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.624
# Episode 48/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.617
# Episode 49/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.611
# Episode 50/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.605
# Episode 51/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.599
# Episode 52/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.593
# Episode 53/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.587
# Episode 54/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.581
# Episode 55/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.575
# Episode 56/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.570
# Episode 57/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.564
# Episode 58/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.558
# Episode 59/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.553
# Episode 60/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.547
# Episode 61/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.542
# Episode 62/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.536
# Episode 63/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.531
# Episode 64/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.526
# Episode 65/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.520
# Episode 66/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.515
# Episode 67/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.510
# Episode 68/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.505
# Episode 69/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.500
# Episode 70/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.495
# Episode 71/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.490
# Episode 72/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.485
# Episode 73/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.480
# Episode 74/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.475
# Episode 75/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.471
# Episode 76/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.466
# Episode 77/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.461
# Episode 78/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.457
# Episode 79/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.452
# Episode 80/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.448
# Episode 81/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.443
# Episode 82/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.439
# Episode 83/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.434
# Episode 84/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.430
# Episode 85/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.426
# Episode 86/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.421
# Episode 87/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.417
# Episode 88/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.413
# Episode 89/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.409
# Episode 90/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.405
# Episode 91/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.401
# Episode 92/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.397
# Episode 93/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.393
# Episode 94/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.389
# Episode 95/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.385
# Episode 96/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.381
# Episode 97/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.377
# Episode 98/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.373
# Episode 99/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.370
# Episode 100/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.366
# Episode 101/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.362
# Episode 102/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.359
# Episode 103/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.355
# Episode 104/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.352
# Episode 105/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.348
# Episode 106/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.345
# Episode 107/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.341
# Episode 108/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.338
# Episode 109/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.334
# Episode 110/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.331
# Episode 111/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.328
# Episode 112/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.324
# Episode 113/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.321
# Episode 114/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.318
# Episode 115/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.315
# Episode 116/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.312
# Episode 117/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.309
# Episode 118/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.305
# Episode 119/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.302
# Episode 120/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.299
# Episode 121/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.296
# Episode 122/1000 | Reward: -15.00 | Steps: 7 | Eps: 0.293
# Episode 123/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.290
# Episode 124/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.288
# Episode 125/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.285
# Episode 126/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.282
# Episode 127/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.279
# Episode 128/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.276
# Episode 129/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.273
# Episode 130/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.271
# Episode 131/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.268
# Episode 132/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.265
# Episode 133/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.263
# Episode 134/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.260
# Episode 135/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.257
# Episode 136/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.255
# Episode 137/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.252
# Episode 138/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.250
# Episode 139/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.247
# Episode 140/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.245
# Episode 141/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.242
# Episode 142/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.240
# Episode 143/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.238
# Episode 144/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.235
# Episode 145/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.233
# Episode 146/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.231
# Episode 147/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.228
# Episode 148/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.226
# Episode 149/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.224
# Episode 150/1000 | Reward: 15.00 | Steps: 4 | Eps: 0.221
# Episode 151/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.219
# Episode 152/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.217
# Episode 153/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.215
# Episode 154/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.213
# Episode 155/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.211
# Episode 156/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.208
# Episode 157/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.206
# Episode 158/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.204
# Episode 159/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.202
# Episode 160/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.200
# Episode 161/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.198
# Episode 162/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.196
# Episode 163/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.194
# Episode 164/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.192
# Episode 165/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.190
# Episode 166/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.189
# Episode 167/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.187
# Episode 168/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.185
# Episode 169/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.183
# Episode 170/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.181
# Episode 171/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.179
# Episode 172/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.178
# Episode 173/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.176
# Episode 174/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.174
# Episode 175/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.172
# Episode 176/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.171
# Episode 177/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.169
# Episode 178/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.167
# Episode 179/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.165
# Episode 180/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.164
# Episode 181/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.162
# Episode 182/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.161
# Episode 183/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.159
# Episode 184/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.157
# Episode 185/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.156
# Episode 186/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.154
# Episode 187/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.153
# Episode 188/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.151
# Episode 189/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.150
# Episode 190/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.148
# Episode 191/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.147
# Episode 192/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.145
# Episode 193/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.144
# Episode 194/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.142
# Episode 195/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.141
# Episode 196/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.139
# Episode 197/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.138
# Episode 198/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.137
# Episode 199/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.135
# Episode 200/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.134
# Episode 201/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.133
# Episode 202/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.131
# Episode 203/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.130
# Episode 204/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.129
# Episode 205/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.127
# Episode 206/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.126
# Episode 207/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.125
# Episode 208/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.124
# Episode 209/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.122
# Episode 210/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.121
# Episode 211/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.120
# Episode 212/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.119
# Episode 213/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.118
# Episode 214/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.116
# Episode 215/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.115
# Episode 216/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.114
# Episode 217/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.113
# Episode 218/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.112
# Episode 219/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.111
# Episode 220/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.110
# Episode 221/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.108
# Episode 222/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.107
# Episode 223/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.106
# Episode 224/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.105
# Episode 225/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.104
# Episode 226/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.103
# Episode 227/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.102
# Episode 228/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.101
# Episode 229/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.100
# Episode 230/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.099
# Episode 231/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.098
# Episode 232/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.097
# Episode 233/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.096
# Episode 234/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.095
# Episode 235/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.094
# Episode 236/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.093
# Episode 237/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.092
# Episode 238/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.091
# Episode 239/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.091
# Episode 240/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.090
# Episode 241/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.089
# Episode 242/1000 | Reward: -15.00 | Steps: 8 | Eps: 0.088
# Episode 243/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.087
# Episode 244/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.086
# Episode 245/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.085
# Episode 246/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.084
# Episode 247/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.084
# Episode 248/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.083
# Episode 249/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.082
# Episode 250/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.081
# Episode 251/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.080
# Episode 252/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.079
# Episode 253/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.079
# Episode 254/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.078
# Episode 255/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.077
# Episode 256/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.076
# Episode 257/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.076
# Episode 258/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.075
# Episode 259/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.074
# Episode 260/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.073
# Episode 261/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.073
# Episode 262/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.072
# Episode 263/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.071
# Episode 264/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.070
# Episode 265/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.070
# Episode 266/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.069
# Episode 267/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.068
# Episode 268/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.068
# Episode 269/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.067
# Episode 270/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.066
# Episode 271/1000 | Reward: -15.00 | Steps: 7 | Eps: 0.066
# Episode 272/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.065
# Episode 273/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.064
# Episode 274/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.064
# Episode 275/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.063
# Episode 276/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.062
# Episode 277/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.062
# Episode 278/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.061
# Episode 279/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.061
# Episode 280/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.060
# Episode 281/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.059
# Episode 282/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.059
# Episode 283/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.058
# Episode 284/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.058
# Episode 285/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.057
# Episode 286/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.056
# Episode 287/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.056
# Episode 288/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.055
# Episode 289/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.055
# Episode 290/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.054
# Episode 291/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.054
# Episode 292/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.053
# Episode 293/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.053
# Episode 294/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.052
# Episode 295/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.052
# Episode 296/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.051
# Episode 297/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.051
# Episode 298/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.050
# Episode 299/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.050
# Episode 300/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.049
# Episode 301/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.049
# Episode 302/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.048
# Episode 303/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.048
# Episode 304/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.047
# Episode 305/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.047
# Episode 306/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.046
# Episode 307/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.046
# Episode 308/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.045
# Episode 309/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.045
# Episode 310/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.044
# Episode 311/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.044
# Episode 312/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.043
# Episode 313/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.043
# Episode 314/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.043
# Episode 315/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.042
# Episode 316/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.042
# Episode 317/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.041
# Episode 318/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.041
# Episode 319/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.041
# Episode 320/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.040
# Episode 321/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.040
# Episode 322/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.039
# Episode 323/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.039
# Episode 324/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.039
# Episode 325/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.038
# Episode 326/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.038
# Episode 327/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.037
# Episode 328/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.037
# Episode 329/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.037
# Episode 330/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.036
# Episode 331/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.036
# Episode 332/1000 | Reward: -15.00 | Steps: 8 | Eps: 0.036
# Episode 333/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.035
# Episode 334/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.035
# Episode 335/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.034
# Episode 336/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.034
# Episode 337/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.034
# Episode 338/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.033
# Episode 339/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.033
# Episode 340/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.033
# Episode 341/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.032
# Episode 342/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.032
# Episode 343/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.032
# Episode 344/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.032
# Episode 345/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.031
# Episode 346/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.031
# Episode 347/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.031
# Episode 348/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.030
# Episode 349/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.030
# Episode 350/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.030
# Episode 351/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.029
# Episode 352/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.029
# Episode 353/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.029
# Episode 354/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.029
# Episode 355/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.028
# Episode 356/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.028
# Episode 357/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.028
# Episode 358/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.027
# Episode 359/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.027
# Episode 360/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.027
# Episode 361/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.027
# Episode 362/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.026
# Episode 363/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.026
# Episode 364/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.026
# Episode 365/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.026
# Episode 366/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.025
# Episode 367/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.025
# Episode 368/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.025
# Episode 369/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.025
# Episode 370/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.024
# Episode 371/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.024
# Episode 372/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.024
# Episode 373/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.024
# Episode 374/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.023
# Episode 375/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.023
# Episode 376/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.023
# Episode 377/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.023
# Episode 378/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.022
# Episode 379/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.022
# Episode 380/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.022
# Episode 381/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.022
# Episode 382/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.022
# Episode 383/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.021
# Episode 384/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.021
# Episode 385/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.021
# Episode 386/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.021
# Episode 387/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.020
# Episode 388/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.020
# Episode 389/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.020
# Episode 390/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.020
# Episode 391/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.020
# Episode 392/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.019
# Episode 393/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.019
# Episode 394/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.019
# Episode 395/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.019
# Episode 396/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.019
# Episode 397/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.019
# Episode 398/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.018
# Episode 399/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.018
# Episode 400/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.018
# Episode 401/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.018
# Episode 402/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.018
# Episode 403/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.017
# Episode 404/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.017
# Episode 405/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.017
# Episode 406/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.017
# Episode 407/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.017
# Episode 408/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.017
# Episode 409/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.016
# Episode 410/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.016
# Episode 411/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.016
# Episode 412/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.016
# Episode 413/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.016
# Episode 414/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.016
# Episode 415/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 416/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 417/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 418/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 419/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 420/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 421/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.015
# Episode 422/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.014
# Episode 423/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.014
# Episode 424/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.014
# Episode 425/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.014
# Episode 426/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.014
# Episode 427/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.014
# Episode 428/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.014
# Episode 429/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 430/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 431/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 432/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 433/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.013
# Episode 434/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 435/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 436/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.013
# Episode 437/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.012
# Episode 438/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.012
# Episode 439/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.012
# Episode 440/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.012
# Episode 441/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.012
# Episode 442/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.012
# Episode 443/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.012
# Episode 444/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.012
# Episode 445/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 446/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 447/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 448/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 449/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 450/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.011
# Episode 451/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 452/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 453/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.011
# Episode 454/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.010
# Episode 455/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 456/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 457/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 458/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 459/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 460/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.010
# Episode 461/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 462/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.010
# Episode 463/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.010
# Episode 464/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.009
# Episode 465/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.009
# Episode 466/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.009
# Episode 467/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.009
# Episode 468/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.009
# Episode 469/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.009
# Episode 470/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.009
# Episode 471/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.009
# Episode 472/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.009
# Episode 473/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.009
# Episode 474/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.009
# Episode 475/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.008
# Episode 476/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.008
# Episode 477/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.008
# Episode 478/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.008
# Episode 479/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.008
# Episode 480/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.008
# Episode 481/1000 | Reward: -15.00 | Steps: 6 | Eps: 0.008
# Episode 482/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.008
# Episode 483/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.008
# Episode 484/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.008
# Episode 485/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.008
# Episode 486/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.008
# Episode 487/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 488/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 489/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.007
# Episode 490/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 491/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 492/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 493/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.007
# Episode 494/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 495/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 496/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 497/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 498/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 499/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 500/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.007
# Episode 501/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.007
# Episode 502/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 503/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 504/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 505/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 506/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 507/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 508/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 509/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 510/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 511/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 512/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 513/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 514/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.006
# Episode 515/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 516/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 517/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.006
# Episode 518/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 519/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 520/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 521/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 522/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 523/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 524/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 525/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 526/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 527/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 528/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 529/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 530/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 531/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 532/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 533/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 534/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 535/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 536/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 537/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 538/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 539/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 540/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 541/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 542/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 543/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 544/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 545/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 546/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 547/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 548/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 549/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 550/1000 | Reward: -15.00 | Steps: 7 | Eps: 0.005
# Episode 551/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 552/1000 | Reward: -15.00 | Steps: 7 | Eps: 0.005
# Episode 553/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 554/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 555/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 556/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 557/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 558/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 559/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 560/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 561/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 562/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 563/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 564/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 565/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 566/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 567/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 568/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 569/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 570/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 571/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 572/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 573/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 574/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 575/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 576/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 577/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 578/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 579/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 580/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 581/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 582/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 583/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 584/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 585/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 586/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 587/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 588/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 589/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 590/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 591/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 592/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 593/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 594/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 595/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 596/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 597/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 598/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 599/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 600/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 601/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 602/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 603/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 604/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 605/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 606/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 607/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 608/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 609/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 610/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 611/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 612/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 613/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 614/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 615/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 616/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 617/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 618/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 619/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 620/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 621/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 622/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 623/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 624/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 625/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 626/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 627/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 628/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 629/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 630/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 631/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 632/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 633/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 634/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 635/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 636/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 637/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 638/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 639/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 640/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 641/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 642/1000 | Reward: -15.00 | Steps: 7 | Eps: 0.005
# Episode 643/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 644/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 645/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 646/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 647/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 648/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 649/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 650/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 651/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 652/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 653/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 654/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 655/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 656/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 657/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.005
# Episode 658/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 659/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 660/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 661/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 662/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 663/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 664/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 665/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 666/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 667/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 668/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 669/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 670/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 671/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 672/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.005
# Episode 673/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 674/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 675/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 676/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 677/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 678/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 679/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 680/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 681/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 682/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 683/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 684/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 685/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 686/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 687/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 688/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 689/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 690/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 691/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 692/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 693/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 694/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 695/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 696/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 697/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 698/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 699/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 700/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 701/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 702/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 703/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 704/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 705/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 706/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 707/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 708/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 709/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 710/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 711/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 712/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 713/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 714/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 715/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 716/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 717/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 718/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 719/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 720/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 721/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 722/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 723/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 724/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 725/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 726/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 727/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.005
# Episode 728/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 729/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 730/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 731/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 732/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 733/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 734/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 735/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 736/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 737/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 738/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 739/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 740/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.005
# Episode 741/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 742/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 743/1000 | Reward: -15.00 | Steps: 12 | Eps: 0.005
# Episode 744/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 745/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 746/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 747/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 748/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 749/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 750/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 751/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 752/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 753/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 754/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 755/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 756/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 757/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.005
# Episode 758/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.005
# Episode 759/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 760/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 761/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 762/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 763/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 764/1000 | Reward: 15.00 | Steps: 5 | Eps: 0.005
# Episode 765/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 766/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 767/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 768/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 769/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 770/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 771/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 772/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 773/1000 | Reward: 15.00 | Steps: 5 | Eps: 0.005
# Episode 774/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 775/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 776/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 777/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 778/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 779/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 780/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 781/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 782/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 783/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 784/1000 | Reward: -15.00 | Steps: 8 | Eps: 0.005
# Episode 785/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 786/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 787/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 788/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 789/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 790/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 791/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 792/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 793/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 794/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 795/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 796/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 797/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 798/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 799/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 800/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 801/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 802/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 803/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 804/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 805/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 806/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 807/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 808/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 809/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 810/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.005
# Episode 811/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 812/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 813/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 814/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 815/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 816/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 817/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 818/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 819/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 820/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 821/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 822/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 823/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 824/1000 | Reward: 15.00 | Steps: 13 | Eps: 0.005
# Episode 825/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 826/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 827/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 828/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 829/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 830/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 831/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 832/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 833/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 834/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 835/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 836/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 837/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 838/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 839/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.005
# Episode 840/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 841/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 842/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 843/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 844/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 845/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 846/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 847/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 848/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 849/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 850/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 851/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 852/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 853/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 854/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 855/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 856/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 857/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 858/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 859/1000 | Reward: 15.00 | Steps: 11 | Eps: 0.005
# Episode 860/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 861/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 862/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 863/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 864/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 865/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 866/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 867/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 868/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 869/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 870/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 871/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 872/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 873/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 874/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 875/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 876/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 877/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 878/1000 | Reward: 15.00 | Steps: 16 | Eps: 0.005
# Episode 879/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 880/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 881/1000 | Reward: -15.00 | Steps: 8 | Eps: 0.005
# Episode 882/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 883/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 884/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 885/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 886/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 887/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 888/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 889/1000 | Reward: 15.00 | Steps: 12 | Eps: 0.005
# Episode 890/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 891/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 892/1000 | Reward: -15.00 | Steps: 8 | Eps: 0.005
# Episode 893/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 894/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 895/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 896/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 897/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.005
# Episode 898/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 899/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 900/1000 | Reward: -15.00 | Steps: 7 | Eps: 0.005
# Episode 901/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 902/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 903/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 904/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 905/1000 | Reward: -15.00 | Steps: 6 | Eps: 0.005
# Episode 906/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 907/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 908/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 909/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 910/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 911/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 912/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 913/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 914/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 915/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 916/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 917/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 918/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 919/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 920/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 921/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 922/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 923/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 924/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 925/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 926/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 927/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 928/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 929/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 930/1000 | Reward: -15.00 | Steps: 10 | Eps: 0.005
# Episode 931/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 932/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 933/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 934/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 935/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 936/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 937/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 938/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 939/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 940/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 941/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 942/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 943/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 944/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 945/1000 | Reward: 15.00 | Steps: 6 | Eps: 0.005
# Episode 946/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 947/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 948/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 949/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 950/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 951/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 952/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 953/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 954/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 955/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 956/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 957/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 958/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 959/1000 | Reward: 15.00 | Steps: 13 | Eps: 0.005
# Episode 960/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 961/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 962/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 963/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 964/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 965/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 966/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 967/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 968/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 969/1000 | Reward: -15.00 | Steps: 9 | Eps: 0.005
# Episode 970/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 971/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 972/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 973/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 974/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 975/1000 | Reward: 15.00 | Steps: 5 | Eps: 0.005
# Episode 976/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 977/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 978/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 979/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 980/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 981/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 982/1000 | Reward: -15.00 | Steps: 5 | Eps: 0.005
# Episode 983/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 984/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 985/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 986/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 987/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 988/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 989/1000 | Reward: 15.00 | Steps: 8 | Eps: 0.005
# Episode 990/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 991/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Episode 992/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 993/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 994/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 995/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 996/1000 | Reward: 15.00 | Steps: 7 | Eps: 0.005
# Episode 997/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 998/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 999/1000 | Reward: 15.00 | Steps: 9 | Eps: 0.005
# Episode 1000/1000 | Reward: 15.00 | Steps: 10 | Eps: 0.005
# Saved trained policy to 'policies/policy_net_1761786692.pth'

# %%
# -------------------------
# Evaluation (ε = 0)
# -------------------------
def evaluate_policy(env, model, episodes=20):
    rewards, lengths = [], []
    action_counts_eval = np.zeros(action_size, dtype=int)

    model.eval()
    with torch.no_grad():
        for ep in range(episodes):
            reset_output = env.reset()
            state = reset_output[0] if isinstance(reset_output, tuple) else reset_output
            state = np.array(state).flatten()
            done, total_reward, steps = False, 0, 0

            while not done:
                state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
                q_values = model(state_t)
                action = torch.argmax(q_values).item()

                step_output = env.step(action)
                if len(step_output) == 5:
                    next_state, reward, terminated, truncated, info = step_output
                    done = terminated or truncated
                else:
                    next_state, reward, done, info = step_output

                next_state = np.array(next_state).flatten()
                state = next_state
                total_reward += reward
                steps += 1
                action_counts_eval[action] += 1

            rewards.append(total_reward)
            lengths.append(steps)
            print("Eval Episode {}/{} | Reward: {:.2f} | Steps: {}".format(ep+1, episodes, total_reward, steps))
    print("Policy Accuracy: {:.2f}".format(100*(rewards.count(15) / episodes)))
    return np.mean(rewards), np.std(rewards), np.mean(lengths), np.std(lengths), action_counts_eval

mean_r, std_r, mean_l, std_l, eval_actions = evaluate_policy(env, policy_net, episodes=eval_episodes)
print("\nEvaluation over {} episodes:".format(eval_episodes))
print("Avg Reward: {:.2f} ± {:.2f}".format(mean_r, std_r))
print("Avg Length: {:.2f} ± {:.2f}".format(mean_l, std_l))
# Out:
# Eval Episode 1/200 | Reward: 15.00 | Steps: 9
# Eval Episode 2/200 | Reward: 15.00 | Steps: 9
# Eval Episode 3/200 | Reward: 15.00 | Steps: 9
# Eval Episode 4/200 | Reward: 15.00 | Steps: 8
# Eval Episode 5/200 | Reward: 15.00 | Steps: 9
# Eval Episode 6/200 | Reward: 15.00 | Steps: 7
# Eval Episode 7/200 | Reward: 15.00 | Steps: 12
# Eval Episode 8/200 | Reward: 15.00 | Steps: 8
# Eval Episode 9/200 | Reward: 15.00 | Steps: 7
# Eval Episode 10/200 | Reward: 15.00 | Steps: 11
# Eval Episode 11/200 | Reward: 15.00 | Steps: 9
# Eval Episode 12/200 | Reward: 15.00 | Steps: 9
# Eval Episode 13/200 | Reward: 15.00 | Steps: 8
# Eval Episode 14/200 | Reward: 15.00 | Steps: 7
# Eval Episode 15/200 | Reward: 15.00 | Steps: 7
# Eval Episode 16/200 | Reward: 15.00 | Steps: 9
# Eval Episode 17/200 | Reward: 15.00 | Steps: 9
# Eval Episode 18/200 | Reward: 15.00 | Steps: 9
# Eval Episode 19/200 | Reward: 15.00 | Steps: 8
# Eval Episode 20/200 | Reward: 15.00 | Steps: 9
# Eval Episode 21/200 | Reward: 15.00 | Steps: 8
# Eval Episode 22/200 | Reward: 15.00 | Steps: 9
# Eval Episode 23/200 | Reward: 15.00 | Steps: 9
# Eval Episode 24/200 | Reward: 15.00 | Steps: 9
# Eval Episode 25/200 | Reward: 15.00 | Steps: 9
# Eval Episode 26/200 | Reward: 15.00 | Steps: 8
# Eval Episode 27/200 | Reward: 15.00 | Steps: 8
# Eval Episode 28/200 | Reward: 15.00 | Steps: 8
# Eval Episode 29/200 | Reward: 15.00 | Steps: 8
# Eval Episode 30/200 | Reward: 15.00 | Steps: 11
# Eval Episode 31/200 | Reward: 15.00 | Steps: 8
# Eval Episode 32/200 | Reward: 15.00 | Steps: 6
# Eval Episode 33/200 | Reward: 15.00 | Steps: 9
# Eval Episode 34/200 | Reward: 15.00 | Steps: 8
# Eval Episode 35/200 | Reward: 15.00 | Steps: 7
# Eval Episode 36/200 | Reward: 15.00 | Steps: 9
# Eval Episode 37/200 | Reward: 15.00 | Steps: 6
# Eval Episode 38/200 | Reward: 15.00 | Steps: 9
# Eval Episode 39/200 | Reward: 15.00 | Steps: 8
# Eval Episode 40/200 | Reward: -15.00 | Steps: 9
# Eval Episode 41/200 | Reward: 15.00 | Steps: 8
# Eval Episode 42/200 | Reward: 15.00 | Steps: 9
# Eval Episode 43/200 | Reward: 15.00 | Steps: 7
# Eval Episode 44/200 | Reward: 15.00 | Steps: 10
# Eval Episode 45/200 | Reward: 15.00 | Steps: 10
# Eval Episode 46/200 | Reward: 15.00 | Steps: 8
# Eval Episode 47/200 | Reward: 15.00 | Steps: 7
# Eval Episode 48/200 | Reward: 15.00 | Steps: 8
# Eval Episode 49/200 | Reward: 15.00 | Steps: 8
# Eval Episode 50/200 | Reward: 15.00 | Steps: 11
# Eval Episode 51/200 | Reward: 15.00 | Steps: 7
# Eval Episode 52/200 | Reward: 15.00 | Steps: 9
# Eval Episode 53/200 | Reward: 15.00 | Steps: 8
# Eval Episode 54/200 | Reward: 15.00 | Steps: 9
# Eval Episode 55/200 | Reward: 15.00 | Steps: 7
# Eval Episode 56/200 | Reward: 15.00 | Steps: 9
# Eval Episode 57/200 | Reward: 15.00 | Steps: 9
# Eval Episode 58/200 | Reward: 15.00 | Steps: 8
# Eval Episode 59/200 | Reward: 15.00 | Steps: 9
# Eval Episode 60/200 | Reward: 15.00 | Steps: 8
# Eval Episode 61/200 | Reward: -15.00 | Steps: 10
# Eval Episode 62/200 | Reward: 15.00 | Steps: 8
# Eval Episode 63/200 | Reward: 15.00 | Steps: 6
# Eval Episode 64/200 | Reward: 15.00 | Steps: 8
# Eval Episode 65/200 | Reward: 15.00 | Steps: 9
# Eval Episode 66/200 | Reward: 15.00 | Steps: 7
# Eval Episode 67/200 | Reward: 15.00 | Steps: 6
# Eval Episode 68/200 | Reward: 15.00 | Steps: 8
# Eval Episode 69/200 | Reward: -15.00 | Steps: 9
# Eval Episode 70/200 | Reward: 15.00 | Steps: 7
# Eval Episode 71/200 | Reward: 15.00 | Steps: 7
# Eval Episode 72/200 | Reward: 15.00 | Steps: 8
# Eval Episode 73/200 | Reward: -15.00 | Steps: 10
# Eval Episode 74/200 | Reward: 15.00 | Steps: 9
# Eval Episode 75/200 | Reward: 15.00 | Steps: 7
# Eval Episode 76/200 | Reward: 15.00 | Steps: 10
# Eval Episode 77/200 | Reward: -15.00 | Steps: 8
# Eval Episode 78/200 | Reward: 15.00 | Steps: 9
# Eval Episode 79/200 | Reward: 15.00 | Steps: 9
# Eval Episode 80/200 | Reward: 15.00 | Steps: 7
# Eval Episode 81/200 | Reward: 15.00 | Steps: 8
# Eval Episode 82/200 | Reward: 15.00 | Steps: 7
# Eval Episode 83/200 | Reward: 15.00 | Steps: 9
# Eval Episode 84/200 | Reward: 15.00 | Steps: 7
# Eval Episode 85/200 | Reward: 15.00 | Steps: 9
# Eval Episode 86/200 | Reward: 15.00 | Steps: 7
# Eval Episode 87/200 | Reward: 15.00 | Steps: 6
# Eval Episode 88/200 | Reward: 15.00 | Steps: 5
# Eval Episode 89/200 | Reward: 15.00 | Steps: 9
# Eval Episode 90/200 | Reward: 15.00 | Steps: 8
# Eval Episode 91/200 | Reward: 15.00 | Steps: 8
# Eval Episode 92/200 | Reward: 15.00 | Steps: 7
# Eval Episode 93/200 | Reward: 15.00 | Steps: 8
# Eval Episode 94/200 | Reward: 15.00 | Steps: 9
# Eval Episode 95/200 | Reward: 15.00 | Steps: 9
# Eval Episode 96/200 | Reward: 15.00 | Steps: 9
# Eval Episode 97/200 | Reward: 15.00 | Steps: 8
# Eval Episode 98/200 | Reward: 15.00 | Steps: 8
# Eval Episode 99/200 | Reward: 15.00 | Steps: 7
# Eval Episode 100/200 | Reward: 15.00 | Steps: 9
# Eval Episode 101/200 | Reward: 15.00 | Steps: 11
# Eval Episode 102/200 | Reward: 15.00 | Steps: 9
# Eval Episode 103/200 | Reward: 15.00 | Steps: 8
# Eval Episode 104/200 | Reward: 15.00 | Steps: 8
# Eval Episode 105/200 | Reward: 15.00 | Steps: 8
# Eval Episode 106/200 | Reward: 15.00 | Steps: 8
# Eval Episode 107/200 | Reward: 15.00 | Steps: 9
# Eval Episode 108/200 | Reward: 15.00 | Steps: 9
# Eval Episode 109/200 | Reward: 15.00 | Steps: 10
# Eval Episode 110/200 | Reward: 15.00 | Steps: 7
# Eval Episode 111/200 | Reward: 15.00 | Steps: 7
# Eval Episode 112/200 | Reward: 15.00 | Steps: 8
# Eval Episode 113/200 | Reward: 15.00 | Steps: 9
# Eval Episode 114/200 | Reward: 15.00 | Steps: 9
# Eval Episode 115/200 | Reward: 15.00 | Steps: 8
# Eval Episode 116/200 | Reward: 15.00 | Steps: 9
# Eval Episode 117/200 | Reward: 15.00 | Steps: 10
# Eval Episode 118/200 | Reward: 15.00 | Steps: 7
# Eval Episode 119/200 | Reward: 15.00 | Steps: 7
# Eval Episode 120/200 | Reward: 15.00 | Steps: 8
# Eval Episode 121/200 | Reward: 15.00 | Steps: 9
# Eval Episode 122/200 | Reward: 15.00 | Steps: 8
# Eval Episode 123/200 | Reward: 15.00 | Steps: 8
# Eval Episode 124/200 | Reward: 15.00 | Steps: 8
# Eval Episode 125/200 | Reward: 15.00 | Steps: 10
# Eval Episode 126/200 | Reward: 15.00 | Steps: 6
# Eval Episode 127/200 | Reward: 15.00 | Steps: 8
# Eval Episode 128/200 | Reward: 15.00 | Steps: 6
# Eval Episode 129/200 | Reward: 15.00 | Steps: 8
# Eval Episode 130/200 | Reward: 15.00 | Steps: 8
# Eval Episode 131/200 | Reward: 15.00 | Steps: 8
# Eval Episode 132/200 | Reward: 15.00 | Steps: 9
# Eval Episode 133/200 | Reward: 15.00 | Steps: 8
# Eval Episode 134/200 | Reward: 15.00 | Steps: 8
# Eval Episode 135/200 | Reward: 15.00 | Steps: 9
# Eval Episode 136/200 | Reward: 15.00 | Steps: 9
# Eval Episode 137/200 | Reward: 15.00 | Steps: 7
# Eval Episode 138/200 | Reward: 15.00 | Steps: 9
# Eval Episode 139/200 | Reward: 15.00 | Steps: 8
# Eval Episode 140/200 | Reward: 15.00 | Steps: 7
# Eval Episode 141/200 | Reward: 15.00 | Steps: 9
# Eval Episode 142/200 | Reward: 15.00 | Steps: 8
# Eval Episode 143/200 | Reward: 15.00 | Steps: 9
# Eval Episode 144/200 | Reward: -15.00 | Steps: 4
# Eval Episode 145/200 | Reward: 15.00 | Steps: 11
# Eval Episode 146/200 | Reward: 15.00 | Steps: 7
# Eval Episode 147/200 | Reward: 15.00 | Steps: 10
# Eval Episode 148/200 | Reward: 15.00 | Steps: 8
# Eval Episode 149/200 | Reward: 15.00 | Steps: 11
# Eval Episode 150/200 | Reward: 15.00 | Steps: 9
# Eval Episode 151/200 | Reward: 15.00 | Steps: 8
# Eval Episode 152/200 | Reward: 15.00 | Steps: 9
# Eval Episode 153/200 | Reward: 15.00 | Steps: 9
# Eval Episode 154/200 | Reward: 15.00 | Steps: 9
# Eval Episode 155/200 | Reward: 15.00 | Steps: 10
# Eval Episode 156/200 | Reward: 15.00 | Steps: 7
# Eval Episode 157/200 | Reward: 15.00 | Steps: 8
# Eval Episode 158/200 | Reward: 15.00 | Steps: 8
# Eval Episode 159/200 | Reward: 15.00 | Steps: 6
# Eval Episode 160/200 | Reward: 15.00 | Steps: 9
# Eval Episode 161/200 | Reward: 15.00 | Steps: 7
# Eval Episode 162/200 | Reward: 15.00 | Steps: 7
# Eval Episode 163/200 | Reward: 15.00 | Steps: 7
# Eval Episode 164/200 | Reward: 15.00 | Steps: 6
# Eval Episode 165/200 | Reward: -15.00 | Steps: 8
# Eval Episode 166/200 | Reward: 15.00 | Steps: 9
# Eval Episode 167/200 | Reward: 15.00 | Steps: 10
# Eval Episode 168/200 | Reward: 15.00 | Steps: 9
# Eval Episode 169/200 | Reward: 15.00 | Steps: 8
# Eval Episode 170/200 | Reward: 15.00 | Steps: 9
# Eval Episode 171/200 | Reward: 15.00 | Steps: 9
# Eval Episode 172/200 | Reward: 15.00 | Steps: 9
# Eval Episode 173/200 | Reward: 15.00 | Steps: 8
# Eval Episode 174/200 | Reward: 15.00 | Steps: 8
# Eval Episode 175/200 | Reward: 15.00 | Steps: 7
# Eval Episode 176/200 | Reward: 15.00 | Steps: 8
# Eval Episode 177/200 | Reward: 15.00 | Steps: 10
# Eval Episode 178/200 | Reward: 15.00 | Steps: 9
# Eval Episode 179/200 | Reward: 15.00 | Steps: 9
# Eval Episode 180/200 | Reward: 15.00 | Steps: 6
# Eval Episode 181/200 | Reward: 15.00 | Steps: 4
# Eval Episode 182/200 | Reward: 15.00 | Steps: 8
# Eval Episode 183/200 | Reward: 15.00 | Steps: 9
# Eval Episode 184/200 | Reward: 15.00 | Steps: 7
# Eval Episode 185/200 | Reward: 15.00 | Steps: 7
# Eval Episode 186/200 | Reward: 15.00 | Steps: 8
# Eval Episode 187/200 | Reward: 15.00 | Steps: 7
# Eval Episode 188/200 | Reward: 15.00 | Steps: 8
# Eval Episode 189/200 | Reward: 15.00 | Steps: 9
# Eval Episode 190/200 | Reward: 15.00 | Steps: 11
# Eval Episode 191/200 | Reward: 15.00 | Steps: 7
# Eval Episode 192/200 | Reward: 15.00 | Steps: 7
# Eval Episode 193/200 | Reward: 15.00 | Steps: 8
# Eval Episode 194/200 | Reward: 15.00 | Steps: 6
# Eval Episode 195/200 | Reward: 15.00 | Steps: 8
# Eval Episode 196/200 | Reward: 15.00 | Steps: 9
# Eval Episode 197/200 | Reward: 15.00 | Steps: 7
# Eval Episode 198/200 | Reward: 15.00 | Steps: 9
# Eval Episode 199/200 | Reward: 15.00 | Steps: 7
# Eval Episode 200/200 | Reward: 15.00 | Steps: 6
# Policy Accuracy: 96.50
#
# Evaluation over 200 episodes:
# Avg Reward: 13.95 ± 5.51
# Avg Length: 8.21 ± 1.25

# %%
# -------------------------
# Visualizations (optional)
# -------------------------
directory_name = f"plots/{unique_id}"
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except Exception as e:
    print(f"An error occurred: {e}")

def visualize_q_distribution(model, n_samples=200):
    sampled_states = []
    for _ in range(n_samples):
        reset_output = env.reset()
        s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
        sampled_states.append(np.array(s).flatten())
    states_t = torch.FloatTensor(np.vstack(sampled_states)).to(device)
    with torch.no_grad():
        q_vals = model(states_t).cpu().numpy()
    plt.figure(figsize=(10,5))
    plt.boxplot(q_vals)
    plt.title("Distribution of Predicted Q-values per Action")
    plt.xlabel("Action Index")
    plt.ylabel("Q-value")
    plt.savefig(f"plots/{unique_id}/q_values.png")
    plt.show()
    plt.close()

visualize_q_distribution(policy_net)

plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
plt.plot(reward_history)
plt.title("Training Reward per Episode")
plt.xlabel("Episode"); plt.ylabel("Reward")

plt.subplot(2,3,2)
plt.plot(loss_history)
plt.title("Average Loss per Episode")
plt.xlabel("Episode"); plt.ylabel("Loss")

plt.subplot(2,3,3)
plt.plot(episode_length)
plt.title("Episode Length")
plt.xlabel("Episode"); plt.ylabel("Steps")

plt.subplot(2,3,4)
plt.bar(np.arange(action_size), action_counts)
plt.title("Action Distribution (Training)")
plt.xlabel("Action"); plt.ylabel("Count")

plt.subplot(2,3,5)
plt.bar(np.arange(action_size), eval_actions, color='orange')
plt.title("Action Distribution (Evaluation)")
plt.xlabel("Action"); plt.ylabel("Count")

plt.subplot(2,3,6)
plt.plot(epsilon_history)
plt.title("Epsilon Decay")
plt.xlabel("Episode"); plt.ylabel("Epsilon")

plt.tight_layout()
plt.savefig(f"plots/{unique_id}/training_plots.png")
plt.show()
plt.close()
# Out:
# Directory 'plots/1761786692' created successfully.

# %%
# -------------------------
# Feature gradient importance (optional)
# -------------------------
def compute_feature_loss_importance(model, memory, batch_size=256):
    if len(memory) < batch_size:
        print("Not enough samples in memory.")
        return None, None

    batch = random.sample(memory, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(np.vstack(states)).to(device)
    next_states = torch.FloatTensor(np.vstack(next_states)).to(device)
    actions = torch.LongTensor(actions).unsqueeze(1).to(device)
    rewards = torch.FloatTensor(rewards).unsqueeze(1).to(device)
    dones = torch.FloatTensor(dones).unsqueeze(1).to(device)

    states.requires_grad = True

    q_values = policy_net(states).gather(1, actions)
    next_actions = policy_net(next_states).argmax(1).unsqueeze(1)
    next_q_values = target_net(next_states).gather(1, next_actions).detach()
    target_q = rewards + (gamma * next_q_values * (1 - dones))

    loss = (q_values - target_q).pow(2).mean()
    loss.backward(retain_graph=True)

    grad_magnitudes = states.grad.abs().mean(dim=0).cpu().numpy()
    norm_grad = grad_magnitudes / (grad_magnitudes.sum() + 1e-8)

    feature_idx = np.arange(len(norm_grad))
    plt.figure(figsize=(16,10))
    feature_names = env.feature_names if hasattr(env, 'feature_names') else ["f{}".format(i) for i in range(state_size)]
    plt.bar(feature_names[0:46], norm_grad)
    plt.xticks(rotation=90)
    plt.title("Normalized Trajectory Loss Contribution by Feature")
    plt.ylabel("Normalized |dLoss/dFeature|")
    plt.savefig(f"plots/{unique_id}/loss_by_feature.png")
    plt.show()
    plt.close()

    return grad_magnitudes, norm_grad

# Run after training:
grad_mags, norm_grad = compute_feature_loss_importance(policy_net, memory)

# %%
# # -------------------------
# # === XRL MODULE 1: Policy Distillation -> Decision Tree
# # -------------------------
# from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
# from sklearn.metrics import accuracy_score

# directory_name = f"trees/{unique_id}"
# try:
#     os.mkdir(directory_name)
#     print(f"Directory '{directory_name}' created successfully.")
# except FileExistsError:
#     print(f"Directory '{directory_name}' already exists.")
# except Exception as e:
#     print(f"An error occurred: {e}")

# def distill_policy_to_tree(model, env, n_samples=3000, max_depth=4):
#     model.eval()
#     X, y = [], []

#     for _ in range(n_samples):
#         reset_output = env.reset()
#         s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
#         s = np.array(s).flatten()
#         X.append(s)

#         with torch.no_grad():
#             s_t = torch.FloatTensor(s).unsqueeze(0).to(device)
#             q_vals = model(s_t)
#             action = torch.argmax(q_vals).item()
#             y.append(action)

#     X = np.array(X)
#     y = np.array(y)

#     tree = DecisionTreeClassifier(max_depth=max_depth, random_state=42)
#     tree.fit(X, y)

#     fidelity = accuracy_score(y, tree.predict(X))
#     print("Distillation complete - Tree fidelity to policy: {:.2f}%".format(fidelity * 100))

#     with open(f"trees/{unique_id}/tree_fidelity.txt", 'w', encoding='utf-8') as file:
#         file.write("Distillation complete - Tree fidelity to policy: {:.2f}%".format(fidelity * 100))

#     plt.figure(figsize=(64, 40))
#     feature_names = getattr(env, "feature_names", ["f{}".format(i) for i in range(X.shape[1])])
#     plot_tree(tree, feature_names=feature_names[0:46],
#               class_names=[str(i) for i in range(env.action_space.n)], filled=True)
#     plt.title("Decision Tree Surrogate for Policy")
#     plt.savefig(f"plots/{unique_id}/decision_tree.png")
#     plt.show()
#     plt.close()

#     print(export_text(tree, feature_names=feature_names[0:46]))
#     return tree

# policy_tree = distill_policy_to_tree(policy_net, env, n_samples=3000, max_depth=4)

# # Save the tree if desired (pickle)
# try:
#     import pickle
#     with open(f"trees/{unique_id}/policy_tree.pkl", "wb") as f:
#         pickle.dump(policy_tree, f)
#     print("Saved tree as 'policy_tree.pkl'")
# except Exception as e:
#     print("Could not save tree: {}".format(e))

# %%
# # -------------------------
# # === XRL MODULE 1: Policy Distillation -> Random Forest with Soft Targets & Per-Action PDPs
# # -------------------------
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import accuracy_score, r2_score
# from sklearn.inspection import PartialDependenceDisplay
# import matplotlib.pyplot as plt
# import numpy as np
# import os
# import torch

# directory_name = f"trees/{unique_id}"
# try:
#     os.mkdir(directory_name)
#     print(f"Directory '{directory_name}' created successfully.")
# except FileExistsError:
#     print(f"Directory '{directory_name}' already exists.")
# except Exception as e:
#     print(f"An error occurred: {e}")


# def sample_policy_states(env, model, n_steps=5000):
#     """Collect realistic state samples by rolling out the trained policy."""
#     states = []
#     reset_output = env.reset()
#     s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
#     s = np.array(s).flatten()
#     done = False

#     while len(states) < n_steps:
#         states.append(s)
#         with torch.no_grad():
#             s_t = torch.FloatTensor(s).unsqueeze(0).to(device)
#             q_vals = model(s_t)
#             a = torch.argmax(q_vals).item()
#         step_output = env.step(a)
#         if len(step_output) == 5:
#             next_state, reward, terminated, truncated, info = step_output
#             done = terminated or truncated
#         else:
#             next_state, reward, done, info = step_output
#         s = np.array(next_state).flatten()
#         if done:
#             reset_output = env.reset()
#             s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
#             s = np.array(s).flatten()
#             done = False
#     return np.array(states)


# def distill_policy_to_forest(model, env, n_samples=5000, max_depth=6,
#                              use_feature_selection=True, top_pdp_features=3):
#     """Distill policy into a RandomForestRegressor trained on Q-values, with per-action PDPs."""
#     model.eval()
#     print("\n--- Sampling states from policy rollouts ---")
#     X = sample_policy_states(env, model, n_steps=n_samples)

#     print("Computing soft Q-targets from trained policy...")
#     Y = []
#     with torch.no_grad():
#         for s in X:
#             s_t = torch.FloatTensor(s).unsqueeze(0).to(device)
#             q_vals = model(s_t).cpu().numpy().flatten()
#             Y.append(q_vals)
#     Y = np.array(Y)

#     # --- Optional feature selection using gradient importance ---
#     feature_names = getattr(env, "feature_names",
#                             [f"f{i}" for i in range(X.shape[1])])
#     if use_feature_selection and 'norm_grad' in globals() and norm_grad is not None:
#         top_k = 15 if X.shape[1] > 15 else X.shape[1]
#         important_idx = np.argsort(norm_grad)[-top_k:]
#         X = X[:, important_idx]
#         selected_features = [feature_names[i] for i in important_idx]
#         print(f"Using top-{top_k} features based on gradient importance.")
#     else:
#         selected_features = feature_names

#     print("\n--- Training Random Forest on Q-value targets ---")
#     forest = RandomForestRegressor(
#         n_estimators=100,
#         max_depth=max_depth,
#         n_jobs=-1,
#         random_state=42
#     )
#     forest.fit(X, Y)

#     # --- Compute fidelity and R² metrics ---
#     preds = forest.predict(X)
#     fidelity = np.mean(np.argmax(preds, axis=1) == np.argmax(Y, axis=1))
#     r2 = r2_score(Y.flatten(), preds.flatten())
#     print(f"\nDistillation complete.")
#     print(f"Fidelity (argmax match): {fidelity*100:.2f}%")
#     print(f"R² on Q-values: {r2:.3f}")

#     # --- Save fidelity results ---
#     with open(f"trees/{unique_id}/forest_fidelity.txt", 'w', encoding='utf-8') as file:
#         file.write(f"Random Forest Distillation Results\n")
#         file.write(f"Fidelity (argmax match): {fidelity*100:.2f}%\n")
#         file.write(f"R² on Q-values: {r2:.3f}\n")

#     # --- Global feature importance ---
#     importances = forest.feature_importances_
#     sorted_idx = np.argsort(importances)[::-1]
#     plt.figure(figsize=(12, 6))
#     plt.bar(np.array(selected_features)[sorted_idx],
#             importances[sorted_idx], color='skyblue')
#     plt.xticks(rotation=90)
#     plt.title("Global Feature Importance (Random Forest)")
#     plt.ylabel("Importance")
#     plt.tight_layout()
#     plt.savefig(f"plots/{unique_id}/forest_feature_importance.png")
#     plt.show()
#     plt.close()

#     # --- Partial Dependence Plots (PDPs) for top features, per action ---
#     try:
#         print("\n--- Generating Partial Dependence Plots (PDPs) per Action ---")
#         top_features = [selected_features[i] for i in sorted_idx[:top_pdp_features]]
#         n_actions = Y.shape[1]

#         for action in range(n_actions):
#             print(f"Creating PDPs for Action {action}...")
#             fig, ax = plt.subplots(figsize=(6 * top_pdp_features, 5))
#             PartialDependenceDisplay.from_estimator(
#                 forest,
#                 X,
#                 features=list(range(min(top_pdp_features, len(selected_features)))),
#                 feature_names=selected_features,
#                 target=action,
#                 ax=ax
#             )
#             plt.suptitle(f"Partial Dependence (Action {action} Q-value)")
#             plt.tight_layout()
#             plt.savefig(f"plots/{unique_id}/forest_pdp_action{action}.png")
#             plt.close()
#     except Exception as e:
#         print(f"Could not generate PDPs: {e}")

#     # --- Save forest model ---
#     import pickle
#     with open(f"trees/{unique_id}/policy_forest.pkl", "wb") as f:
#         pickle.dump(forest, f)
#     print("Saved distilled forest as 'policy_forest.pkl'")

#     return forest, fidelity, r2


# # Run distillation
# policy_forest, fidelity, r2 = distill_policy_to_forest(
#     policy_net, env, n_samples=5000, max_depth=6,
#     use_feature_selection=True, top_pdp_features=3)

# %%
# === XRL MODULE 1: Policy Distillation -> Random Forest + PDP (legacy) + SHAP
# Compatible with Python 3.6.8 / scikit-learn <= 0.22
# -------------------------
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, r2_score
from sklearn.inspection import partial_dependence
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import shap
from dtreeviz.trees import dtreeviz
import pandas as pd


directory_name = f"trees/{unique_id}"
os.makedirs(directory_name, exist_ok=True)
os.makedirs(f"plots/{unique_id}/shap_summary_plots", exist_ok=True)
os.makedirs(f"plots/{unique_id}/forest_pdp_plots", exist_ok=True)
os.makedirs(f"plots/{unique_id}/dtree_plots", exist_ok=True)


def sample_policy_states(env, model, n_steps=5000):
    """Collect realistic state samples by rolling out the trained policy."""
    states = []
    reset_output = env.reset()
    s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
    s = np.array(s).flatten()
    done = False

    while len(states) < n_steps:
        states.append(s)
        with torch.no_grad():
            s_t = torch.FloatTensor(s).unsqueeze(0).to(device)
            q_vals = model(s_t)
            a = torch.argmax(q_vals).item()
        step_output = env.step(a)
        if len(step_output) == 5:
            next_state, reward, terminated, truncated, info = step_output
            done = terminated or truncated
        else:
            next_state, reward, done, info = step_output
        s = np.array(next_state).flatten()
        if done:
            reset_output = env.reset()
            s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
            s = np.array(s).flatten()
            done = False
    return np.array(states)


def distill_policy_to_forest(model, env, n_samples=5000, max_depth=6,
                             use_feature_selection=True, top_pdp_features=3):
    """Distill policy into a RandomForestRegressor trained on Q-values, with PDP & SHAP."""
    model.eval()
    print("\n--- Sampling states from policy rollouts ---")
    X = sample_policy_states(env, model, n_steps=n_samples)

    print("Computing soft Q-targets from trained policy...")
    Y = []
    with torch.no_grad():
        for s in X:
            s_t = torch.FloatTensor(s).unsqueeze(0).to(device)
            q_vals = model(s_t).cpu().numpy().flatten()
            Y.append(q_vals)
    Y = np.array(Y)

    feature_names = getattr(env, "feature_names",
                            [f"f{i}" for i in range(X.shape[1])])
    if use_feature_selection and 'norm_grad' in globals() and norm_grad is not None:
        top_k = 15 if X.shape[1] > 15 else X.shape[1]
        important_idx = np.argsort(norm_grad)[-top_k:]
        X = X[:, important_idx]
        selected_features = [feature_names[i] for i in important_idx]
        print(f"Using top-{top_k} features based on gradient importance.")
    else:
        selected_features = feature_names

    print("\n--- Training Random Forest on Q-value targets ---")
    forest = RandomForestRegressor(
        n_estimators=100, max_depth=max_depth, n_jobs=-1, random_state=42
    )
    forest.fit(X, Y)

    preds = forest.predict(X)
    fidelity = np.mean(np.argmax(preds, axis=1) == np.argmax(Y, axis=1))
    r2 = r2_score(Y.flatten(), preds.flatten())
    print(f"\nFidelity (argmax match): {fidelity*100:.2f}% | R²: {r2:.3f}")

    # --- Save fidelity results ---
    with open(f"trees/{unique_id}/forest_fidelity.txt", 'w', encoding='utf-8') as f:
        f.write("Random Forest Distillation Results\n")
        f.write(f"Fidelity (argmax match): {fidelity*100:.2f}%\n")
        f.write(f"R² on Q-values: {r2:.3f}\n")


    # --- Visualize one best decision tree per action using dtreeviz (Python 3.6.8 compatible) ---
    try:
        print("\n--- Visualizing one best-performing tree per action with dtreeviz ---")
        feature_names_viz = selected_features
        X_df = pd.DataFrame(X, columns=feature_names_viz)
        n_actions = Y.shape[1] if Y.ndim > 1 else 1

        for action_idx in range(n_actions):
            y_single = Y[:, action_idx]

            # Compute individual tree R² for this action
            scores = []
            for i, tree in enumerate(forest.estimators_):
                preds = tree.predict(X)
                if preds.ndim > 1:
                    preds = preds[:, action_idx]
                r2_i = r2_score(y_single, preds)
                scores.append(r2_i)

            best_idx = int(np.argmax(scores))
            best_tree = forest.estimators_[best_idx]
            print(f"Action {action_idx}: selected tree #{best_idx} with R²={scores[best_idx]:.3f}")

            viz = dtreeviz(
                best_tree,
                X_df,
                y_single,
                target_name=f"Q(Action {action_idx})",
                feature_names=feature_names_viz,
                title=f"Decision Tree #{best_idx} – Action {action_idx}",
                fancy=True,
                histtype='barstacked',
                scale=1.0
            )

            viz_path = f"plots/{unique_id}/dtree_plots/dtreeviz_best_tree_action{action_idx}.svg"
            viz.save(viz_path)
            print(f"Saved dtreeviz visualization for Action {action_idx} → {viz_path}")

        print("All dtreeviz visualizations complete.")

    except ImportError:
        print("dtreeviz not installed. Install with:")
        print("pip install dtreeviz==1.1.5 graphviz pydotplus")
    except Exception as e:
        print(f"Could not generate dtreeviz visualizations: {e}")


    # --- Summarize feature usage frequency across best trees (structure-level interpretability) ---
    try:
        print("\n--- Summarizing feature usage frequency across best trees ---")
        n_actions = Y.shape[1] if Y.ndim > 1 else 1   # ensure defined

        feature_usage_counts = {feat: 0 for feat in selected_features}
        action_best_trees = []

        for action_idx in range(n_actions):
            y_single = Y[:, action_idx]
            scores = []
            for i, tree in enumerate(forest.estimators_):
                preds = tree.predict(X)
                if preds.ndim > 1:
                    preds = preds[:, action_idx]
                r2_i = r2_score(y_single, preds)
                scores.append(r2_i)

            best_idx = int(np.argmax(scores))
            best_tree = forest.estimators_[best_idx]
            action_best_trees.append(best_tree)

            used_features = best_tree.tree_.feature
            for f_idx in used_features:
                if f_idx >= 0:  # skip leaves
                    feature_usage_counts[selected_features[f_idx]] += 1

        feature_usage_df = pd.DataFrame(
            list(feature_usage_counts.items()),
            columns=["Feature", "UsageCount"]
        ).sort_values("UsageCount", ascending=False)

        print("\nTop features used across best trees:")
        print(feature_usage_df.head(10))

        plt.figure(figsize=(10, 5))
        plt.bar(feature_usage_df["Feature"], feature_usage_df["UsageCount"], color='teal')
        plt.xticks(rotation=90)
        plt.title("Feature Usage Frequency Across Best Trees (All Actions)")
        plt.ylabel("Number of Splits (across trees)")
        plt.tight_layout()
        plt.savefig(f"plots/{unique_id}/feature_usage_best_trees.png")
        plt.close()

        feature_usage_df.to_csv(f"plots/{unique_id}/feature_usage_best_trees.csv", index=False)
        print(f"Feature usage summary saved to plots/{unique_id}/feature_usage_best_trees.png and .csv")

    except Exception as e:
        print(f"Could not summarize feature usage: {e}")





    # --- Global feature importance ---
    importances = forest.feature_importances_
    sorted_idx = np.argsort(importances)[::-1]
    plt.figure(figsize=(12, 6))
    plt.bar(np.array(selected_features)[sorted_idx],
            importances[sorted_idx], color='skyblue')
    plt.xticks(rotation=90)
    plt.title("Global Feature Importance (Random Forest)")
    plt.ylabel("Importance")
    plt.tight_layout()
    plt.savefig(f"plots/{unique_id}/forest_feature_importance.png")
    plt.show()
    plt.close()

    # --- PDPs (fully backward-compatible for sklearn <=0.25) ---
    try:
        print("\n--- Generating Partial Dependence Plots (legacy-safe mode) ---")
        from sklearn.inspection import partial_dependence

        top_features = [selected_features[i] for i in sorted_idx[:top_pdp_features]]
        n_actions = Y.shape[1]

        for action in range(n_actions):
            print(f"Creating PDPs for Action {action}...")
            for feat_name in top_features:
                feat_idx = selected_features.index(feat_name)

                # Call partial_dependence()
                pdp_out = partial_dependence(
                    forest,
                    X,
                    [feat_idx],
                    grid_resolution=80
                )

                # Handle different sklearn versions
                if isinstance(pdp_out, tuple):
                    avg, values = pdp_out  # old sklearn <=0.25
                elif isinstance(pdp_out, dict) or hasattr(pdp_out, "average"):
                    avg = pdp_out["average"]
                    values = pdp_out["values"]
                else:
                    raise TypeError("Unrecognized partial_dependence() output format")

                # Extract results per action
                if isinstance(avg, list) or avg.ndim == 3:
                    yvals = avg[0][action]
                else:
                    yvals = avg[0]

                xvals = values[0]

                # Plot PDP curve
                plt.figure(figsize=(5, 4))
                plt.plot(xvals, yvals, color='C0', lw=2)
                plt.title(f'PDP: {feat_name} → Q(Action {action})')
                plt.xlabel(feat_name)
                plt.ylabel('Partial Dependence')
                plt.grid(True, alpha=0.3)
                plt.tight_layout()
                plt.savefig(f"plots/{unique_id}/forest_pdp_plots/forest_pdp_action{action}_{feat_name}.png")
                plt.close()

        print("PDP generation complete.")
    except Exception as e:
        print(f"Could not generate PDPs: {e}")



    # --- SHAP value visualizations ---
    try:
        print("\n--- Computing SHAP values (TreeExplainer) ---")
        explainer = shap.TreeExplainer(forest)
        # Use subset for performance
        X_sample = X[:min(1000, len(X))]
        shap_values = explainer.shap_values(X_sample)

        # Global summary (averaged across actions)
        if isinstance(shap_values, list):
            shap_values_mean = np.mean([np.abs(sv) for sv in shap_values], axis=0)
        else:
            shap_values_mean = np.abs(shap_values)
        shap.summary_plot(shap_values_mean, X_sample,
                          feature_names=selected_features,
                          show=False)
        plt.title("SHAP Summary (Mean |SHAP| across actions)")
        plt.tight_layout()
        plt.savefig(f"plots/{unique_id}/shap_summary_global.png")
        plt.close()

        # Local dependence for top feature, first action
        if isinstance(shap_values, list):
            shap.dependence_plot(0, shap_values[0], X_sample,
                                 feature_names=selected_features,
                                 show=False)
        else:
            shap.dependence_plot(0, shap_values, X_sample,
                                 feature_names=selected_features,
                                 show=False)
        plt.title("SHAP Dependence: Top Feature vs Q(Action 0)")
        plt.tight_layout()
        plt.savefig(f"plots/{unique_id}/shap_dependence_action0.png")
        plt.close()

        # === NEW: Per-Action SHAP Summaries ===
        print("\n--- Generating per-action SHAP summary plots ---")
        if isinstance(shap_values, list):
            n_actions = len(shap_values)
            for action_idx, sv in enumerate(shap_values):
                plt.figure()
                shap.summary_plot(sv, X_sample, feature_names=selected_features,
                                  show=False, max_display=15)
                plt.title(f"SHAP Summary: Action {action_idx} (Q-value)")
                plt.tight_layout()
                plt.savefig(f"plots/{unique_id}/shap_summary_plots/shap_summary_action{action_idx}.png")
                plt.close()
        else:
            print("Single output model: per-action SHAP summaries not applicable.")

        print("SHAP plots saved successfully.")
    except Exception as e:
        print(f"Could not compute SHAP values: {e}")


    # --- Save forest model ---
    import pickle
    with open(f"trees/{unique_id}/policy_forest.pkl", "wb") as f:
        pickle.dump(forest, f)
    print("Saved distilled forest as 'policy_forest.pkl'")

    return forest, fidelity, r2


# Run distillation
policy_forest, fidelity, r2 = distill_policy_to_forest(
    policy_net, env, n_samples=5000, max_depth=6,
    use_feature_selection=True, top_pdp_features=3)
# Out:
# --- Sampling states from policy rollouts ---
# Computing soft Q-targets from trained policy...
# Using top-15 features based on gradient importance.
#
# --- Training Random Forest on Q-value targets ---
#
# Fidelity (argmax match): 37.08% | R²: 0.814
#
# --- Visualizing one best-performing tree per action with dtreeviz ---
# Action 0: selected tree #78 with R²=0.786
# Saved dtreeviz visualization for Action 0 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action0.svg
# Action 1: selected tree #78 with R²=0.792
# Saved dtreeviz visualization for Action 1 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action1.svg
# Action 2: selected tree #78 with R²=0.811
# Saved dtreeviz visualization for Action 2 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action2.svg
# Action 3: selected tree #78 with R²=0.786
# Saved dtreeviz visualization for Action 3 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action3.svg
# Action 4: selected tree #77 with R²=0.811
# Saved dtreeviz visualization for Action 4 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action4.svg
# Action 5: selected tree #77 with R²=0.785
# Saved dtreeviz visualization for Action 5 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action5.svg
# Action 6: selected tree #78 with R²=0.794
# Saved dtreeviz visualization for Action 6 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action6.svg
# Action 7: selected tree #77 with R²=0.811
# Saved dtreeviz visualization for Action 7 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action7.svg
# Action 8: selected tree #77 with R²=0.789
# Saved dtreeviz visualization for Action 8 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action8.svg
# Action 9: selected tree #78 with R²=0.787
# Saved dtreeviz visualization for Action 9 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action9.svg
# Action 10: selected tree #78 with R²=0.791
# Saved dtreeviz visualization for Action 10 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action10.svg
# Action 11: selected tree #78 with R²=0.788
# Saved dtreeviz visualization for Action 11 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action11.svg
# Action 12: selected tree #78 with R²=0.795
# Saved dtreeviz visualization for Action 12 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action12.svg
# Action 13: selected tree #78 with R²=0.786
# Saved dtreeviz visualization for Action 13 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action13.svg
# Action 14: selected tree #77 with R²=0.805
# Saved dtreeviz visualization for Action 14 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action14.svg
# Action 15: selected tree #77 with R²=0.803
# Saved dtreeviz visualization for Action 15 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action15.svg
# Action 16: selected tree #78 with R²=0.807
# Saved dtreeviz visualization for Action 16 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action16.svg
# Action 17: selected tree #77 with R²=0.787
# Saved dtreeviz visualization for Action 17 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action17.svg
# Action 18: selected tree #78 with R²=0.790
# Saved dtreeviz visualization for Action 18 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action18.svg
# Action 19: selected tree #77 with R²=0.806
# Saved dtreeviz visualization for Action 19 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action19.svg
# Action 20: selected tree #77 with R²=0.809
# Saved dtreeviz visualization for Action 20 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action20.svg
# Action 21: selected tree #78 with R²=0.791
# Saved dtreeviz visualization for Action 21 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action21.svg
# Action 22: selected tree #89 with R²=0.795
# Saved dtreeviz visualization for Action 22 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action22.svg
# Action 23: selected tree #78 with R²=0.789
# Saved dtreeviz visualization for Action 23 → plots/1761786692/dtree_plots/dtreeviz_best_tree_action23.svg
# All dtreeviz visualizations complete.
#
# --- Summarizing feature usage frequency across best trees ---
#
# Top features used across best trees:
#                    Feature  UsageCount
# 13                    lods         149
# 10                    SpO2         135
# 14                 ALBUMIN         111
# 7                 CHLORIDE         102
# 5                 PLATELET          84
# 6                ANION GAP          78
# 9   blood_culture_positive          77
# 3                    BANDS          64
# 4                    SysBP          58
# 12                  weight          55
# Feature usage summary saved to plots/1761786692/feature_usage_best_trees.png and .csv
# --- Generating Partial Dependence Plots (legacy-safe mode) ---
# Creating PDPs for Action 0...
# A Bunch will be returned in place of 'predictions' from version 1.1 (renaming of 0.26) with partial dependence results accessible via the 'average' key. In the meantime, pass kind='average' to get the future behaviour.
# Creating PDPs for Action 1...
# Creating PDPs for Action 2...
# Creating PDPs for Action 3...
# Creating PDPs for Action 4...
# Creating PDPs for Action 5...
# Creating PDPs for Action 6...
# Creating PDPs for Action 7...
# Creating PDPs for Action 8...
# Creating PDPs for Action 9...
# Creating PDPs for Action 10...
# Creating PDPs for Action 11...
# Creating PDPs for Action 12...
# Creating PDPs for Action 13...
# Creating PDPs for Action 14...
# Creating PDPs for Action 15...
# Creating PDPs for Action 16...
# Creating PDPs for Action 17...
# Creating PDPs for Action 18...
# Creating PDPs for Action 19...
# Creating PDPs for Action 20...
# Creating PDPs for Action 21...
# Creating PDPs for Action 22...
# Creating PDPs for Action 23...
# PDP generation complete.
#
# --- Computing SHAP values (TreeExplainer) ---
#
# --- Generating per-action SHAP summary plots ---
# SHAP plots saved successfully.
# Saved distilled forest as 'policy_forest.pkl'
