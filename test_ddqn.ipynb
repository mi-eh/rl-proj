# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import random
# import numpy as np
# from collections import deque
# from gym_sepsis.envs.sepsis_env import SepsisEnv

# %%
# env = SepsisEnv()

# %%
from gym_sepsis.envs.sepsis_env import SepsisEnv
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt

# -----------------------------------------------------
# Device setup
# -----------------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# -----------------------------------------------------
# Environment setup
# -----------------------------------------------------
env = SepsisEnv()

reset_output = env.reset()
if isinstance(reset_output, tuple):
    state = reset_output[0]
else:
    state = reset_output
state = np.array(state).flatten()

state_size = len(state)
action_size = env.action_space.n

print("State size:", state_size)
print("Action size:", action_size)

# -----------------------------------------------------
# Q-network (shared by online and target)
# -----------------------------------------------------
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# -----------------------------------------------------
# Hyperparameters
# -----------------------------------------------------
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.995
lr = 1e-3
batch_size = 64
memory_size = 20000
num_episodes = 500
target_update_freq = 10
eval_episodes = 20  # number of episodes for testing

# -----------------------------------------------------
# Initialize networks, optimizer, memory
# -----------------------------------------------------
policy_net = QNetwork(state_size, action_size).to(device)
target_net = QNetwork(state_size, action_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
loss_fn = nn.MSELoss()
memory = deque(maxlen=memory_size)

# -----------------------------------------------------
# Helper functions
# -----------------------------------------------------
def get_action(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
        q_values = policy_net(state_t)
        return torch.argmax(q_values).item()

def replay():
    if len(memory) < batch_size:
        return None
    
    batch = random.sample(memory, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(np.vstack(states)).to(device)
    next_states = torch.FloatTensor(np.vstack(next_states)).to(device)
    actions = torch.LongTensor(actions).unsqueeze(1).to(device)
    rewards = torch.FloatTensor(rewards).unsqueeze(1).to(device)
    dones = torch.FloatTensor(dones).unsqueeze(1).to(device)

    # Q-learning (Double DQN)
    q_values = policy_net(states).gather(1, actions)
    next_actions = policy_net(next_states).argmax(1).unsqueeze(1)
    next_q_values = target_net(next_states).gather(1, next_actions).detach()
    target_q = rewards + (gamma * next_q_values * (1 - dones))

    loss = loss_fn(q_values, target_q)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return loss.item()

# -----------------------------------------------------
# Training loop
# -----------------------------------------------------
reward_history, loss_history, episode_length = [], [], []
epsilon_history, action_counts = [], np.zeros(action_size, dtype=int)

for episode in range(num_episodes):
    reset_output = env.reset()
    state = reset_output[0] if isinstance(reset_output, tuple) else reset_output
    state = np.array(state).flatten()
    done, total_reward, steps = False, 0, 0
    episode_losses = []

    while not done:
        action = get_action(state, epsilon)
        step_output = env.step(action)
        if len(step_output) == 5:
            next_state, reward, terminated, truncated, info = step_output
            done = terminated or truncated
        else:
            next_state, reward, done, info = step_output
        next_state = np.array(next_state).flatten()

        memory.append((state, action, reward, next_state, float(done)))
        state = next_state
        total_reward += reward
        steps += 1
        action_counts[action] += 1

        loss_val = replay()
        if loss_val is not None:
            episode_losses.append(loss_val)

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    if episode % target_update_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())

    reward_history.append(total_reward)
    epsilon_history.append(epsilon)
    episode_length.append(steps)
    loss_history.append(np.mean(episode_losses) if episode_losses else 0)

    print(f"Episode {episode+1}/{num_episodes} | Reward: {total_reward:.2f} | Steps: {steps} | Eps: {epsilon:.3f}")

# -----------------------------------------------------
# Evaluation (ε = 0)
# -----------------------------------------------------
def evaluate_policy(env, model, episodes=20):
    rewards, lengths = [], []
    action_counts_eval = np.zeros(action_size, dtype=int)

    model.eval()
    with torch.no_grad():
        for ep in range(episodes):
            reset_output = env.reset()
            state = reset_output[0] if isinstance(reset_output, tuple) else reset_output
            state = np.array(state).flatten()
            done, total_reward, steps = False, 0, 0

            while not done:
                state_t = torch.FloatTensor(state).unsqueeze(0).to(device)
                q_values = model(state_t)
                action = torch.argmax(q_values).item()

                step_output = env.step(action)
                if len(step_output) == 5:
                    next_state, reward, terminated, truncated, info = step_output
                    done = terminated or truncated
                else:
                    next_state, reward, done, info = step_output

                next_state = np.array(next_state).flatten()
                state = next_state
                total_reward += reward
                steps += 1
                action_counts_eval[action] += 1

            rewards.append(total_reward)
            lengths.append(steps)
            print(f"Eval Episode {ep+1}/{episodes} | Reward: {total_reward:.2f} | Steps: {steps}")

    return np.mean(rewards), np.std(rewards), np.mean(lengths), np.std(lengths), action_counts_eval

mean_r, std_r, mean_l, std_l, eval_actions = evaluate_policy(env, policy_net, episodes=eval_episodes)
print(f"\nEvaluation over {eval_episodes} episodes:")
print(f"Avg Reward: {mean_r:.2f} ± {std_r:.2f}")
print(f"Avg Length: {mean_l:.2f} ± {std_l:.2f}")

# -----------------------------------------------------
# Q-value landscape inspection
# -----------------------------------------------------
def visualize_q_distribution(model, n_samples=200):
    """Plots distribution of Q-values over random sampled states."""
    sampled_states = []
    for _ in range(n_samples):
        reset_output = env.reset()
        s = reset_output[0] if isinstance(reset_output, tuple) else reset_output
        sampled_states.append(np.array(s).flatten())
    states_t = torch.FloatTensor(np.vstack(sampled_states)).to(device)
    with torch.no_grad():
        q_vals = model(states_t).cpu().numpy()
    plt.figure(figsize=(10,5))
    plt.boxplot(q_vals)
    plt.title("Distribution of Predicted Q-values per Action")
    plt.xlabel("Action Index")
    plt.ylabel("Q-value")
    plt.show()

visualize_q_distribution(policy_net)
# Out:
# Using device: cpu
# State size: 46
# Action size: 24
# Episode 1/500 | Reward: 15.00 | Steps: 9 | Eps: 0.995
# Episode 2/500 | Reward: 15.00 | Steps: 10 | Eps: 0.990
# Episode 3/500 | Reward: 15.00 | Steps: 9 | Eps: 0.985
# Episode 4/500 | Reward: 15.00 | Steps: 9 | Eps: 0.980
# Episode 5/500 | Reward: 15.00 | Steps: 10 | Eps: 0.975
# Episode 6/500 | Reward: -15.00 | Steps: 5 | Eps: 0.970
# Episode 7/500 | Reward: 15.00 | Steps: 9 | Eps: 0.966
# Episode 8/500 | Reward: 15.00 | Steps: 10 | Eps: 0.961
# Episode 9/500 | Reward: 15.00 | Steps: 9 | Eps: 0.956
# Episode 10/500 | Reward: 15.00 | Steps: 10 | Eps: 0.951
# Episode 11/500 | Reward: -15.00 | Steps: 8 | Eps: 0.946
# Episode 12/500 | Reward: 15.00 | Steps: 9 | Eps: 0.942
# Episode 13/500 | Reward: 15.00 | Steps: 9 | Eps: 0.937
# Episode 14/500 | Reward: 15.00 | Steps: 10 | Eps: 0.932
# Episode 15/500 | Reward: 15.00 | Steps: 9 | Eps: 0.928
# Episode 16/500 | Reward: 15.00 | Steps: 10 | Eps: 0.923
# Episode 17/500 | Reward: 15.00 | Steps: 9 | Eps: 0.918
# Episode 18/500 | Reward: 15.00 | Steps: 10 | Eps: 0.914
# Episode 19/500 | Reward: 15.00 | Steps: 9 | Eps: 0.909
# Episode 20/500 | Reward: 15.00 | Steps: 9 | Eps: 0.905
# Episode 21/500 | Reward: 15.00 | Steps: 10 | Eps: 0.900
# Episode 22/500 | Reward: 15.00 | Steps: 9 | Eps: 0.896
# Episode 23/500 | Reward: 15.00 | Steps: 9 | Eps: 0.891
# Episode 24/500 | Reward: -15.00 | Steps: 9 | Eps: 0.887
# Episode 25/500 | Reward: -15.00 | Steps: 9 | Eps: 0.882
# Episode 26/500 | Reward: -15.00 | Steps: 10 | Eps: 0.878
# Episode 27/500 | Reward: 15.00 | Steps: 9 | Eps: 0.873
# Episode 28/500 | Reward: 15.00 | Steps: 10 | Eps: 0.869
# Episode 29/500 | Reward: 15.00 | Steps: 10 | Eps: 0.865
# Episode 30/500 | Reward: 15.00 | Steps: 10 | Eps: 0.860
# Episode 31/500 | Reward: 15.00 | Steps: 10 | Eps: 0.856
# Episode 32/500 | Reward: 15.00 | Steps: 9 | Eps: 0.852
# Episode 33/500 | Reward: 15.00 | Steps: 9 | Eps: 0.848
# Episode 34/500 | Reward: 15.00 | Steps: 9 | Eps: 0.843
# Episode 35/500 | Reward: 15.00 | Steps: 9 | Eps: 0.839
# Episode 36/500 | Reward: 15.00 | Steps: 10 | Eps: 0.835
# Episode 37/500 | Reward: 15.00 | Steps: 9 | Eps: 0.831
# Episode 38/500 | Reward: -15.00 | Steps: 10 | Eps: 0.827
# Episode 39/500 | Reward: 15.00 | Steps: 9 | Eps: 0.822
# Episode 40/500 | Reward: 15.00 | Steps: 10 | Eps: 0.818
# Episode 41/500 | Reward: 15.00 | Steps: 9 | Eps: 0.814
# Episode 42/500 | Reward: -15.00 | Steps: 9 | Eps: 0.810
# Episode 43/500 | Reward: 15.00 | Steps: 10 | Eps: 0.806
# Episode 44/500 | Reward: 15.00 | Steps: 10 | Eps: 0.802
# Episode 45/500 | Reward: 15.00 | Steps: 10 | Eps: 0.798
# Episode 46/500 | Reward: 15.00 | Steps: 9 | Eps: 0.794
# Episode 47/500 | Reward: 15.00 | Steps: 9 | Eps: 0.790
# Episode 48/500 | Reward: 15.00 | Steps: 9 | Eps: 0.786
# Episode 49/500 | Reward: -15.00 | Steps: 9 | Eps: 0.782
# Episode 50/500 | Reward: 15.00 | Steps: 9 | Eps: 0.778
# Episode 51/500 | Reward: 15.00 | Steps: 10 | Eps: 0.774
# Episode 52/500 | Reward: 15.00 | Steps: 10 | Eps: 0.771
# Episode 53/500 | Reward: 15.00 | Steps: 9 | Eps: 0.767
# Episode 54/500 | Reward: 15.00 | Steps: 10 | Eps: 0.763
# Episode 55/500 | Reward: 15.00 | Steps: 9 | Eps: 0.759
# Episode 56/500 | Reward: 15.00 | Steps: 10 | Eps: 0.755
# Episode 57/500 | Reward: 15.00 | Steps: 10 | Eps: 0.751
# Episode 58/500 | Reward: 15.00 | Steps: 9 | Eps: 0.748
# Episode 59/500 | Reward: 15.00 | Steps: 10 | Eps: 0.744
# Episode 60/500 | Reward: 15.00 | Steps: 9 | Eps: 0.740
# Episode 61/500 | Reward: 15.00 | Steps: 9 | Eps: 0.737
# Episode 62/500 | Reward: 15.00 | Steps: 9 | Eps: 0.733
# Episode 63/500 | Reward: 15.00 | Steps: 9 | Eps: 0.729
# Episode 64/500 | Reward: 15.00 | Steps: 9 | Eps: 0.726
# Episode 65/500 | Reward: 15.00 | Steps: 10 | Eps: 0.722
# Episode 66/500 | Reward: 15.00 | Steps: 9 | Eps: 0.718
# Episode 67/500 | Reward: 15.00 | Steps: 9 | Eps: 0.715
# Episode 68/500 | Reward: 15.00 | Steps: 9 | Eps: 0.711
# Episode 69/500 | Reward: 15.00 | Steps: 10 | Eps: 0.708
# Episode 70/500 | Reward: 15.00 | Steps: 9 | Eps: 0.704
# Episode 71/500 | Reward: 15.00 | Steps: 10 | Eps: 0.701
# Episode 72/500 | Reward: 15.00 | Steps: 9 | Eps: 0.697
# Episode 73/500 | Reward: 15.00 | Steps: 9 | Eps: 0.694
# Episode 74/500 | Reward: 15.00 | Steps: 9 | Eps: 0.690
# Episode 75/500 | Reward: 15.00 | Steps: 9 | Eps: 0.687
# Episode 76/500 | Reward: 15.00 | Steps: 10 | Eps: 0.683
# Episode 77/500 | Reward: 15.00 | Steps: 9 | Eps: 0.680
# Episode 78/500 | Reward: 15.00 | Steps: 10 | Eps: 0.676
# Episode 79/500 | Reward: 15.00 | Steps: 9 | Eps: 0.673
# Episode 80/500 | Reward: 15.00 | Steps: 10 | Eps: 0.670
# Episode 81/500 | Reward: 15.00 | Steps: 9 | Eps: 0.666
# Episode 82/500 | Reward: 15.00 | Steps: 9 | Eps: 0.663
# Episode 83/500 | Reward: 15.00 | Steps: 9 | Eps: 0.660
# Episode 84/500 | Reward: 15.00 | Steps: 11 | Eps: 0.656
# Episode 85/500 | Reward: 15.00 | Steps: 9 | Eps: 0.653
# Episode 86/500 | Reward: 15.00 | Steps: 10 | Eps: 0.650
# Episode 87/500 | Reward: 15.00 | Steps: 9 | Eps: 0.647
# Episode 88/500 | Reward: 15.00 | Steps: 9 | Eps: 0.643
# Episode 89/500 | Reward: 15.00 | Steps: 9 | Eps: 0.640
# Episode 90/500 | Reward: 15.00 | Steps: 10 | Eps: 0.637
# Episode 91/500 | Reward: 15.00 | Steps: 10 | Eps: 0.634
# Episode 92/500 | Reward: 15.00 | Steps: 10 | Eps: 0.631
# Episode 93/500 | Reward: 15.00 | Steps: 9 | Eps: 0.627
# Episode 94/500 | Reward: -15.00 | Steps: 10 | Eps: 0.624
# Episode 95/500 | Reward: 15.00 | Steps: 10 | Eps: 0.621
# Episode 96/500 | Reward: -15.00 | Steps: 3 | Eps: 0.618
# Episode 97/500 | Reward: 15.00 | Steps: 9 | Eps: 0.615
# Episode 98/500 | Reward: 15.00 | Steps: 9 | Eps: 0.612
# Episode 99/500 | Reward: 15.00 | Steps: 9 | Eps: 0.609
# Episode 100/500 | Reward: 15.00 | Steps: 9 | Eps: 0.606
# Episode 101/500 | Reward: 15.00 | Steps: 8 | Eps: 0.603
# Episode 102/500 | Reward: -15.00 | Steps: 10 | Eps: 0.600
# Episode 103/500 | Reward: 15.00 | Steps: 9 | Eps: 0.597
# Episode 104/500 | Reward: 15.00 | Steps: 9 | Eps: 0.594
# Episode 105/500 | Reward: 15.00 | Steps: 8 | Eps: 0.591
# Episode 106/500 | Reward: 15.00 | Steps: 9 | Eps: 0.588
# Episode 107/500 | Reward: 15.00 | Steps: 10 | Eps: 0.585
# Episode 108/500 | Reward: -15.00 | Steps: 7 | Eps: 0.582
# Episode 109/500 | Reward: 15.00 | Steps: 9 | Eps: 0.579
# Episode 110/500 | Reward: 15.00 | Steps: 9 | Eps: 0.576
# Episode 111/500 | Reward: 15.00 | Steps: 11 | Eps: 0.573
# Episode 112/500 | Reward: 15.00 | Steps: 9 | Eps: 0.570
# Episode 113/500 | Reward: 15.00 | Steps: 9 | Eps: 0.568
# Episode 114/500 | Reward: 15.00 | Steps: 8 | Eps: 0.565
# Episode 115/500 | Reward: 15.00 | Steps: 9 | Eps: 0.562
# Episode 116/500 | Reward: 15.00 | Steps: 10 | Eps: 0.559
# Episode 117/500 | Reward: 15.00 | Steps: 10 | Eps: 0.556
# Episode 118/500 | Reward: 15.00 | Steps: 9 | Eps: 0.554
# Episode 119/500 | Reward: 15.00 | Steps: 10 | Eps: 0.551
# Episode 120/500 | Reward: 15.00 | Steps: 9 | Eps: 0.548
# Episode 121/500 | Reward: 15.00 | Steps: 10 | Eps: 0.545
# Episode 122/500 | Reward: 15.00 | Steps: 9 | Eps: 0.543
# Episode 123/500 | Reward: 15.00 | Steps: 9 | Eps: 0.540
# Episode 124/500 | Reward: 15.00 | Steps: 10 | Eps: 0.537
# Episode 125/500 | Reward: 15.00 | Steps: 9 | Eps: 0.534
# Episode 126/500 | Reward: 15.00 | Steps: 10 | Eps: 0.532
# Episode 127/500 | Reward: 15.00 | Steps: 10 | Eps: 0.529
# Episode 128/500 | Reward: 15.00 | Steps: 10 | Eps: 0.526
# Episode 129/500 | Reward: 15.00 | Steps: 10 | Eps: 0.524
# Episode 130/500 | Reward: 15.00 | Steps: 9 | Eps: 0.521
# Episode 131/500 | Reward: 15.00 | Steps: 9 | Eps: 0.519
# Episode 132/500 | Reward: 15.00 | Steps: 9 | Eps: 0.516
# Episode 133/500 | Reward: 15.00 | Steps: 10 | Eps: 0.513
# Episode 134/500 | Reward: 15.00 | Steps: 10 | Eps: 0.511
# Episode 135/500 | Reward: 15.00 | Steps: 10 | Eps: 0.508
# Episode 136/500 | Reward: 15.00 | Steps: 8 | Eps: 0.506
# Episode 137/500 | Reward: 15.00 | Steps: 10 | Eps: 0.503
# Episode 138/500 | Reward: 15.00 | Steps: 10 | Eps: 0.501
# Episode 139/500 | Reward: 15.00 | Steps: 10 | Eps: 0.498
# Episode 140/500 | Reward: 15.00 | Steps: 10 | Eps: 0.496
# Episode 141/500 | Reward: 15.00 | Steps: 9 | Eps: 0.493
# Episode 142/500 | Reward: 15.00 | Steps: 9 | Eps: 0.491
# Episode 143/500 | Reward: 15.00 | Steps: 10 | Eps: 0.488
# Episode 144/500 | Reward: 15.00 | Steps: 9 | Eps: 0.486
# Episode 145/500 | Reward: 15.00 | Steps: 9 | Eps: 0.483
# Episode 146/500 | Reward: 15.00 | Steps: 9 | Eps: 0.481
# Episode 147/500 | Reward: 15.00 | Steps: 10 | Eps: 0.479
# Episode 148/500 | Reward: 15.00 | Steps: 9 | Eps: 0.476
# Episode 149/500 | Reward: 15.00 | Steps: 9 | Eps: 0.474
# Episode 150/500 | Reward: 15.00 | Steps: 10 | Eps: 0.471
# Episode 151/500 | Reward: 15.00 | Steps: 10 | Eps: 0.469
# Episode 152/500 | Reward: 15.00 | Steps: 9 | Eps: 0.467
# Episode 153/500 | Reward: 15.00 | Steps: 9 | Eps: 0.464
# Episode 154/500 | Reward: 15.00 | Steps: 9 | Eps: 0.462
# Episode 155/500 | Reward: 15.00 | Steps: 9 | Eps: 0.460
# Episode 156/500 | Reward: 15.00 | Steps: 9 | Eps: 0.458
# Episode 157/500 | Reward: 15.00 | Steps: 10 | Eps: 0.455
# Episode 158/500 | Reward: 15.00 | Steps: 10 | Eps: 0.453
# Episode 159/500 | Reward: 15.00 | Steps: 10 | Eps: 0.451
# Episode 160/500 | Reward: 15.00 | Steps: 9 | Eps: 0.448
# Episode 161/500 | Reward: 15.00 | Steps: 9 | Eps: 0.446
# Episode 162/500 | Reward: 15.00 | Steps: 10 | Eps: 0.444
# Episode 163/500 | Reward: 15.00 | Steps: 10 | Eps: 0.442
# Episode 164/500 | Reward: 15.00 | Steps: 9 | Eps: 0.440
# Episode 165/500 | Reward: 15.00 | Steps: 9 | Eps: 0.437
# Episode 166/500 | Reward: 15.00 | Steps: 10 | Eps: 0.435
# Episode 167/500 | Reward: 15.00 | Steps: 9 | Eps: 0.433
# Episode 168/500 | Reward: 15.00 | Steps: 10 | Eps: 0.431
# Episode 169/500 | Reward: 15.00 | Steps: 9 | Eps: 0.429
# Episode 170/500 | Reward: 15.00 | Steps: 10 | Eps: 0.427
# Episode 171/500 | Reward: 15.00 | Steps: 9 | Eps: 0.424
# Episode 172/500 | Reward: 15.00 | Steps: 9 | Eps: 0.422
# Episode 173/500 | Reward: 15.00 | Steps: 9 | Eps: 0.420
# Episode 174/500 | Reward: 15.00 | Steps: 9 | Eps: 0.418
# Episode 175/500 | Reward: 15.00 | Steps: 10 | Eps: 0.416
# Episode 176/500 | Reward: 15.00 | Steps: 10 | Eps: 0.414
# Episode 177/500 | Reward: 15.00 | Steps: 9 | Eps: 0.412
# Episode 178/500 | Reward: -15.00 | Steps: 9 | Eps: 0.410
# Episode 179/500 | Reward: 15.00 | Steps: 9 | Eps: 0.408
# Episode 180/500 | Reward: 15.00 | Steps: 9 | Eps: 0.406
# Episode 181/500 | Reward: 15.00 | Steps: 10 | Eps: 0.404
# Episode 182/500 | Reward: 15.00 | Steps: 9 | Eps: 0.402
# Episode 183/500 | Reward: -15.00 | Steps: 10 | Eps: 0.400
# Episode 184/500 | Reward: 15.00 | Steps: 9 | Eps: 0.398
# Episode 185/500 | Reward: 15.00 | Steps: 10 | Eps: 0.396
# Episode 186/500 | Reward: 15.00 | Steps: 10 | Eps: 0.394
# Episode 187/500 | Reward: 15.00 | Steps: 9 | Eps: 0.392
# Episode 188/500 | Reward: 15.00 | Steps: 9 | Eps: 0.390
# Episode 189/500 | Reward: 15.00 | Steps: 9 | Eps: 0.388
# Episode 190/500 | Reward: 15.00 | Steps: 9 | Eps: 0.386
# Episode 191/500 | Reward: 15.00 | Steps: 9 | Eps: 0.384
# Episode 192/500 | Reward: 15.00 | Steps: 10 | Eps: 0.382
# Episode 193/500 | Reward: -15.00 | Steps: 10 | Eps: 0.380
# Episode 194/500 | Reward: 15.00 | Steps: 9 | Eps: 0.378
# Episode 195/500 | Reward: 15.00 | Steps: 10 | Eps: 0.376
# Episode 196/500 | Reward: 15.00 | Steps: 10 | Eps: 0.374
# Episode 197/500 | Reward: 15.00 | Steps: 9 | Eps: 0.373
# Episode 198/500 | Reward: 15.00 | Steps: 9 | Eps: 0.371
# Episode 199/500 | Reward: 15.00 | Steps: 10 | Eps: 0.369
# Episode 200/500 | Reward: 15.00 | Steps: 11 | Eps: 0.367
# Episode 201/500 | Reward: 15.00 | Steps: 9 | Eps: 0.365
# Episode 202/500 | Reward: 15.00 | Steps: 10 | Eps: 0.363
# Episode 203/500 | Reward: 15.00 | Steps: 9 | Eps: 0.361
# Episode 204/500 | Reward: 15.00 | Steps: 9 | Eps: 0.360
# Episode 205/500 | Reward: -15.00 | Steps: 9 | Eps: 0.358
# Episode 206/500 | Reward: 15.00 | Steps: 9 | Eps: 0.356
# Episode 207/500 | Reward: 15.00 | Steps: 10 | Eps: 0.354
# Episode 208/500 | Reward: 15.00 | Steps: 9 | Eps: 0.353
# Episode 209/500 | Reward: 15.00 | Steps: 9 | Eps: 0.351
# Episode 210/500 | Reward: 15.00 | Steps: 10 | Eps: 0.349
# Episode 211/500 | Reward: 15.00 | Steps: 10 | Eps: 0.347
# Episode 212/500 | Reward: 15.00 | Steps: 10 | Eps: 0.346
# Episode 213/500 | Reward: 15.00 | Steps: 10 | Eps: 0.344
# Episode 214/500 | Reward: 15.00 | Steps: 10 | Eps: 0.342
# Episode 215/500 | Reward: 15.00 | Steps: 9 | Eps: 0.340
# Episode 216/500 | Reward: 15.00 | Steps: 9 | Eps: 0.339
# Episode 217/500 | Reward: 15.00 | Steps: 9 | Eps: 0.337
# Episode 218/500 | Reward: 15.00 | Steps: 11 | Eps: 0.335
# Episode 219/500 | Reward: 15.00 | Steps: 10 | Eps: 0.334
# Episode 220/500 | Reward: 15.00 | Steps: 9 | Eps: 0.332
# Episode 221/500 | Reward: 15.00 | Steps: 9 | Eps: 0.330
# Episode 222/500 | Reward: 15.00 | Steps: 9 | Eps: 0.329
# Episode 223/500 | Reward: 15.00 | Steps: 10 | Eps: 0.327
# Episode 224/500 | Reward: 15.00 | Steps: 9 | Eps: 0.325
# Episode 225/500 | Reward: 15.00 | Steps: 9 | Eps: 0.324
# Episode 226/500 | Reward: 15.00 | Steps: 9 | Eps: 0.322
# Episode 227/500 | Reward: 15.00 | Steps: 10 | Eps: 0.321
# Episode 228/500 | Reward: 15.00 | Steps: 10 | Eps: 0.319
# Episode 229/500 | Reward: 15.00 | Steps: 9 | Eps: 0.317
# Episode 230/500 | Reward: 15.00 | Steps: 10 | Eps: 0.316
# Episode 231/500 | Reward: 15.00 | Steps: 10 | Eps: 0.314
# Episode 232/500 | Reward: 15.00 | Steps: 10 | Eps: 0.313
# Episode 233/500 | Reward: 15.00 | Steps: 9 | Eps: 0.311
# Episode 234/500 | Reward: 15.00 | Steps: 10 | Eps: 0.309
# Episode 235/500 | Reward: 15.00 | Steps: 9 | Eps: 0.308
# Episode 236/500 | Reward: 15.00 | Steps: 9 | Eps: 0.306
# Episode 237/500 | Reward: 15.00 | Steps: 10 | Eps: 0.305
# Episode 238/500 | Reward: 15.00 | Steps: 9 | Eps: 0.303
# Episode 239/500 | Reward: 15.00 | Steps: 9 | Eps: 0.302
# Episode 240/500 | Reward: 15.00 | Steps: 10 | Eps: 0.300
# Episode 241/500 | Reward: 15.00 | Steps: 9 | Eps: 0.299
# Episode 242/500 | Reward: 15.00 | Steps: 9 | Eps: 0.297
# Episode 243/500 | Reward: 15.00 | Steps: 9 | Eps: 0.296
# Episode 244/500 | Reward: 15.00 | Steps: 10 | Eps: 0.294
# Episode 245/500 | Reward: 15.00 | Steps: 9 | Eps: 0.293
# Episode 246/500 | Reward: 15.00 | Steps: 10 | Eps: 0.291
# Episode 247/500 | Reward: 15.00 | Steps: 9 | Eps: 0.290
# Episode 248/500 | Reward: 15.00 | Steps: 9 | Eps: 0.288
# Episode 249/500 | Reward: 15.00 | Steps: 9 | Eps: 0.287
# Episode 250/500 | Reward: 15.00 | Steps: 9 | Eps: 0.286
# Episode 251/500 | Reward: 15.00 | Steps: 10 | Eps: 0.284
# Episode 252/500 | Reward: 15.00 | Steps: 9 | Eps: 0.283
# Episode 253/500 | Reward: 15.00 | Steps: 10 | Eps: 0.281
# Episode 254/500 | Reward: 15.00 | Steps: 10 | Eps: 0.280
# Episode 255/500 | Reward: 15.00 | Steps: 10 | Eps: 0.279
# Episode 256/500 | Reward: 15.00 | Steps: 10 | Eps: 0.277
# Episode 257/500 | Reward: 15.00 | Steps: 10 | Eps: 0.276
# Episode 258/500 | Reward: 15.00 | Steps: 9 | Eps: 0.274
# Episode 259/500 | Reward: 15.00 | Steps: 9 | Eps: 0.273
# Episode 260/500 | Reward: 15.00 | Steps: 9 | Eps: 0.272
# Episode 261/500 | Reward: 15.00 | Steps: 9 | Eps: 0.270
# Episode 262/500 | Reward: 15.00 | Steps: 7 | Eps: 0.269
# Episode 263/500 | Reward: 15.00 | Steps: 10 | Eps: 0.268
# Episode 264/500 | Reward: 15.00 | Steps: 10 | Eps: 0.266
# Episode 265/500 | Reward: 15.00 | Steps: 9 | Eps: 0.265
# Episode 266/500 | Reward: 15.00 | Steps: 11 | Eps: 0.264
# Episode 267/500 | Reward: 15.00 | Steps: 9 | Eps: 0.262
# Episode 268/500 | Reward: 15.00 | Steps: 9 | Eps: 0.261
# Episode 269/500 | Reward: 15.00 | Steps: 10 | Eps: 0.260
# Episode 270/500 | Reward: -15.00 | Steps: 9 | Eps: 0.258
# Episode 271/500 | Reward: 15.00 | Steps: 10 | Eps: 0.257
# Episode 272/500 | Reward: 15.00 | Steps: 10 | Eps: 0.256
# Episode 273/500 | Reward: 15.00 | Steps: 9 | Eps: 0.255
# Episode 274/500 | Reward: 15.00 | Steps: 10 | Eps: 0.253
# Episode 275/500 | Reward: 15.00 | Steps: 9 | Eps: 0.252
# Episode 276/500 | Reward: 15.00 | Steps: 9 | Eps: 0.251
# Episode 277/500 | Reward: 15.00 | Steps: 10 | Eps: 0.249
# Episode 278/500 | Reward: 15.00 | Steps: 10 | Eps: 0.248
# Episode 279/500 | Reward: 15.00 | Steps: 9 | Eps: 0.247
# Episode 280/500 | Reward: 15.00 | Steps: 9 | Eps: 0.246
# Episode 281/500 | Reward: 15.00 | Steps: 9 | Eps: 0.245
# Episode 282/500 | Reward: 15.00 | Steps: 9 | Eps: 0.243
# Episode 283/500 | Reward: 15.00 | Steps: 9 | Eps: 0.242
# Episode 284/500 | Reward: 15.00 | Steps: 9 | Eps: 0.241
# Episode 285/500 | Reward: 15.00 | Steps: 9 | Eps: 0.240
# Episode 286/500 | Reward: 15.00 | Steps: 9 | Eps: 0.238
# Episode 287/500 | Reward: 15.00 | Steps: 9 | Eps: 0.237
# Episode 288/500 | Reward: 15.00 | Steps: 10 | Eps: 0.236
# Episode 289/500 | Reward: 15.00 | Steps: 9 | Eps: 0.235
# Episode 290/500 | Reward: 15.00 | Steps: 9 | Eps: 0.234
# Episode 291/500 | Reward: 15.00 | Steps: 9 | Eps: 0.233
# Episode 292/500 | Reward: 15.00 | Steps: 9 | Eps: 0.231
# Episode 293/500 | Reward: 15.00 | Steps: 10 | Eps: 0.230
# Episode 294/500 | Reward: 15.00 | Steps: 9 | Eps: 0.229
# Episode 295/500 | Reward: 15.00 | Steps: 10 | Eps: 0.228
# Episode 296/500 | Reward: 15.00 | Steps: 9 | Eps: 0.227
# Episode 297/500 | Reward: 15.00 | Steps: 9 | Eps: 0.226
# Episode 298/500 | Reward: 15.00 | Steps: 9 | Eps: 0.225
# Episode 299/500 | Reward: 15.00 | Steps: 10 | Eps: 0.223
# Episode 300/500 | Reward: 15.00 | Steps: 10 | Eps: 0.222
# Episode 301/500 | Reward: 15.00 | Steps: 9 | Eps: 0.221
# Episode 302/500 | Reward: 15.00 | Steps: 9 | Eps: 0.220
# Episode 303/500 | Reward: 15.00 | Steps: 9 | Eps: 0.219
# Episode 304/500 | Reward: 15.00 | Steps: 10 | Eps: 0.218
# Episode 305/500 | Reward: -15.00 | Steps: 8 | Eps: 0.217
# Episode 306/500 | Reward: 15.00 | Steps: 10 | Eps: 0.216
# Episode 307/500 | Reward: 15.00 | Steps: 10 | Eps: 0.215
# Episode 308/500 | Reward: 15.00 | Steps: 8 | Eps: 0.214
# Episode 309/500 | Reward: 15.00 | Steps: 10 | Eps: 0.212
# Episode 310/500 | Reward: 15.00 | Steps: 10 | Eps: 0.211
# Episode 311/500 | Reward: 15.00 | Steps: 9 | Eps: 0.210
# Episode 312/500 | Reward: 15.00 | Steps: 10 | Eps: 0.209
# Episode 313/500 | Reward: 15.00 | Steps: 10 | Eps: 0.208
# Episode 314/500 | Reward: 15.00 | Steps: 9 | Eps: 0.207
# Episode 315/500 | Reward: 15.00 | Steps: 10 | Eps: 0.206
# Episode 316/500 | Reward: 15.00 | Steps: 9 | Eps: 0.205
# Episode 317/500 | Reward: 15.00 | Steps: 9 | Eps: 0.204
# Episode 318/500 | Reward: 15.00 | Steps: 9 | Eps: 0.203
# Episode 319/500 | Reward: 15.00 | Steps: 9 | Eps: 0.202
# Episode 320/500 | Reward: 15.00 | Steps: 10 | Eps: 0.201
# Episode 321/500 | Reward: 15.00 | Steps: 10 | Eps: 0.200
# Episode 322/500 | Reward: 15.00 | Steps: 9 | Eps: 0.199
# Episode 323/500 | Reward: 15.00 | Steps: 10 | Eps: 0.198
# Episode 324/500 | Reward: 15.00 | Steps: 10 | Eps: 0.197
# Episode 325/500 | Reward: 15.00 | Steps: 10 | Eps: 0.196
# Episode 326/500 | Reward: 15.00 | Steps: 10 | Eps: 0.195
# Episode 327/500 | Reward: 15.00 | Steps: 10 | Eps: 0.194
# Episode 328/500 | Reward: 15.00 | Steps: 9 | Eps: 0.193
# Episode 329/500 | Reward: 15.00 | Steps: 10 | Eps: 0.192
# Episode 330/500 | Reward: 15.00 | Steps: 9 | Eps: 0.191
# Episode 331/500 | Reward: 15.00 | Steps: 11 | Eps: 0.190
# Episode 332/500 | Reward: 15.00 | Steps: 8 | Eps: 0.189
# Episode 333/500 | Reward: 15.00 | Steps: 9 | Eps: 0.188
# Episode 334/500 | Reward: 15.00 | Steps: 9 | Eps: 0.187
# Episode 335/500 | Reward: 15.00 | Steps: 9 | Eps: 0.187
# Episode 336/500 | Reward: 15.00 | Steps: 9 | Eps: 0.186
# Episode 337/500 | Reward: 15.00 | Steps: 9 | Eps: 0.185
# Episode 338/500 | Reward: 15.00 | Steps: 9 | Eps: 0.184
# Episode 339/500 | Reward: 15.00 | Steps: 9 | Eps: 0.183
# Episode 340/500 | Reward: 15.00 | Steps: 10 | Eps: 0.182
# Episode 341/500 | Reward: 15.00 | Steps: 10 | Eps: 0.181
# Episode 342/500 | Reward: 15.00 | Steps: 9 | Eps: 0.180
# Episode 343/500 | Reward: 15.00 | Steps: 10 | Eps: 0.179
# Episode 344/500 | Reward: 15.00 | Steps: 10 | Eps: 0.178
# Episode 345/500 | Reward: 15.00 | Steps: 10 | Eps: 0.177
# Episode 346/500 | Reward: 15.00 | Steps: 10 | Eps: 0.177
# Episode 347/500 | Reward: 15.00 | Steps: 9 | Eps: 0.176
# Episode 348/500 | Reward: 15.00 | Steps: 10 | Eps: 0.175
# Episode 349/500 | Reward: 15.00 | Steps: 9 | Eps: 0.174
# Episode 350/500 | Reward: 15.00 | Steps: 9 | Eps: 0.173
# Episode 351/500 | Reward: 15.00 | Steps: 9 | Eps: 0.172
# Episode 352/500 | Reward: 15.00 | Steps: 9 | Eps: 0.171
# Episode 353/500 | Reward: 15.00 | Steps: 9 | Eps: 0.170
# Episode 354/500 | Reward: 15.00 | Steps: 9 | Eps: 0.170
# Episode 355/500 | Reward: 15.00 | Steps: 10 | Eps: 0.169
# Episode 356/500 | Reward: 15.00 | Steps: 10 | Eps: 0.168
# Episode 357/500 | Reward: 15.00 | Steps: 10 | Eps: 0.167
# Episode 358/500 | Reward: 15.00 | Steps: 9 | Eps: 0.166
# Episode 359/500 | Reward: 15.00 | Steps: 9 | Eps: 0.165
# Episode 360/500 | Reward: 15.00 | Steps: 9 | Eps: 0.165
# Episode 361/500 | Reward: 15.00 | Steps: 10 | Eps: 0.164
# Episode 362/500 | Reward: 15.00 | Steps: 10 | Eps: 0.163
# Episode 363/500 | Reward: 15.00 | Steps: 9 | Eps: 0.162
# Episode 364/500 | Reward: 15.00 | Steps: 10 | Eps: 0.161
# Episode 365/500 | Reward: 15.00 | Steps: 9 | Eps: 0.160
# Episode 366/500 | Reward: 15.00 | Steps: 9 | Eps: 0.160
# Episode 367/500 | Reward: 15.00 | Steps: 10 | Eps: 0.159
# Episode 368/500 | Reward: -15.00 | Steps: 7 | Eps: 0.158
# Episode 369/500 | Reward: 15.00 | Steps: 10 | Eps: 0.157
# Episode 370/500 | Reward: 15.00 | Steps: 10 | Eps: 0.157
# Episode 371/500 | Reward: 15.00 | Steps: 9 | Eps: 0.156
# Episode 372/500 | Reward: 15.00 | Steps: 10 | Eps: 0.155
# Episode 373/500 | Reward: 15.00 | Steps: 11 | Eps: 0.154
# Episode 374/500 | Reward: 15.00 | Steps: 10 | Eps: 0.153
# Episode 375/500 | Reward: 15.00 | Steps: 10 | Eps: 0.153
# Episode 376/500 | Reward: 15.00 | Steps: 10 | Eps: 0.152
# Episode 377/500 | Reward: 15.00 | Steps: 10 | Eps: 0.151
# Episode 378/500 | Reward: 15.00 | Steps: 9 | Eps: 0.150
# Episode 379/500 | Reward: 15.00 | Steps: 10 | Eps: 0.150
# Episode 380/500 | Reward: 15.00 | Steps: 9 | Eps: 0.149
# Episode 381/500 | Reward: 15.00 | Steps: 10 | Eps: 0.148
# Episode 382/500 | Reward: -15.00 | Steps: 9 | Eps: 0.147
# Episode 383/500 | Reward: 15.00 | Steps: 10 | Eps: 0.147
# Episode 384/500 | Reward: 15.00 | Steps: 9 | Eps: 0.146
# Episode 385/500 | Reward: 15.00 | Steps: 9 | Eps: 0.145
# Episode 386/500 | Reward: 15.00 | Steps: 10 | Eps: 0.144
# Episode 387/500 | Reward: 15.00 | Steps: 10 | Eps: 0.144
# Episode 388/500 | Reward: 15.00 | Steps: 9 | Eps: 0.143
# Episode 389/500 | Reward: 15.00 | Steps: 12 | Eps: 0.142
# Episode 390/500 | Reward: 15.00 | Steps: 10 | Eps: 0.142
# Episode 391/500 | Reward: 15.00 | Steps: 9 | Eps: 0.141
# Episode 392/500 | Reward: 15.00 | Steps: 9 | Eps: 0.140
# Episode 393/500 | Reward: 15.00 | Steps: 9 | Eps: 0.139
# Episode 394/500 | Reward: 15.00 | Steps: 9 | Eps: 0.139
# Episode 395/500 | Reward: 15.00 | Steps: 9 | Eps: 0.138
# Episode 396/500 | Reward: 15.00 | Steps: 9 | Eps: 0.137
# Episode 397/500 | Reward: 15.00 | Steps: 10 | Eps: 0.137
# Episode 398/500 | Reward: 15.00 | Steps: 9 | Eps: 0.136
# Episode 399/500 | Reward: 15.00 | Steps: 9 | Eps: 0.135
# Episode 400/500 | Reward: 15.00 | Steps: 10 | Eps: 0.135
# Episode 401/500 | Reward: 15.00 | Steps: 10 | Eps: 0.134
# Episode 402/500 | Reward: 15.00 | Steps: 9 | Eps: 0.133
# Episode 403/500 | Reward: 15.00 | Steps: 10 | Eps: 0.133
# Episode 404/500 | Reward: 15.00 | Steps: 10 | Eps: 0.132
# Episode 405/500 | Reward: 15.00 | Steps: 9 | Eps: 0.131
# Episode 406/500 | Reward: 15.00 | Steps: 9 | Eps: 0.131
# Episode 407/500 | Reward: 15.00 | Steps: 10 | Eps: 0.130
# Episode 408/500 | Reward: 15.00 | Steps: 10 | Eps: 0.129
# Episode 409/500 | Reward: 15.00 | Steps: 10 | Eps: 0.129
# Episode 410/500 | Reward: 15.00 | Steps: 9 | Eps: 0.128
# Episode 411/500 | Reward: 15.00 | Steps: 10 | Eps: 0.127
# Episode 412/500 | Reward: -15.00 | Steps: 10 | Eps: 0.127
# Episode 413/500 | Reward: 15.00 | Steps: 9 | Eps: 0.126
# Episode 414/500 | Reward: 15.00 | Steps: 10 | Eps: 0.126
# Episode 415/500 | Reward: -15.00 | Steps: 9 | Eps: 0.125
# Episode 416/500 | Reward: 15.00 | Steps: 10 | Eps: 0.124
# Episode 417/500 | Reward: 15.00 | Steps: 9 | Eps: 0.124
# Episode 418/500 | Reward: -15.00 | Steps: 8 | Eps: 0.123
# Episode 419/500 | Reward: 15.00 | Steps: 9 | Eps: 0.122
# Episode 420/500 | Reward: 15.00 | Steps: 9 | Eps: 0.122
# Episode 421/500 | Reward: 15.00 | Steps: 10 | Eps: 0.121
# Episode 422/500 | Reward: 15.00 | Steps: 10 | Eps: 0.121
# Episode 423/500 | Reward: 15.00 | Steps: 9 | Eps: 0.120
# Episode 424/500 | Reward: 15.00 | Steps: 10 | Eps: 0.119
# Episode 425/500 | Reward: 15.00 | Steps: 9 | Eps: 0.119
# Episode 426/500 | Reward: 15.00 | Steps: 10 | Eps: 0.118
# Episode 427/500 | Reward: 15.00 | Steps: 9 | Eps: 0.118
# Episode 428/500 | Reward: 15.00 | Steps: 9 | Eps: 0.117
# Episode 429/500 | Reward: -15.00 | Steps: 9 | Eps: 0.116
# Episode 430/500 | Reward: 15.00 | Steps: 8 | Eps: 0.116
# Episode 431/500 | Reward: 15.00 | Steps: 10 | Eps: 0.115
# Episode 432/500 | Reward: 15.00 | Steps: 9 | Eps: 0.115
# Episode 433/500 | Reward: 15.00 | Steps: 9 | Eps: 0.114
# Episode 434/500 | Reward: 15.00 | Steps: 9 | Eps: 0.114
# Episode 435/500 | Reward: -15.00 | Steps: 10 | Eps: 0.113
# Episode 436/500 | Reward: 15.00 | Steps: 10 | Eps: 0.112
# Episode 437/500 | Reward: 15.00 | Steps: 9 | Eps: 0.112
# Episode 438/500 | Reward: 15.00 | Steps: 9 | Eps: 0.111
# Episode 439/500 | Reward: 15.00 | Steps: 9 | Eps: 0.111
# Episode 440/500 | Reward: 15.00 | Steps: 10 | Eps: 0.110
# Episode 441/500 | Reward: 15.00 | Steps: 10 | Eps: 0.110
# Episode 442/500 | Reward: 15.00 | Steps: 9 | Eps: 0.109
# Episode 443/500 | Reward: 15.00 | Steps: 9 | Eps: 0.109
# Episode 444/500 | Reward: 15.00 | Steps: 10 | Eps: 0.108
# Episode 445/500 | Reward: 15.00 | Steps: 10 | Eps: 0.107
# Episode 446/500 | Reward: 15.00 | Steps: 9 | Eps: 0.107
# Episode 447/500 | Reward: 15.00 | Steps: 10 | Eps: 0.106
# Episode 448/500 | Reward: 15.00 | Steps: 10 | Eps: 0.106
# Episode 449/500 | Reward: -15.00 | Steps: 10 | Eps: 0.105
# Episode 450/500 | Reward: 15.00 | Steps: 9 | Eps: 0.105
# Episode 451/500 | Reward: 15.00 | Steps: 9 | Eps: 0.104
# Episode 452/500 | Reward: 15.00 | Steps: 10 | Eps: 0.104
# Episode 453/500 | Reward: 15.00 | Steps: 11 | Eps: 0.103
# Episode 454/500 | Reward: 15.00 | Steps: 10 | Eps: 0.103
# Episode 455/500 | Reward: 15.00 | Steps: 9 | Eps: 0.102
# Episode 456/500 | Reward: 15.00 | Steps: 9 | Eps: 0.102
# Episode 457/500 | Reward: 15.00 | Steps: 10 | Eps: 0.101
# Episode 458/500 | Reward: 15.00 | Steps: 9 | Eps: 0.101
# Episode 459/500 | Reward: 15.00 | Steps: 9 | Eps: 0.100
# Episode 460/500 | Reward: 15.00 | Steps: 12 | Eps: 0.100
# Episode 461/500 | Reward: 15.00 | Steps: 10 | Eps: 0.099
# Episode 462/500 | Reward: 15.00 | Steps: 9 | Eps: 0.099
# Episode 463/500 | Reward: 15.00 | Steps: 9 | Eps: 0.098
# Episode 464/500 | Reward: 15.00 | Steps: 9 | Eps: 0.098
# Episode 465/500 | Reward: 15.00 | Steps: 9 | Eps: 0.097
# Episode 466/500 | Reward: 15.00 | Steps: 9 | Eps: 0.097
# Episode 467/500 | Reward: 15.00 | Steps: 9 | Eps: 0.096
# Episode 468/500 | Reward: 15.00 | Steps: 9 | Eps: 0.096
# Episode 469/500 | Reward: 15.00 | Steps: 9 | Eps: 0.095
# Episode 470/500 | Reward: 15.00 | Steps: 8 | Eps: 0.095
# Episode 471/500 | Reward: 15.00 | Steps: 10 | Eps: 0.094
# Episode 472/500 | Reward: 15.00 | Steps: 10 | Eps: 0.094
# Episode 473/500 | Reward: 15.00 | Steps: 9 | Eps: 0.093
# Episode 474/500 | Reward: -15.00 | Steps: 9 | Eps: 0.093
# Episode 475/500 | Reward: 15.00 | Steps: 10 | Eps: 0.092
# Episode 476/500 | Reward: 15.00 | Steps: 10 | Eps: 0.092
# Episode 477/500 | Reward: 15.00 | Steps: 10 | Eps: 0.092
# Episode 478/500 | Reward: 15.00 | Steps: 10 | Eps: 0.091
# Episode 479/500 | Reward: 15.00 | Steps: 9 | Eps: 0.091
# Episode 480/500 | Reward: 15.00 | Steps: 10 | Eps: 0.090
# Episode 481/500 | Reward: 15.00 | Steps: 9 | Eps: 0.090
# Episode 482/500 | Reward: 15.00 | Steps: 10 | Eps: 0.089
# Episode 483/500 | Reward: 15.00 | Steps: 10 | Eps: 0.089
# Episode 484/500 | Reward: 15.00 | Steps: 9 | Eps: 0.088
# Episode 485/500 | Reward: 15.00 | Steps: 9 | Eps: 0.088
# Episode 486/500 | Reward: 15.00 | Steps: 9 | Eps: 0.088
# Episode 487/500 | Reward: 15.00 | Steps: 10 | Eps: 0.087
# Episode 488/500 | Reward: 15.00 | Steps: 11 | Eps: 0.087
# Episode 489/500 | Reward: 15.00 | Steps: 10 | Eps: 0.086
# Episode 490/500 | Reward: 15.00 | Steps: 9 | Eps: 0.086
# Episode 491/500 | Reward: 15.00 | Steps: 10 | Eps: 0.085
# Episode 492/500 | Reward: 15.00 | Steps: 9 | Eps: 0.085
# Episode 493/500 | Reward: 15.00 | Steps: 10 | Eps: 0.084
# Episode 494/500 | Reward: 15.00 | Steps: 9 | Eps: 0.084
# Episode 495/500 | Reward: 15.00 | Steps: 9 | Eps: 0.084
# Episode 496/500 | Reward: 15.00 | Steps: 9 | Eps: 0.083
# Episode 497/500 | Reward: 15.00 | Steps: 9 | Eps: 0.083
# Episode 498/500 | Reward: 15.00 | Steps: 9 | Eps: 0.082
# Episode 499/500 | Reward: 15.00 | Steps: 9 | Eps: 0.082
# Episode 500/500 | Reward: 15.00 | Steps: 10 | Eps: 0.082
# Eval Episode 1/20 | Reward: 15.00 | Steps: 9
# Eval Episode 2/20 | Reward: 15.00 | Steps: 9
# Eval Episode 3/20 | Reward: 15.00 | Steps: 10
# Eval Episode 4/20 | Reward: 15.00 | Steps: 9
# Eval Episode 5/20 | Reward: 15.00 | Steps: 9
# Eval Episode 6/20 | Reward: 15.00 | Steps: 10
# Eval Episode 7/20 | Reward: 15.00 | Steps: 10
# Eval Episode 8/20 | Reward: 15.00 | Steps: 9
# Eval Episode 9/20 | Reward: 15.00 | Steps: 9
# Eval Episode 10/20 | Reward: 15.00 | Steps: 9
# Eval Episode 11/20 | Reward: 15.00 | Steps: 10
# Eval Episode 12/20 | Reward: 15.00 | Steps: 10
# Eval Episode 13/20 | Reward: -15.00 | Steps: 9
# Eval Episode 14/20 | Reward: 15.00 | Steps: 9
# Eval Episode 15/20 | Reward: 15.00 | Steps: 10
# Eval Episode 16/20 | Reward: 15.00 | Steps: 9
# Eval Episode 17/20 | Reward: 15.00 | Steps: 10
# Eval Episode 18/20 | Reward: 15.00 | Steps: 9
# Eval Episode 19/20 | Reward: 15.00 | Steps: 10
# Eval Episode 20/20 | Reward: 15.00 | Steps: 9
#
# Evaluation over 20 episodes:
# Avg Reward: 13.50 ± 6.54
# Avg Length: 9.40 ± 0.49

# %%
# -----------------------------------------------------
# Performance visualization
# -----------------------------------------------------
plt.figure(figsize=(15,10))

plt.subplot(2,3,1)
plt.plot(reward_history)
plt.title("Training Reward per Episode")
plt.xlabel("Episode"); plt.ylabel("Reward")

plt.subplot(2,3,2)
plt.plot(loss_history)
plt.title("Average Loss per Episode")
plt.xlabel("Episode"); plt.ylabel("Loss")

plt.subplot(2,3,3)
plt.plot(episode_length)
plt.title("Episode Length")
plt.xlabel("Episode"); plt.ylabel("Steps")

plt.subplot(2,3,4)
plt.bar(np.arange(action_size), action_counts)
plt.title("Action Distribution (Training)")
plt.xlabel("Action"); plt.ylabel("Count")

plt.subplot(2,3,5)
plt.bar(np.arange(action_size), eval_actions, color='orange')
plt.title("Action Distribution (Evaluation)")
plt.xlabel("Action"); plt.ylabel("Count")

plt.subplot(2,3,6)
plt.plot(epsilon_history)
plt.title("Epsilon Decay")
plt.xlabel("Episode"); plt.ylabel("Epsilon")

plt.tight_layout()
plt.savefig("plot1.png")
plt.show()
